# %% [markdown]
# <a href="https://colab.research.google.com/github/d4vidi4n/EL7006/blob/main/run_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import h5py
import json
import os
from pathlib import Path
from torch.utils.data import Dataset, DataLoader, Subset
import pandas as pd
from timeit import default_timer as timer
from collections import defaultdict
import gc

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Model_SEED

# %%
# ===================================================================
# MÓDULOS DEL MODELO
# ===================================================================

class ConvBlock_SEED(nn.Module):
    def __init__(self, in_channels, out_channels, block_depth, window):
        super(ConvBlock_SEED, self).__init__()

        self.block_depth = block_depth

        self.convs = nn.ModuleList(
            [nn.Conv1d(in_channels if i==0 else out_channels, out_channels, window, padding=int(window/2))
                                for i in range(block_depth)])

        self.bns = nn.ModuleList([nn.BatchNorm1d(out_channels) for _ in range(block_depth)])

        self.gelu= nn.GELU()
        self.relu = nn.ReLU()

    def forward(self, x): # (B, i, L)

        for i in range(self.block_depth):

            x = self.convs[i](x)

            x = torch.relu(self.bns[i](x))

        return x


class ConvEmbed_SEED(nn.Module):
    def __init__(self, embed_dim, block_depth, blocks, dropout, window_len):
        super(ConvEmbed_SEED, self).__init__()

        self.bn = nn.BatchNorm1d(1)

        self.ln = nn.LayerNorm(1)

        self.blocks = blocks

        self.conv_blocks = nn.ModuleList([
            ConvBlock_SEED(1 if i==0 else embed_dim//(2**(blocks - i)), embed_dim//(2**(blocks - i - 1)), block_depth, window=window_len)
                                    for i in range(blocks)])

        self.pool = nn.AvgPool1d(2 , stride=2)

        self.dropout = nn.Dropout(dropout)

    def forward(self, x): # (B, L)

        x = self.bn(x.unsqueeze(1)) # (B, 1, L)


        for i in range(self.blocks):

            x = self.conv_blocks[i](x) # (B, Ei, L)


            x = self.pool(x)

        x = self.dropout(x) # (B, E, L/8)

        return x


class StageMultiDilatedConvolutions(nn.Module):
    def __init__(self, max_dil, filters_in, filters_out):
        super(StageMultiDilatedConvolutions, self).__init__()
        self.stage_config = []
        max_exponent = int(np.round(np.log(max_dil) / np.log(2)))
        for single_exponent in range(max_exponent + 1):
            f = int(filters_out / (2 ** (single_exponent + 1)))
            d = int(2**single_exponent)
            self.stage_config.append((f, d))
        self.stage_config[-1] = (2 * self.stage_config[-1][0], self.stage_config[-1][1])

        print(self.stage_config)
        self.branches = nn.ModuleList()
        for branch_filters, branch_dilation in self.stage_config:
            branch_layers = []
            for layer_id in ["a", "b"]:
                conv_layer = nn.Conv1d(
                    in_channels=filters_in if layer_id == "a" else branch_filters,
                    out_channels=branch_filters,
                    kernel_size=3,
                    padding=branch_dilation,
                    dilation=branch_dilation,
                    bias=False
                )
                bn_layer = nn.BatchNorm1d(branch_filters)
                relu_layer = nn.ReLU()
                branch_layers.append(conv_layer)
                branch_layers.append(bn_layer)
                branch_layers.append(relu_layer)
            self.branches.append(nn.Sequential(*branch_layers))

    def forward(self, inputs):
        outputs_branches = []
        for branch in self.branches:

            branch_outputs = inputs

            for layer in branch:

                branch_outputs = layer(branch_outputs)

            outputs_branches.append(branch_outputs)

        outputs = torch.cat(outputs_branches, dim=1)
        return outputs

class Local_encoding_stage_SEED(nn.Module):
    def __init__(self,  embed_dim, block_depth, blocks, dropout, window_len, filters_in, block_dilatation):
        super(Local_encoding_stage_SEED, self).__init__()

        self.block_dilatation = block_dilatation

        self.conv_layer = ConvEmbed_SEED(embed_dim, block_depth, blocks, dropout, window_len)

        self.layer_dilatations = nn.ModuleList([
            StageMultiDilatedConvolutions(8, filters_in*pow(2, i), filters_in*pow(2, i+1))
                                for i in range(block_dilatation)])
        self.pool = nn.AvgPool1d(2 , stride=2)


    def forward(self, inputs):

        output = self.conv_layer(inputs)

        for i in range(self.block_dilatation):

            output = self.layer_dilatations[i](output)

            output = self.pool(output)

        output = output.transpose(1, 2)

        return output


class BiLSTM(nn.Module):
    def __init__(self, embed_dim=256):
        super(BiLSTM, self).__init__()
        self.dropout = nn.Dropout(0.2)
        self.lstm = nn.LSTM(embed_dim, embed_dim, num_layers=2, dropout=0.5, bidirectional=True)

    def forward(self, x):
        x = self.dropout(x)
        h, _ = self.lstm(x.transpose(0, 1))
        return h.transpose(0, 1)

class RED_FC(nn.Module):
    def __init__(self, embed_dim = 256, hide_dim = 128):
        super(RED_FC, self).__init__()

        self.dropout = nn.Dropout(0.5)

        self.hidden = nn.Linear(2*embed_dim, hide_dim)
        nn.init.xavier_uniform_(self.hidden.weight, gain=nn.init.calculate_gain('relu'))
        self.hidden.bias.data.fill_(0.)

        self.logits = nn.Linear(hide_dim, 1)
        nn.init.xavier_uniform_(self.logits.weight)
        p1 = 0.1
        logp1 = torch.log(torch.tensor(p1/(1 - p1)))
        self.logits.bias = nn.Parameter(torch.tensor([logp1]))

        self.fc = nn.Sequential(self.hidden, nn.ReLU(), self.logits)

    def forward(self, x):
        x = self.dropout(x)
        x = self.fc(x).squeeze(-1)
        return x

# %%
# Parámetros del modelo
EMBED_DIM = 64
EMBED_BLOCKS = 1
FILTER_IN = 64
BLOCK_DILATATION = 2
RESOL_FACTOR = 8

# Parámetros de entrenamiento
EPOCHS = 5
BATCH_SIZE = 128 # Lo cambié a 128 para ocupar más memoria, debería demorarse menos (?)
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-4
NUM_WORKERS = 12
DROPOUT = 0.1

# Configuraciones del modelo
EMBEDDING_CONFIG_SEED = {
    "embed_dim": EMBED_DIM,
    "block_depth": 2,
    "blocks": EMBED_BLOCKS,
    "dropout": 0.0,
    "filters_in": FILTER_IN,
    "block_dilatation": BLOCK_DILATATION,
}

CLASSIFIER_CONFIG = {
    "embed_dim": 256,  # BiLSTM es bidireccional (2x)
    "hide_dim": 128,
}


class SEED_Model(nn.Module):
    def __init__(self):
        super(SEED_Model, self).__init__()

        self.embedding = Local_encoding_stage_SEED(**EMBEDDING_CONFIG_SEED, window_len=3)
        final_channels = FILTER_IN * (2 ** BLOCK_DILATATION)
        self.transformer = BiLSTM(final_channels)
        self.classifier = RED_FC(**CLASSIFIER_CONFIG)

        # Loss
        self.criterion = nn.BCEWithLogitsLoss()

    def forward(self, x):
        embeds = self.embedding(x)
        output = self.transformer(embeds)
        output = self.classifier(output)
        output = output.repeat_interleave(RESOL_FACTOR, dim=1)
        return output

# %% [markdown]
# # Train_model

# %%
# ===================================================================
# PARÁMETROS DE CONFIGURACIÓN
# ===================================================================

# Parámetros del modelo
EMBED_DIM = 64
EMBED_BLOCKS = 1
FILTER_IN = 64
BLOCK_DILATATION = 2
RESOL_FACTOR = 8

# Parámetros de entrenamiento
EPOCHS = 5
BATCH_SIZE = 128
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-4
NUM_WORKERS = 12
DROPOUT = 0.1

# Configuraciones del modelo
EMBEDDING_CONFIG_SEED = {
    "embed_dim": EMBED_DIM,
    "block_depth": 2,
    "blocks": EMBED_BLOCKS,
    "dropout": 0.0,
    "filters_in": FILTER_IN,
    "block_dilatation": BLOCK_DILATATION,
}

CLASSIFIER_CONFIG = {
    "embed_dim": 256,  # BiLSTM es bidireccional (2x)
    "hide_dim": 128,
}

# Paths
h5_file_path = "/content/drive/MyDrive/codigo_eeg_redes/data/moda_augmented_s5.h5"
folds_json_path = "/content/drive/MyDrive/codigo_eeg_redes/data/moda_folds.json"
weights_save_dir = "/content/drive/MyDrive/codigo_eeg_redes/model_weights_best_original"  # o model_weights

print("🚀 CONFIGURACIÓN CARGADA:")
print(f"   📁 Dataset: {h5_file_path}")
print(f"   📁 Folds: {folds_json_path}")
print(f"   💾 Pesos: {weights_save_dir}")
print(f"   🧠 Embed dim: {EMBED_DIM}")
print(f"   🎯 Epochs: {EPOCHS}")
print(f"   📦 Batch size: {BATCH_SIZE}")


class H5Dataset(Dataset):
    def __init__(self, h5_file_path, subject_ids=None, norm_data=False):
        self.h5_file_path = h5_file_path
        self.norm_data = norm_data

        # Abrir archivo para obtener información
        with h5py.File(h5_file_path, 'r') as f:
            self.total_samples = len(f['signals'])
            self.signal_length = f['signals'].shape[1]
            self.label_length = f['labels'].shape[1]

            # Obtener todos los subject_ids
            all_subject_ids = [s.decode('utf-8') for s in f['subject_ids'][:]]

            # Filtrar por subject_ids si se especifica
            if subject_ids is not None:
                self.valid_indices = []
                for i, subj_id in enumerate(all_subject_ids):
                    if subj_id in subject_ids:
                        self.valid_indices.append(i)
            else:
                self.valid_indices = list(range(self.total_samples))

        # ✅ CALCULAR df_id_group PARA BALANCED BATCH SAMPLER
        self._calculate_median_groups()

        print(f"📊 H5Dataset creado:")
        print(f"   Total muestras en H5: {self.total_samples}")
        print(f"   Muestras válidas: {len(self.valid_indices)}")
        print(f"   Longitud señal: {self.signal_length}")
        print(f"   Longitud labels: {self.label_length}")

    def _calculate_median_groups(self):
        """Calcular grupos de mediana para balanceado"""
        print("📊 Calculando grupos de mediana para balanceado...")

        # Calcular positivos por muestra
        positives_per_sample = []
        with h5py.File(self.h5_file_path, 'r') as f:
            for idx in self.valid_indices:
                labels = f['labels'][idx]
                positives = np.sum(labels)
                positives_per_sample.append(positives)

        # Calcular mediana
        median_positives = np.median(positives_per_sample)

        # Crear DataFrame con grupos de mediana
        data = []
        for i, idx in enumerate(self.valid_indices):
            positives = positives_per_sample[i]
            median_group = 1 if positives > median_positives else 0
            data.append({'id': i + 1, 'median_group': median_group})  # +1 para compatibilidad

        self.df_id_group = pd.DataFrame(data)

        above_median = len(self.df_id_group[self.df_id_group['median_group'] == 1])
        below_median = len(self.df_id_group[self.df_id_group['median_group'] == 0])

        print(f"   ✅ Mediana de positivos: {median_positives:.1f}")
        print(f"   📊 Above median: {above_median} muestras")
        print(f"   📊 Below median: {below_median} muestras")

    def __len__(self):
        return len(self.valid_indices)

    def __getitem__(self, idx):
        real_idx = self.valid_indices[idx]

        with h5py.File(self.h5_file_path, 'r') as f:
            signal = f['signals'][real_idx]
            labels = f['labels'][real_idx]

            # Convertir a float32
            signal = signal.astype(np.float32)
            labels = labels.astype(np.float32)

            # Normalizar si es necesario
            if self.norm_data:
                min_val, max_val = np.min(signal), np.max(signal)
                if max_val > min_val:
                    signal = 2 * (signal - min_val) / (max_val - min_val) - 1

            return real_idx, signal, labels

# ===================================================================
# BALANCED BATCH SAMPLER
# ===================================================================

class BalancedBatchSampler:
    def __init__(self, df_id_group, batch_size, shuffle=True):
        self.shuffle = shuffle
        self.batch_size = batch_size

        self.id_above_median = df_id_group[
            df_id_group.median_group == 1
        ]['id'].values
        self.id_below_median = df_id_group[
            df_id_group.median_group == 0
        ]['id'].values

        # ✅ BALANCEO ORIGINAL (above/below median)
        self._balance_above_below_median()

    def _balance_above_below_median(self):
        """Balanceo original por above/below median"""
        print(f"\n📊 BALANCEO ABOVE/BELOW MEDIAN:")
        print(f"   Above median: {len(self.id_above_median)} IDs")
        print(f"   Below median: {len(self.id_below_median)} IDs")

        difference = len(self.id_above_median) - len(self.id_below_median)

        if difference > 0:  # Más IDs above que below
            ids_repeated = np.random.choice(
                self.id_below_median, difference, replace=False,
            )
            self.id_below_median = np.append(
                self.id_below_median, ids_repeated,
            )
            print(f"   ✅ Duplicados {difference} IDs del grupo below_median")

        elif difference < 0:  # Más IDs below que above
            ids_repeated = np.random.choice(
                self.id_above_median, -1*difference, replace=False,
            )
            self.id_above_median = np.append(
                self.id_above_median, ids_repeated,
            )
            print(f"   ✅ Duplicados {-difference} IDs del grupo above_median")

        print(f"   📊 RESULTADO: Above={len(self.id_above_median)}, Below={len(self.id_below_median)}")

    def __iter__(self):
        if self.shuffle:
            np.random.shuffle(self.id_above_median)
            np.random.shuffle(self.id_below_median)

        batch = [0] * self.batch_size  # indexes of batch init ceros
        idx_in_batch = 0

        for above_idx, below_idx in zip(self.id_above_median, self.id_below_median):
            batch[idx_in_batch] = below_idx - 1  # -1 para índices de torch
            batch[idx_in_batch + 1] = above_idx - 1  # -1 para índices de torch
            idx_in_batch += 2

            if idx_in_batch >= self.batch_size:  # yield batch and start new one
                yield batch
                idx_in_batch = 0
                batch = [0] * self.batch_size

        # if, for some ids group there are more than in others
        if idx_in_batch > 0:
            yield batch[:idx_in_batch]

    def __len__(self):
        total_ids = len(self.id_above_median) + len(self.id_below_median)
        return (total_ids + self.batch_size - 1) // self.batch_size

def create_batch_h5(data_list):
    """Función para crear batches desde H5Dataset"""
    data_list = [data for data in data_list if data is not None]

    if len(data_list) == 0:
        return torch.empty(0, dtype=torch.long), torch.empty(0, 0), torch.empty(0, 0)

    ids, signals, labels = zip(*data_list)

    ids_tensor = torch.LongTensor(np.array(ids))
    signals_tensor = torch.FloatTensor(np.array(signals))
    labels_tensor = torch.FloatTensor(np.array(labels))

    return ids_tensor, signals_tensor, labels_tensor

# ===================================================================
# FUNCIONES DE ENTRENAMIENTO
# ===================================================================

def early_stopping(loss_dev, patience=8):
    if len(loss_dev) < patience:
        return False
    recent_losses = loss_dev[-patience:]
    return all(recent_losses[i] >= recent_losses[i - 1] for i in range(1, patience))

def train_epoch(model, optimizer, loader, epoch, device):
    model.train()
    run_loss = 0.0
    batches = len(loader)

    for i, (_, input, target) in enumerate(loader):
        input, target = input.to(device), target.to(device)

        output = model(input)
        loss = model.criterion(output.flatten(), target.flatten())

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        optimizer.zero_grad()

        run_loss += loss.item()
        print(f'\rEpoch {epoch} ({100*(i + 1)/batches:.2f}%) | Train Loss: {run_loss / (i + 1):.4f} ', end='', flush=True)

    return run_loss / batches

def evaluate_epoch(model, loader, device):
    model.eval()
    val_loss = 0.0

    with torch.no_grad():
        for _, input, target in loader:
            input, target = input.to(device), target.to(device)

            output = model(input)
            val_loss += model.criterion(output.flatten(), target.flatten()).item()

    avg_loss = val_loss / len(loader)
    print(f"| Val Loss: {avg_loss:.4f}")
    return avg_loss

# ===================================================================
# FUNCIÓN PRINCIPAL DE ENTRENAMIENTO
# ===================================================================

def train_model_for_fold(eval_num, fold_num, val_subjects, test_subjects, all_subjects):
    """Entrena el modelo para un fold específico"""

    print(f"\n{'='*60}")
    print(f"🎯 ENTRENANDO EVAL {eval_num} - FOLD {fold_num}")
    print(f"{'='*60}")

    # ✅ LIMPIAR MEMORIA Y CACHE DE CUDA ANTES DE CREAR NUEVO MODELO
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    gc.collect()

    # Determinar sujetos de entrenamiento
    train_subjects = [s for s in all_subjects if s not in val_subjects and s not in test_subjects]

    print(f"📊 Distribución de sujetos:")
    print(f"   Train: {len(train_subjects)} sujetos")
    print(f"   Val: {len(val_subjects)} sujetos")
    print(f"   Test: {len(test_subjects)} sujetos")

    # Crear datasets
    train_dataset = H5Dataset(h5_file_path, subject_ids=train_subjects, norm_data=False)
    val_dataset = H5Dataset(h5_file_path, subject_ids=val_subjects, norm_data=False)

    # ✅ CREAR LOADERS CON BALANCED BATCH SAMPLER PARA ENTRENAMIENTO
    train_loader = DataLoader(
        train_dataset,
        num_workers=NUM_WORKERS,
        collate_fn=create_batch_h5,
        batch_sampler=BalancedBatchSampler(train_dataset.df_id_group, batch_size=BATCH_SIZE, shuffle=True)
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        collate_fn=create_batch_h5
    )

    print(f"📦 Datos cargados:")
    print(f"   Train samples: {len(train_dataset)}")
    print(f"   Val samples: {len(val_dataset)}")
    print(f"   Train batches: {len(train_loader)}")
    print(f"   Val batches: {len(val_loader)}")

    # Configurar device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"🖥️  Device: {device}")

    # ✅ CREAR MODELO NUEVO PARA CADA FOLD (sin reutilizar)
    model = SEED_Model().to(device)
    print(f"🧠 Parámetros del modelo: {sum(p.numel() for p in model.parameters()):,}")

    # ✅ OPTIMIZADOR NUEVO PARA CADA FOLD
    optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

    # Variables de seguimiento
    loss_train, loss_dev = [], []
    best_val_loss = float('inf')
    patience_count = 0

    # Carpeta para guardar pesos
    save_folder = Path(weights_save_dir) / f"eval_{eval_num}" / f"fold_{fold_num}"
    save_folder.mkdir(parents=True, exist_ok=True)

    print(f"💾 Guardando en: {save_folder}")

    # Entrenamiento
    for epoch in range(1, EPOCHS + 1):
        t0 = timer()

        # Entrenar
        train_loss = train_epoch(model, optimizer, train_loader, epoch, device)

        # Evaluar
        val_loss = evaluate_epoch(model, val_loader, device)

        # Guardar métricas
        loss_train.append(train_loss)
        loss_dev.append(val_loss)

        dt = timer() - t0
        print(f'| Epoch Time: {dt//60:.0f}m {dt%60:.1f}s')

        # Guardar mejor modelo
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_count = 0

            # Guardar pesos
            torch.save(model.embedding.state_dict(), save_folder / "embedding_best.pth")
            torch.save(model.transformer.state_dict(), save_folder / "lstm_best.pth")
            torch.save(model.classifier.state_dict(), save_folder / "classifier_best.pth")

            print(f"✅ Mejor modelo guardado | Val Loss: {best_val_loss:.4f}")
        else:
            patience_count += 1


        # Paciencia
        if patience_count >= 6:
            print(f"🛑 Early stopping por paciencia en época {epoch}")
            break

    # Guardar modelo final
    torch.save(model.embedding.state_dict(), save_folder / "embedding_final.pth")
    torch.save(model.transformer.state_dict(), save_folder / "lstm_final.pth")
    torch.save(model.classifier.state_dict(), save_folder / "classifier_final.pth")

    print(f"✅ Entrenamiento completado para Eval {eval_num} - Fold {fold_num}")
    print(f"📊 Mejor Val Loss: {best_val_loss:.4f}")
    print(f"💾 Pesos guardados en: {save_folder}")

    # ✅ LIMPIAR MODELO Y MEMORIA AL FINALIZAR EL FOLD
    del model
    del optimizer
    del train_loader
    del val_loader
    del train_dataset
    del val_dataset

    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    gc.collect()

    print(f"🧹 Memoria limpiada para siguiente fold")

    return best_val_loss

# ===================================================================
# EJECUCIÓN PRINCIPAL
# ===================================================================

def main():
    """Función principal que ejecuta todo el entrenamiento"""

    print("🚀 INICIANDO ENTRENAMIENTO COMPLETO DEL MODELO SEED")
    print("="*60)

    # Cargar folds
    print("📁 Cargando configuración de folds...")
    with open(folds_json_path, 'r') as f:
        folds_data = json.load(f)

    # Obtener todos los sujetos del dataset
    with h5py.File(h5_file_path, 'r') as f:
        all_subjects = list(set([s.decode('utf-8') for s in f['subject_ids'][:]]))

    print(f"📊 Total sujetos en dataset: {len(all_subjects)}")

    # Crear directorio base
    Path(weights_save_dir).mkdir(exist_ok=True)

    # Resultados generales
    results = []

    # Iterar sobre todas las evaluaciones y folds
    for eval_key in sorted(folds_data.keys()):
        eval_num = int(eval_key.split('_')[1])

        for fold_key in sorted(folds_data[eval_key].keys()):
            fold_num = int(fold_key.split('_')[1])

            # Obtener sujetos
            val_subjects = folds_data[eval_key][fold_key]['val']
            test_subjects = folds_data[eval_key][fold_key]['test']

            # ✅ ENTRENAR MODELO (NUEVO PARA CADA FOLD)
            best_loss = train_model_for_fold(eval_num, fold_num, val_subjects, test_subjects, all_subjects)

            # Guardar resultado
            results.append({
                'eval': eval_num,
                'fold': fold_num,
                'best_val_loss': best_loss,
                'train_subjects': len(all_subjects) - len(val_subjects) - len(test_subjects),
                'val_subjects': len(val_subjects),
                'test_subjects': len(test_subjects)
            })

    # Mostrar resumen final
    print(f"\n{'='*60}")
    print("📊 RESUMEN FINAL DE ENTRENAMIENTO")
    print(f"{'='*60}")

    results_df = pd.DataFrame(results)
    print(results_df.to_string(index=False))

    print(f"\n📊 Estadísticas generales:")
    print(f"   Mejor Val Loss promedio: {results_df['best_val_loss'].mean():.4f}")
    print(f"   Mejor Val Loss std: {results_df['best_val_loss'].std():.4f}")
    print(f"   Mejor Val Loss min: {results_df['best_val_loss'].min():.4f}")
    print(f"   Mejor Val Loss max: {results_df['best_val_loss'].max():.4f}")

    print(f"\n✅ ENTRENAMIENTO COMPLETO FINALIZADO")
    print(f"💾 Todos los pesos guardados en: {weights_save_dir}")

# Ejecutar entrenamiento
if __name__ == "__main__":
    main()
# Out:
# 🚀 CONFIGURACIÓN CARGADA:
#    📁 Dataset: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/data/moda_augmented_s5.h5
#    📁 Folds: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/data/moda_folds.json
#    💾 Pesos: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/model_weights
#    🧠 Embed dim: 64
#    🎯 Epochs: 5
#    📦 Batch size: 32
# 🚀 INICIANDO ENTRENAMIENTO COMPLETO DEL MODELO SEED
# ============================================================
# 📁 Cargando configuración de folds...
# 📊 Total sujetos en dataset: 180
#
# ============================================================
# 🎯 ENTRENANDO EVAL 1 - FOLD 1
# ============================================================
# 📊 Distribución de sujetos:
#    Train: 108 sujetos
#    Val: 36 sujetos
#    Test: 36 sujetos
# 📊 Calculando grupos de mediana para balanceado...
#    ✅ Mediana de positivos: 132.0
#    📊 Above median: 4471 muestras
#    📊 Below median: 4484 muestras
# 📊 H5Dataset creado:
#    Total muestras en H5: 14940
#    Muestras válidas: 8955
#    Longitud señal: 4000
#    Longitud labels: 4000
# 📊 Calculando grupos de mediana para balanceado...
#    ✅ Mediana de positivos: 116.0
#    📊 Above median: 1495 muestras
#    📊 Below median: 1496 muestras
# 📊 H5Dataset creado:
#    Total muestras en H5: 14940
#    Muestras válidas: 2991
#    Longitud señal: 4000
#    Longitud labels: 4000
#
# 📊 BALANCEO ABOVE/BELOW MEDIAN:
#    Above median: 4471 IDs
#    Below median: 4484 IDs
#    ✅ Duplicados 13 IDs del grupo above_median
#    📊 RESULTADO: Above=4484, Below=4484
# 📦 Datos cargados:
#    Train samples: 8955
#    Val samples: 2991
#    Train batches: 281
#    Val batches: 94
# 🖥️  Device: cuda
# [(64, 1), (32, 2), (16, 4), (16, 8)]
# [(128, 1), (64, 2), (32, 4), (32, 8)]
# 🧠 Parámetros del modelo: 2,917,189
# 💾 Guardando en: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/model_weights/eval_1/fold_1
# Epoch 1 (100.00%) | Train Loss: 0.0697 | Val Loss: 0.0459
# | Epoch Time: 5m 17.8s
# ✅ Mejor modelo guardado | Val Loss: 0.0459
# Epoch 2 (100.00%) | Train Loss: 0.0521 | Val Loss: 0.0433
# | Epoch Time: 5m 17.3s
# ✅ Mejor modelo guardado | Val Loss: 0.0433
# Epoch 3 (100.00%) | Train Loss: 0.0477 | Val Loss: 0.0460
# | Epoch Time: 5m 16.3s
# Epoch 4 (100.00%) | Train Loss: 0.0449 | Val Loss: 0.0420
# | Epoch Time: 5m 18.3s
# ✅ Mejor modelo guardado | Val Loss: 0.0420
# Epoch 5 (100.00%) | Train Loss: 0.0421 | Val Loss: 0.0467
# | Epoch Time: 5m 18.4s
# ✅ Entrenamiento completado para Eval 1 - Fold 1
# 📊 Mejor Val Loss: 0.0420
# 💾 Pesos guardados en: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/model_weights/eval_1/fold_1
# 🧹 Memoria limpiada para siguiente fold
#
# ============================================================
# 🎯 ENTRENANDO EVAL 1 - FOLD 2
# ============================================================
# 📊 Distribución de sujetos:
#    Train: 108 sujetos
#    Val: 36 sujetos
#    Test: 36 sujetos
# 📊 Calculando grupos de mediana para balanceado...
#    ✅ Mediana de positivos: 126.5
#    📊 Above median: 4478 muestras
#    📊 Below median: 4478 muestras
# 📊 H5Dataset creado:
#    Total muestras en H5: 14940
#    Muestras válidas: 8956
#    Longitud señal: 4000
#    Longitud labels: 4000
# 📊 Calculando grupos de mediana para balanceado...
#    ✅ Mediana de positivos: 120.0
#    📊 Above median: 1489 muestras
#    📊 Below median: 1505 muestras
# 📊 H5Dataset creado:
#    Total muestras en H5: 14940
#    Muestras válidas: 2994
#    Longitud señal: 4000
#    Longitud labels: 4000
#
# 📊 BALANCEO ABOVE/BELOW MEDIAN:
#    Above median: 4478 IDs
#    Below median: 4478 IDs
#    📊 RESULTADO: Above=4478, Below=4478
# 📦 Datos cargados:
#    Train samples: 8956
#    Val samples: 2994
#    Train batches: 280
#    Val batches: 94
# 🖥️  Device: cuda
# [(64, 1), (32, 2), (16, 4), (16, 8)]
# [(128, 1), (64, 2), (32, 4), (32, 8)]
# 🧠 Parámetros del modelo: 2,917,189
# 💾 Guardando en: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/model_weights/eval_1/fold_2
# Epoch 1 (100.00%) | Train Loss: 0.0658 | Val Loss: 0.0560
# | Epoch Time: 5m 15.6s
# ✅ Mejor modelo guardado | Val Loss: 0.0560
# Epoch 2 (100.00%) | Train Loss: 0.0484 | Val Loss: 0.0480
# | Epoch Time: 5m 17.5s
# ✅ Mejor modelo guardado | Val Loss: 0.0480
# Epoch 3 (100.00%) | Train Loss: 0.0437 | Val Loss: 0.0463
# | Epoch Time: 5m 23.2s
# ✅ Mejor modelo guardado | Val Loss: 0.0463
# Epoch 4 (100.00%) | Train Loss: 0.0416 | Val Loss: 0.0459
# | Epoch Time: 5m 16.4s
# ✅ Mejor modelo guardado | Val Loss: 0.0459
# Epoch 5 (100.00%) | Train Loss: 0.0385 | Val Loss: 0.0490
# | Epoch Time: 5m 14.4s
# ✅ Entrenamiento completado para Eval 1 - Fold 2
# 📊 Mejor Val Loss: 0.0459
# 💾 Pesos guardados en: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/model_weights/eval_1/fold_2
# 🧹 Memoria limpiada para siguiente fold
#
# ============================================================
# 🎯 ENTRENANDO EVAL 1 - FOLD 3
# ============================================================
# 📊 Distribución de sujetos:
#    Train: 108 sujetos
#    Val: 36 sujetos
#    Test: 36 sujetos
# 📊 Calculando grupos de mediana para balanceado...
#    ✅ Mediana de positivos: 128.0
#    📊 Above median: 4441 muestras
#    📊 Below median: 4516 muestras
# 📊 H5Dataset creado:
#    Total muestras en H5: 14940
#    Muestras válidas: 8957
#    Longitud señal: 4000
#    Longitud labels: 4000
# 📊 Calculando grupos de mediana para balanceado...
#    ✅ Mediana de positivos: 124.5
#    📊 Above median: 1495 muestras
#    📊 Below median: 1495 muestras
# 📊 H5Dataset creado:
#    Total muestras en H5: 14940
#    Muestras válidas: 2990
#    Longitud señal: 4000
#    Longitud labels: 4000
#
# 📊 BALANCEO ABOVE/BELOW MEDIAN:
#    Above median: 4441 IDs
#    Below median: 4516 IDs
#    ✅ Duplicados 75 IDs del grupo above_median
#    📊 RESULTADO: Above=4516, Below=4516
# 📦 Datos cargados:
#    Train samples: 8957
#    Val samples: 2990
#    Train batches: 283
#    Val batches: 94
# 🖥️  Device: cuda
# [(64, 1), (32, 2), (16, 4), (16, 8)]
# [(128, 1), (64, 2), (32, 4), (32, 8)]
# 🧠 Parámetros del modelo: 2,917,189
# 💾 Guardando en: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/model_weights/eval_1/fold_3
# Epoch 1 (100.00%) | Train Loss: 0.0641 | Val Loss: 0.0612
# | Epoch Time: 5m 14.3s
# ✅ Mejor modelo guardado | Val Loss: 0.0612
# Epoch 2 (100.00%) | Train Loss: 0.0482 | Val Loss: 0.0667
# | Epoch Time: 5m 14.7s
# Epoch 3 (100.00%) | Train Loss: 0.0441 | Val Loss: 0.0588
# | Epoch Time: 5m 14.1s
# ✅ Mejor modelo guardado | Val Loss: 0.0588
# Epoch 4 (100.00%) | Train Loss: 0.0416 | Val Loss: 0.0611
# | Epoch Time: 5m 12.7s
# Epoch 5 (100.00%) | Train Loss: 0.0379 | Val Loss: 0.0647
# | Epoch Time: 5m 13.6s
# ✅ Entrenamiento completado para Eval 1 - Fold 3
# 📊 Mejor Val Loss: 0.0588
# 💾 Pesos guardados en: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/model_weights/eval_1/fold_3
# 🧹 Memoria limpiada para siguiente fold
#
# ============================================================
# 🎯 ENTRENANDO EVAL 1 - FOLD 4
# ============================================================
# 📊 Distribución de sujetos:
#    Train: 108 sujetos
#    Val: 36 sujetos
#    Test: 36 sujetos
# 📊 Calculando grupos de mediana para balanceado...
#    ✅ Mediana de positivos: 120.0
#    📊 Above median: 4442 muestras
#    📊 Below median: 4533 muestras
# 📊 H5Dataset creado:
#    Total muestras en H5: 14940
#    Muestras válidas: 8975
#    Longitud señal: 4000
#    Longitud labels: 4000
# 📊 Calculando grupos de mediana para balanceado...
#    ✅ Mediana de positivos: 120.0
#    📊 Above median: 1483 muestras
#    📊 Below median: 1510 muestras
# 📊 H5Dataset creado:
#    Total muestras en H5: 14940
#    Muestras válidas: 2993
#    Longitud señal: 4000
#    Longitud labels: 4000
#
# 📊 BALANCEO ABOVE/BELOW MEDIAN:
#    Above median: 4442 IDs
#    Below median: 4533 IDs
#    ✅ Duplicados 91 IDs del grupo above_median
#    📊 RESULTADO: Above=4533, Below=4533
# 📦 Datos cargados:
#    Train samples: 8975
#    Val samples: 2993
#    Train batches: 284
#    Val batches: 94
# 🖥️  Device: cuda
# [(64, 1), (32, 2), (16, 4), (16, 8)]
# [(128, 1), (64, 2), (32, 4), (32, 8)]
# 🧠 Parámetros del modelo: 2,917,189
# 💾 Guardando en: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/model_weights/eval_1/fold_4
# Epoch 1 (100.00%) | Train Loss: 0.0661 | Val Loss: 0.0515
# | Epoch Time: 5m 14.4s
# ✅ Mejor modelo guardado | Val Loss: 0.0515
# Epoch 2 (100.00%) | Train Loss: 0.0482 | Val Loss: 0.0594
# | Epoch Time: 5m 15.6s
# Epoch 3 (100.00%) | Train Loss: 0.0445 | Val Loss: 0.0529
# | Epoch Time: 5m 14.6s
# Epoch 4 (100.00%) | Train Loss: 0.0416 | Val Loss: 0.0583
# | Epoch Time: 5m 15.0s
# Epoch 5 (100.00%) | Train Loss: 0.0389 | Val Loss: 0.0508
# | Epoch Time: 5m 15.8s
# ✅ Mejor modelo guardado | Val Loss: 0.0508
# ✅ Entrenamiento completado para Eval 1 - Fold 4
# 📊 Mejor Val Loss: 0.0508
# 💾 Pesos guardados en: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/model_weights/eval_1/fold_4
# 🧹 Memoria limpiada para siguiente fold
#
# ============================================================
# 🎯 ENTRENANDO EVAL 1 - FOLD 5
# ============================================================
# 📊 Distribución de sujetos:
#    Train: 108 sujetos
#    Val: 36 sujetos
#    Test: 36 sujetos
# 📊 Calculando grupos de mediana para balanceado...
#    ✅ Mediana de positivos: 120.0
#    📊 Above median: 4486 muestras
#    📊 Below median: 4491 muestras
# 📊 H5Dataset creado:
#    Total muestras en H5: 14940
#    Muestras válidas: 8977
#    Longitud señal: 4000
#    Longitud labels: 4000
# 📊 Calculando grupos de mediana para balanceado...
#    ✅ Mediana de positivos: 156.0
#    📊 Above median: 1482 muestras
#    📊 Below median: 1490 muestras
# 📊 H5Dataset creado:
#    Total muestras en H5: 14940
#    Muestras válidas: 2972
#    Longitud señal: 4000
#    Longitud labels: 4000
#
# 📊 BALANCEO ABOVE/BELOW MEDIAN:
#    Above median: 4486 IDs
#    Below median: 4491 IDs
#    ✅ Duplicados 5 IDs del grupo above_median
#    📊 RESULTADO: Above=4491, Below=4491
# 📦 Datos cargados:
#    Train samples: 8977
#    Val samples: 2972
#    Train batches: 281
#    Val batches: 93
# 🖥️  Device: cuda
# [(64, 1), (32, 2), (16, 4), (16, 8)]
# [(128, 1), (64, 2), (32, 4), (32, 8)]
# 🧠 Parámetros del modelo: 2,917,189
# 💾 Guardando en: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/model_weights/eval_1/fold_5
# Epoch 1 (100.00%) | Train Loss: 0.0672 | Val Loss: 0.0590
# | Epoch Time: 5m 15.7s
# ✅ Mejor modelo guardado | Val Loss: 0.0590
# Epoch 2 (100.00%) | Train Loss: 0.0497 | Val Loss: 0.0561
# | Epoch Time: 5m 16.0s
# ✅ Mejor modelo guardado | Val Loss: 0.0561
# Epoch 3 (100.00%) | Train Loss: 0.0463 | Val Loss: 0.0499
# | Epoch Time: 5m 16.2s
# ✅ Mejor modelo guardado | Val Loss: 0.0499
# Epoch 4 (100.00%) | Train Loss: 0.0432 | Val Loss: 0.0517
# | Epoch Time: 5m 17.0s
# Epoch 5 (100.00%) | Train Loss: 0.0405 | Val Loss: 0.0543
# | Epoch Time: 5m 18.3s
# ✅ Entrenamiento completado para Eval 1 - Fold 5
# 📊 Mejor Val Loss: 0.0499
# 💾 Pesos guardados en: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/model_weights/eval_1/fold_5
# 🧹 Memoria limpiada para siguiente fold
#
# ============================================================
# 🎯 ENTRENANDO EVAL 2 - FOLD 1
# ============================================================
# 📊 Distribución de sujetos:
#    Train: 108 sujetos
#    Val: 36 sujetos
#    Test: 36 sujetos
# 📊 Calculando grupos de mediana para balanceado...
#    ✅ Mediana de positivos: 126.0
#    📊 Above median: 4460 muestras
#    📊 Below median: 4514 muestras
# 📊 H5Dataset creado:
#    Total muestras en H5: 14940
#    Muestras válidas: 8974
#    Longitud señal: 4000
#    Longitud labels: 4000
# 📊 Calculando grupos de mediana para balanceado...
#    ✅ Mediana de positivos: 124.0
#    📊 Above median: 1474 muestras
#    📊 Below median: 1500 muestras
# 📊 H5Dataset creado:
#    Total muestras en H5: 14940
#    Muestras válidas: 2974
#    Longitud señal: 4000
#    Longitud labels: 4000
#
# 📊 BALANCEO ABOVE/BELOW MEDIAN:
#    Above median: 4460 IDs
#    Below median: 4514 IDs
#    ✅ Duplicados 54 IDs del grupo above_median
#    📊 RESULTADO: Above=4514, Below=4514
# 📦 Datos cargados:
#    Train samples: 8974
#    Val samples: 2974
#    Train batches: 283
#    Val batches: 93
# 🖥️  Device: cuda
# [(64, 1), (32, 2), (16, 4), (16, 8)]
# [(128, 1), (64, 2), (32, 4), (32, 8)]
# 🧠 Parámetros del modelo: 2,917,189
# 💾 Guardando en: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/model_weights/eval_2/fold_1
# Epoch 1 (100.00%) | Train Loss: 0.0675 | Val Loss: 0.0656
# | Epoch Time: 5m 16.6s
# ✅ Mejor modelo guardado | Val Loss: 0.0656
# Epoch 2 (100.00%) | Train Loss: 0.0500 | Val Loss: 0.0611
# | Epoch Time: 5m 23.6s
# ✅ Mejor modelo guardado | Val Loss: 0.0611
# Epoch 3 (100.00%) | Train Loss: 0.0459 | Val Loss: 0.0768
# | Epoch Time: 5m 16.6s
# Epoch 4 (100.00%) | Train Loss: 0.0433 | Val Loss: 0.0524
# | Epoch Time: 5m 17.3s
# ✅ Mejor modelo guardado | Val Loss: 0.0524
# Epoch 5 (100.00%) | Train Loss: 0.0405 | Val Loss: 0.0572
# | Epoch Time: 5m 16.4s
# ✅ Entrenamiento completado para Eval 2 - Fold 1
# 📊 Mejor Val Loss: 0.0524
# 💾 Pesos guardados en: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/model_weights/eval_2/fold_1
# 🧹 Memoria limpiada para siguiente fold
#
# ============================================================
# 🎯 ENTRENANDO EVAL 2 - FOLD 2
# ============================================================
# 📊 Distribución de sujetos:
#    Train: 108 sujetos
#    Val: 36 sujetos
#    Test: 36 sujetos
# 📊 Calculando grupos de mediana para balanceado...
#    ✅ Mediana de positivos: 124.0
#    📊 Above median: 4439 muestras
#    📊 Below median: 4518 muestras
# 📊 H5Dataset creado:
#    Total muestras en H5: 14940
#    Muestras válidas: 8957
#    Longitud señal: 4000
#    Longitud labels: 4000
# 📊 Calculando grupos de mediana para balanceado...
#    ✅ Mediana de positivos: 128.0
#    📊 Above median: 1490 muestras
#    📊 Below median: 1502 muestras
# 📊 H5Dataset creado:
#    Total muestras en H5: 14940
#    Muestras válidas: 2992
#    Longitud señal: 4000
#    Longitud labels: 4000
#
# 📊 BALANCEO ABOVE/BELOW MEDIAN:
#    Above median: 4439 IDs
#    Below median: 4518 IDs
#    ✅ Duplicados 79 IDs del grupo above_median
#    📊 RESULTADO: Above=4518, Below=4518
# 📦 Datos cargados:
#    Train samples: 8957
#    Val samples: 2992
#    Train batches: 283
#    Val batches: 94
# 🖥️  Device: cuda
# [(64, 1), (32, 2), (16, 4), (16, 8)]
# [(128, 1), (64, 2), (32, 4), (32, 8)]
# 🧠 Parámetros del modelo: 2,917,189
# 💾 Guardando en: /content/drive/MyDrive/docs phd/2025-2/Redes neuronales/Proyecto/código_eeg_redes/código_eeg_redes/model_weights/eval_2/fold_2
# Epoch 1 (100.00%) | Train Loss: 0.0694 | Val Loss: 0.0533
# | Epoch Time: 5m 15.8s
# ✅ Mejor modelo guardado | Val Loss: 0.0533
# Epoch 2 (100.00%) | Train Loss: 0.0510

# %% [markdown]
# # Inference

# %%
import torch
import torch.nn as nn
import numpy as np
import h5py
import json
from pathlib import Path
import gc
from torch.utils.data import Dataset

# ===================================================================
# CONFIGURACIÓN DEL MODELO (misma que en entrenamiento)
# ===================================================================



EMBED_DIM = 64
EMBED_BLOCKS = 1
FILTER_IN = 64
BLOCK_DILATATION = 2
RESOL_FACTOR = 8
BATCH_SIZE = 32
NUM_WORKERS = 12

EMBEDDING_CONFIG_SEED = {
    "embed_dim": EMBED_DIM,
    "block_depth": 2,
    "blocks": EMBED_BLOCKS,
    "dropout": 0.0,
    "filters_in": FILTER_IN,
    "block_dilatation": BLOCK_DILATATION,
}

CLASSIFIER_CONFIG = {
    "embed_dim": 256,
    "hide_dim": 128,
}

# Paths
h5_file_path = "/content/drive/MyDrive/codigo_eeg_redes/data/moda_augmented_s5.h5"
folds_json_path = "/content/drive/MyDrive/codigo_eeg_redes/data/moda_folds.json"
weights_save_dir = "/content/drive/MyDrive/codigo_eeg_redes/model_weights_best_original"  # o model_weights

print("🔍 CONFIGURACIÓN DE INFERENCIA:")
print(f"   📁 Dataset: {h5_file_path}")
print(f"   📁 Folds: {folds_json_path}")
print(f"   💾 Pesos: {weights_save_dir}")


# ===================================================================
# DATASET H5 PARA INFERENCIA
# ===================================================================

class H5InferenceDataset(Dataset):
    def __init__(self, h5_file_path, subject_ids=None):
        self.h5_file_path = h5_file_path

        with h5py.File(h5_file_path, 'r') as f:
            self.total_samples = len(f['signals'])
            self.signal_length = f['signals'].shape[1]
            self.label_length = f['labels'].shape[1]

            all_subject_ids = [s.decode('utf-8') for s in f['subject_ids'][:]]

            if subject_ids is not None:
                self.valid_indices = []
                for i, subj_id in enumerate(all_subject_ids):
                    if subj_id in subject_ids:
                        self.valid_indices.append(i)
            else:
                self.valid_indices = list(range(self.total_samples))

        print(f"📊 Dataset de inferencia creado:")
        print(f"   Total muestras: {len(self.valid_indices)}")

    def __len__(self):
        return len(self.valid_indices)

    def __getitem__(self, idx):
        real_idx = self.valid_indices[idx]

        with h5py.File(self.h5_file_path, 'r') as f:
            signal = f['signals'][real_idx]
            labels = f['labels'][real_idx]

            signal = signal.astype(np.float32)
            labels = labels.astype(np.float32)

            return real_idx, signal, labels

def create_batch_inference(data_list):
    """Función para crear batches para inferencia"""
    data_list = [data for data in data_list if data is not None]

    if len(data_list) == 0:
        return torch.empty(0, dtype=torch.long), torch.empty(0, 0), torch.empty(0, 0)

    ids, signals, labels = zip(*data_list)

    ids_tensor = torch.LongTensor(np.array(ids))
    signals_tensor = torch.FloatTensor(np.array(signals))
    labels_tensor = torch.FloatTensor(np.array(labels))

    return ids_tensor, signals_tensor, labels_tensor

# ===================================================================
# FUNCIONES DE Post PROCESAMIENTO
# ===================================================================

def process_spindle_simple(det_out, dur_out):
    """Versión simplificada del procesamiento de spindles"""
    new_output = dur_out.copy()

    F_RESAMPLE = 200  # Frecuencia de muestreo
    min_duration = int(F_RESAMPLE * 0.3)  # 0.3 segundos
    max_duration = int(F_RESAMPLE * 5)    # 5 segundos

    # Conectar detecciones cercanas
    i_last_label = 0
    in_event = False

    for i, label in enumerate(dur_out):
        if label == 1 and not in_event:
            if i_last_label != 0 and i - i_last_label < min_duration:
                new_output[i_last_label: i] = np.ones(i - i_last_label)
            in_event = True
        elif label == 0 and in_event:
            i_last_label = i
            in_event = False

    # Eliminar eventos muy cortos o largos
    i_start_label = 0
    in_event = False

    for i, label in enumerate(new_output):
        if label == 1 and not in_event:
            i_start_label = i
            in_event = True
        elif (label == 0 or i + 1 == len(new_output)) and in_event:
            if i - i_start_label < min_duration:
                new_output[i_start_label: i] = np.zeros(i - i_start_label)
            elif i - i_start_label > max_duration:
                p0 = (i - i_start_label - max_duration) // 2 + i_start_label
                pf = p0 + max_duration
                new_output[i_start_label: p0] = np.zeros(p0 - i_start_label)
                new_output[pf: i] = np.zeros(i - pf)
            in_event = False

    return new_output

def get_results_simple(labels, output):

    label_stamps = []
    predict_stamps = []

    in_predict_event = 0
    in_label_event = 0

    for i, (label, predict) in enumerate(zip(labels, output)):
        # Eventos reales
        if not in_label_event and label == 1:
            in_label_event = i
        elif in_label_event and (label == 0 or i + 1 == len(labels)):
            label_stamps.append((in_label_event, i))
            in_label_event = 0
            if (not in_predict_event and len(predict_stamps) < len(label_stamps)) or len(predict_stamps) + 1 < len(label_stamps):
                predict_stamps.append(0)

        # Eventos predichos
        if not in_predict_event and predict == 1:
            in_predict_event = i
        elif in_predict_event and (predict == 0 or i + 1 == len(output)):
            predict_stamps.append((in_predict_event, i))
            in_predict_event = 0
            if (not in_label_event and len(label_stamps) < len(predict_stamps)) or len(label_stamps) + 1 < len(predict_stamps):
                label_stamps.append(0)

    result = []
    # Calcular IoUs
    for label, predict in zip(label_stamps, predict_stamps):
        if not label and predict:  # Falso positivo
            result.append(-1)
        elif not predict and label:  # Falso negativo
            result.append(0)
        else:  # IoU
            inter = min(label[1], predict[1]) - max(label[0], predict[0])
            union = max(label[1], predict[1]) - min(label[0], predict[0])
            result.append(inter / union)

    return result

def calculate_metrics_simple(results, thresholds, threshold=0.2):
    """Versión simplificada de calculate_metrics"""
    true_positives = np.zeros_like(thresholds, dtype=float)
    false_positives = np.zeros_like(thresholds, dtype=float)
    false_negatives = np.zeros_like(thresholds, dtype=float)

    threshold_index = np.argmin(np.abs(thresholds - threshold))

    for i, t in enumerate(thresholds):
        for IoU in results:
            if IoU == -1:
                false_positives[i] += 1
            elif IoU == 0:
                false_negatives[i] += 1
            elif IoU >= t:
                true_positives[i] += 1
            else:
                false_negatives[i] += 1

    with np.errstate(divide='ignore', invalid='ignore'):
        precision = np.divide(true_positives, (true_positives + false_positives))
        recall = np.divide(true_positives, (true_positives + false_negatives))

        precision = np.nan_to_num(precision, nan=0.0)
        recall = np.nan_to_num(recall, nan=0.0)

        f1_score = np.divide(2 * precision * recall, (precision + recall),
                           out=np.zeros_like(recall), where=(precision + recall) != 0)

    return threshold_index, precision, recall, f1_score
# ===================================================================
# FUNCIÓN PRINCIPAL DE INFERENCIA
# ===================================================================

def run_inference_for_fold(eval_num, fold_num, test_subjects, model_weights_dir):
    """Ejecuta inferencia para un fold específico SIN DataLoader"""

    print(f"\n🔍 INFERENCIA EVAL {eval_num} - FOLD {fold_num}")
    print(f"   Test subjects: {test_subjects}")

    # Limpiar memoria
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    gc.collect()

    # Crear dataset de test (SIN DataLoader)
    test_dataset = H5InferenceDataset(h5_file_path, subject_ids=test_subjects)

    # Cargar modelo
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = SEED_Model().to(device)

    # Cargar pesos

    weights_folder = Path(model_weights_dir) / f"eval_{eval_num}" / f"fold_{fold_num}"

    try:
        model.embedding.load_state_dict(torch.load(weights_folder / "embedding_best.pth", map_location=device), strict=False) # Stric=False para no cargar pesos innecesarios de los embeddings originales
        model.transformer.load_state_dict(torch.load(weights_folder / "lstm_best.pth", map_location=device))
        model.classifier.load_state_dict(torch.load(weights_folder / "classifier_best.pth", map_location=device))
        print(f"   ✅ Pesos cargados desde: {weights_folder}")
    except Exception as e:
        print(f"   ❌ Error cargando pesos: {e}")
        return []

    # Modo evaluación
    model.eval()

    all_results = []
    total_signals = len(test_dataset)

    # ✅ ITERAR DIRECTAMENTE SOBRE EL DATASET
    with torch.no_grad():
        for s, (_, comp_signal, comp_labels) in enumerate(test_dataset):

            print(f"   Procesando señal {s+1}/{total_signals}")

            # Procesar señal completa
            comp_output = process_full_signal(model, comp_signal, device) #LOGITS

            # Aplicar thresholds
            det_out = np.where(comp_output >= 0.5, np.ones_like(comp_output), np.zeros_like(comp_output))
            dur_out = np.where(comp_output >= 0.425, np.ones_like(comp_output), np.zeros_like(comp_output))

            # Procesar detecciones
            processed_out = process_spindle_simple(det_out, dur_out)

            # Calcular IoUs
            sample_results = get_results_simple(comp_labels.astype(int), processed_out)
            all_results.extend(sample_results)

    print(f"\n   📊 Total resultados: {len(all_results)}")

    # Limpiar memoria
    del model
    del test_dataset

    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    gc.collect()

    return all_results

def process_full_signal(model, comp_signal, device):
    """Procesa una señal completa usando segmentos (como en detections_2.py)"""

    F_RESAMPLE = 200
    SIGNAL_WINDOW = 20  # 20 segundos
    INFERENCE_STRIDE = 10  # 10 segundos

    # Cantidad de segmentos
    segments = int(len(comp_signal) / F_RESAMPLE - SIGNAL_WINDOW) // INFERENCE_STRIDE + 1

    for i in range(segments):
        p0 = INFERENCE_STRIDE * F_RESAMPLE * i
        pf = p0 + SIGNAL_WINDOW * F_RESAMPLE  # 20 segundos desde la pos inicial

        # Obtener output del segmento
        signal_segment = torch.FloatTensor(comp_signal[p0:pf]).unsqueeze(0).to(device)
        output = model(signal_segment)
        output = torch.sigmoid(output).squeeze().cpu().numpy()

        # Concatenar 10 segundos centrales del output
        p1 = F_RESAMPLE * (SIGNAL_WINDOW - INFERENCE_STRIDE) // 2
        p2 = p1 + F_RESAMPLE * INFERENCE_STRIDE

        if i == 0:
            comp_output = output[:p2]
        elif i + 1 == segments:
            comp_output = np.concatenate((comp_output, output[p1:]), axis=0)
        else:
            comp_output = np.concatenate((comp_output, output[p1:p2]), axis=0)

    # Analizar si queda resto de señal
    rest = (len(comp_signal) / F_RESAMPLE - SIGNAL_WINDOW) % INFERENCE_STRIDE
    if rest != 0:
        p0 = len(comp_signal) - SIGNAL_WINDOW * F_RESAMPLE
        signal_segment = torch.FloatTensor(comp_signal[p0:]).unsqueeze(0).to(device)
        output = model(signal_segment)
        output = torch.sigmoid(output).squeeze().cpu().numpy()
        comp_output = np.concatenate((comp_output, output[-int(rest * F_RESAMPLE):]), axis=0)

    return comp_output

def main_inference():
    """Función principal que ejecuta toda la inferencia SIN DataLoader"""

    print("🚀 INICIANDO INFERENCIA COMPLETA")
    print("="*60)

    # Cargar configuración de folds
    with open(folds_json_path, 'r') as f:
        folds_data = json.load(f)

    all_fold_results = []
    evaluations = [1, 2, 3]
    folds = [1, 2, 3, 4, 5]

    total_folds = len(evaluations) * len(folds)
    current_fold = 0

    # Iterar sobre todas las evaluaciones y folds
    for eval_num in evaluations:
        for fold_num in folds:
            current_fold += 1

            eval_key = f"eval_{eval_num}"
            fold_key = f"fold_{fold_num}"

            test_subjects = folds_data[eval_key][fold_key]['test']

            print(f"\n{'='*60}")
            print(f"🎯 PROCESANDO {current_fold}/{total_folds}: EVAL {eval_num} - FOLD {fold_num}")
            print(f"{'='*60}")

            # Ejecutar inferencia para este fold
            fold_results = run_inference_for_fold(eval_num, fold_num, test_subjects, weights_save_dir)

            if fold_results:
                all_fold_results.extend(fold_results)
                print(f"✅ Fold completado - Resultados agregados: {len(fold_results)}")
            else:
                print(f"❌ Error en fold {eval_num}-{fold_num}")

    # Calcular métricas finales (microaverage)
    print(f"\n{'='*60}")
    print("📊 CALCULANDO MÉTRICAS FINALES")
    print(f"{'='*60}")

    if all_fold_results:
        thresholds = np.linspace(0, 1, 100)
        index, precision, recall, f1_score = calculate_metrics_simple(all_fold_results, thresholds)

        final_metrics = {
            'total_results': len(all_fold_results),
            'f1_score': float(f1_score[index] * 100),
            'precision': float(precision[index] * 100),
            'recall': float(recall[index] * 100),
            'threshold_iou': 0.2,
            'evaluations': evaluations,
            'folds': folds,
            'microaverage': True
        }

        print(f"📊 RESULTADOS FINALES (Microaverage):")
        print(f"   Total resultados: {final_metrics['total_results']}")
        print(f"   F1-Score: {final_metrics['f1_score']:.3f}%")
        print(f"   Precision: {final_metrics['precision']:.3f}%")
        print(f"   Recall: {final_metrics['recall']:.3f}%")

        # Guardar resultados
        output_file = "inference_results_moda_microaverage.json"
        with open(output_file, 'w') as f:
            json.dump(final_metrics, f, indent=4)

        print(f"\n💾 Resultados guardados en: {output_file}")

    else:
        print("❌ No se obtuvieron resultados de ningún fold")

# Ejecutar inferencia
if __name__ == "__main__":
    main_inference()
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#    Procesando señal 993/2992
#    Procesando señal 994/2992
#    Procesando señal 995/2992
#    Procesando señal 996/2992
#    Procesando señal 997/2992
#    Procesando señal 998/2992
#    Procesando señal 999/2992
#    Procesando señal 1000/2992
#    Procesando señal 1001/2992
#    Procesando señal 1002/2992
#    Procesando señal 1003/2992
#    Procesando señal 1004/2992
#    Procesando señal 1005/2992
#    Procesando señal 1006/2992
#    Procesando señal 1007/2992
#    Procesando señal 1008/2992
#    Procesando señal 1009/2992
#    Procesando señal 1010/2992
#    Procesando señal 1011/2992
#    Procesando señal 1012/2992
#    Procesando señal 1013/2992
#    Procesando señal 1014/2992
#    Procesando señal 1015/2992
#    Procesando señal 1016/2992
#    Procesando señal 1017/2992
#    Procesando señal 1018/2992
#    Procesando señal 1019/2992
#    Procesando señal 1020/2992
#    Procesando señal 1021/2992
#    Procesando señal 1022/2992
#    Procesando señal 1023/2992
#    Procesando señal 1024/2992
#    Procesando señal 1025/2992
#    Procesando señal 1026/2992
#    Procesando señal 1027/2992
#    Procesando señal 1028/2992
#    Procesando señal 1029/2992
#    Procesando señal 1030/2992
#    Procesando señal 1031/2992
#    Procesando señal 1032/2992
#    Procesando señal 1033/2992
#    Procesando señal 1034/2992
#    Procesando señal 1035/2992
#    Procesando señal 1036/2992
#    Procesando señal 1037/2992
#    Procesando señal 1038/2992
#    Procesando señal 1039/2992
#    Procesando señal 1040/2992
#    Procesando señal 1041/2992
#    Procesando señal 1042/2992
#    Procesando señal 1043/2992
#    Procesando señal 1044/2992
#    Procesando señal 1045/2992
#    Procesando señal 1046/2992
#    Procesando señal 1047/2992
#    Procesando señal 1048/2992
#    Procesando señal 1049/2992
#    Procesando señal 1050/2992
#    Procesando señal 1051/2992
#    Procesando señal 1052/2992
#    Procesando señal 1053/2992
#    Procesando señal 1054/2992
#    Procesando señal 1055/2992
#    Procesando señal 1056/2992
#    Procesando señal 1057/2992
#    Procesando señal 1058/2992
#    Procesando señal 1059/2992
#    Procesando señal 1060/2992
#    Procesando señal 1061/2992
#    Procesando señal 1062/2992
#    Procesando señal 1063/2992
#    Procesando señal 1064/2992
#    Procesando señal 1065/2992
#    Procesando señal 1066/2992
#    Procesando señal 1067/2992
#    Procesando señal 1068/2992
#    Procesando señal 1069/2992
#    Procesando señal 1070/2992
#    Procesando señal 1071/2992
#    Procesando señal 1072/2992
#    Procesando señal 1073/2992
#    Procesando señal 1074/2992
#    Procesando señal 1075/2992
#    Procesando señal 1076/2992
#    Procesando señal 1077/2992
#    Procesando señal 1078/2992
#    Procesando señal 1079/2992
#    Procesando señal 1080/2992
#    Procesando señal 1081/2992
#    Procesando señal 1082/2992
#    Procesando señal 1083/2992
#    Procesando señal 1084/2992
#    Procesando señal 1085/2992
#    Procesando señal 1086/2992
#    Procesando señal 1087/2992
#    Procesando señal 1088/2992
#    Procesando señal 1089/2992
#    Procesando señal 1090/2992
#    Procesando señal 1091/2992
#    Procesando señal 1092/2992
#    Procesando señal 1093/2992
#    Procesando señal 1094/2992
#    Procesando señal 1095/2992
#    Procesando señal 1096/2992
#    Procesando señal 1097/2992
#    Procesando señal 1098/2992
#    Procesando señal 1099/2992
#    Procesando señal 1100/2992
#    Procesando señal 1101/2992
#    Procesando señal 1102/2992
#    Procesando señal 1103/2992
#    Procesando señal 1104/2992
#    Procesando señal 1105/2992
#    Procesando señal 1106/2992
#    Procesando señal 1107/2992
#    Procesando señal 1108/2992
#    Procesando señal 1109/2992
#    Procesando señal 1110/2992
#    Procesando señal 1111/2992
#    Procesando señal 1112/2992
#    Procesando señal 1113/2992
#    Procesando señal 1114/2992
#    Procesando señal 1115/2992
#    Procesando señal 1116/2992
#    Procesando señal 1117/2992
#    Procesando señal 1118/2992
#    Procesando señal 1119/2992
#    Procesando señal 1120/2992
#    Procesando señal 1121/2992
#    Procesando señal 1122/2992
#    Procesando señal 1123/2992
#    Procesando señal 1124/2992
#    Procesando señal 1125/2992
#    Procesando señal 1126/2992
#    Procesando señal 1127/2992
#    Procesando señal 1128/2992
#    Procesando señal 1129/2992
#    Procesando señal 1130/2992
#    Procesando señal 1131/2992
#    Procesando señal 1132/2992
#    Procesando señal 1133/2992
#    Procesando señal 1134/2992
#    Procesando señal 1135/2992
#    Procesando señal 1136/2992
#    Procesando señal 1137/2992
#    Procesando señal 1138/2992
#    Procesando señal 1139/2992
#    Procesando señal 1140/2992
#    Procesando señal 1141/2992
#    Procesando señal 1142/2992
#    Procesando señal 1143/2992
#    Procesando señal 1144/2992
#    Procesando señal 1145/2992
#    Procesando señal 1146/2992
#    Procesando señal 1147/2992
#    Procesando señal 1148/2992
#    Procesando señal 1149/2992
#    Procesando señal 1150/2992
#    Procesando señal 1151/2992
#    Procesando señal 1152/2992
#    Procesando señal 1153/2992
#    Procesando señal 1154/2992
#    Procesando señal 1155/2992
#    Procesando señal 1156/2992
#    Procesando señal 1157/2992
#    Procesando señal 1158/2992
#    Procesando señal 1159/2992
#    Procesando señal 1160/2992
#    Procesando señal 1161/2992
#    Procesando señal 1162/2992
#    Procesando señal 1163/2992
#    Procesando señal 1164/2992
#    Procesando señal 1165/2992
#    Procesando señal 1166/2992
#    Procesando señal 1167/2992
#    Procesando señal 1168/2992
#    Procesando señal 1169/2992
#    Procesando señal 1170/2992
#    Procesando señal 1171/2992
#    Procesando señal 1172/2992
#    Procesando señal 1173/2992
#    Procesando señal 1174/2992
#    Procesando señal 1175/2992
#    Procesando señal 1176/2992
#    Procesando señal 1177/2992
#    Procesando señal 1178/2992
#    Procesando señal 1179/2992
#    Procesando señal 1180/2992
#    Procesando señal 1181/2992
#    Procesando señal 1182/2992
#    Procesando señal 1183/2992
#    Procesando señal 1184/2992
#    Procesando señal 1185/2992
#    Procesando señal 1186/2992
#    Procesando señal 1187/2992
#    Procesando señal 1188/2992
#    Procesando señal 1189/2992
#    Procesando señal 1190/2992
#    Procesando señal 1191/2992
#    Procesando señal 1192/2992
#    Procesando señal 1193/2992
#    Procesando señal 1194/2992
#    Procesando señal 1195/2992
#    Procesando señal 1196/2992
#    Procesando señal 1197/2992
#    Procesando señal 1198/2992
#    Procesando señal 1199/2992
#    Procesando señal 1200/2992
#    Procesando señal 1201/2992
#    Procesando señal 1202/2992
#    Procesando señal 1203/2992
#    Procesando señal 1204/2992
#    Procesando señal 1205/2992
#    Procesando señal 1206/2992
#    Procesando señal 1207/2992
#    Procesando señal 1208/2992
#    Procesando señal 1209/2992
#    Procesando señal 1210/2992
#    Procesando señal 1211/2992
#    Procesando señal 1212/2992
#    Procesando señal 1213/2992
#    Procesando señal 1214/2992
#    Procesando señal 1215/2992
#    Procesando señal 1216/2992
#    Procesando señal 1217/2992
#    Procesando señal 1218/2992
#    Procesando señal 1219/2992
#    Procesando señal 1220/2992
#    Procesando señal 1221/2992
#    Procesando señal 1222/2992
#    Procesando señal 1223/2992
#    Procesando señal 1224/2992
#    Procesando señal 1225/2992
#    Procesando señal 1226/2992
#    Procesando señal 1227/2992
#    Procesando señal 1228/2992
#    Procesando señal 1229/2992
#    Procesando señal 1230/2992
#    Procesando señal 1231/2992
#    Procesando señal 1232/2992
#    Procesando señal 1233/2992
#    Procesando señal 1234/2992
#    Procesando señal 1235/2992
#    Procesando señal 1236/2992
#    Procesando señal 1237/2992
#    Procesando señal 1238/2992
#    Procesando señal 1239/2992
#    Procesando señal 1240/2992
#    Procesando señal 1241/2992
#    Procesando señal 1242/2992
#    Procesando señal 1243/2992
#    Procesando señal 1244/2992
#    Procesando señal 1245/2992
#    Procesando señal 1246/2992
#    Procesando señal 1247/2992
#    Procesando señal 1248/2992
#    Procesando señal 1249/2992
#    Procesando señal 1250/2992
#    Procesando señal 1251/2992
#    Procesando señal 1252/2992
#    Procesando señal 1253/2992
#    Procesando señal 1254/2992
#    Procesando señal 1255/2992
#    Procesando señal 1256/2992
#    Procesando señal 1257/2992
#    Procesando señal 1258/2992
#    Procesando señal 1259/2992
#    Procesando señal 1260/2992
#    Procesando señal 1261/2992
#    Procesando señal 1262/2992
#    Procesando señal 1263/2992
#    Procesando señal 1264/2992
#    Procesando señal 1265/2992
#    Procesando señal 1266/2992
#    Procesando señal 1267/2992
#    Procesando señal 1268/2992
#    Procesando señal 1269/2992
#    Procesando señal 1270/2992
#    Procesando señal 1271/2992
#    Procesando señal 1272/2992
#    Procesando señal 1273/2992
#    Procesando señal 1274/2992
#    Procesando señal 1275/2992
#    Procesando señal 1276/2992
#    Procesando señal 1277/2992
#    Procesando señal 1278/2992
#    Procesando señal 1279/2992
#    Procesando señal 1280/2992
#    Procesando señal 1281/2992
#    Procesando señal 1282/2992
#    Procesando señal 1283/2992
#    Procesando señal 1284/2992
#    Procesando señal 1285/2992
#    Procesando señal 1286/2992
#    Procesando señal 1287/2992
#    Procesando señal 1288/2992
#    Procesando señal 1289/2992
#    Procesando señal 1290/2992
#    Procesando señal 1291/2992
#    Procesando señal 1292/2992
#    Procesando señal 1293/2992
#    Procesando señal 1294/2992
#    Procesando señal 1295/2992
#    Procesando señal 1296/2992
#    Procesando señal 1297/2992
#    Procesando señal 1298/2992
#    Procesando señal 1299/2992
#    Procesando señal 1300/2992
#    Procesando señal 1301/2992
#    Procesando señal 1302/2992
#    Procesando señal 1303/2992
#    Procesando señal 1304/2992
#    Procesando señal 1305/2992
#    Procesando señal 1306/2992
#    Procesando señal 1307/2992
#    Procesando señal 1308/2992
#    Procesando señal 1309/2992
#    Procesando señal 1310/2992
#    Procesando señal 1311/2992
#    Procesando señal 1312/2992
#    Procesando señal 1313/2992
#    Procesando señal 1314/2992
#    Procesando señal 1315/2992
#    Procesando señal 1316/2992
#    Procesando señal 1317/2992
#    Procesando señal 1318/2992
#    Procesando señal 1319/2992
#    Procesando señal 1320/2992
#    Procesando señal 1321/2992
#    Procesando señal 1322/2992
#    Procesando señal 1323/2992
#    Procesando señal 1324/2992
#    Procesando señal 1325/2992
#    Procesando señal 1326/2992
#    Procesando señal 1327/2992
#    Procesando señal 1328/2992
#    Procesando señal 1329/2992
#    Procesando señal 1330/2992
#    Procesando señal 1331/2992
#    Procesando señal 1332/2992
#    Procesando señal 1333/2992
#    Procesando señal 1334/2992
#    Procesando señal 1335/2992
#    Procesando señal 1336/2992
#    Procesando señal 1337/2992
#    Procesando señal 1338/2992
#    Procesando señal 1339/2992
#    Procesando señal 1340/2992
#    Procesando señal 1341/2992
#    Procesando señal 1342/2992
#    Procesando señal 1343/2992
#    Procesando señal 1344/2992
#    Procesando señal 1345/2992
#    Procesando señal 1346/2992
#    Procesando señal 1347/2992
#    Procesando señal 1348/2992
#    Procesando señal 1349/2992
#    Procesando señal 1350/2992
#    Procesando señal 1351/2992
#    Procesando señal 1352/2992
#    Procesando señal 1353/2992
#    Procesando señal 1354/2992
#    Procesando señal 1355/2992
#    Procesando señal 1356/2992
#    Procesando señal 1357/2992
#    Procesando señal 1358/2992
#    Procesando señal 1359/2992
#    Procesando señal 1360/2992
#    Procesando señal 1361/2992
#    Procesando señal 1362/2992
#    Procesando señal 1363/2992
#    Procesando señal 1364/2992
#    Procesando señal 1365/2992
#    Procesando señal 1366/2992
#    Procesando señal 1367/2992
#    Procesando señal 1368/2992
#    Procesando señal 1369/2992
#    Procesando señal 1370/2992
#    Procesando señal 1371/2992
#    Procesando señal 1372/2992
#    Procesando señal 1373/2992
#    Procesando señal 1374/2992
#    Procesando señal 1375/2992
#    Procesando señal 1376/2992
#    Procesando señal 1377/2992
#    Procesando señal 1378/2992
#    Procesando señal 1379/2992
#    Procesando señal 1380/2992
#    Procesando señal 1381/2992
#    Procesando señal 1382/2992
#    Procesando señal 1383/2992
#    Procesando señal 1384/2992
#    Procesando señal 1385/2992
#    Procesando señal 1386/2992
#    Procesando señal 1387/2992
#    Procesando señal 1388/2992
#    Procesando señal 1389/2992
#    Procesando señal 1390/2992
#    Procesando señal 1391/2992
#    Procesando señal 1392/2992
#    Procesando señal 1393/2992
#    Procesando señal 1394/2992
#    Procesando señal 1395/2992
#    Procesando señal 1396/2992
#    Procesando señal 1397/2992
#    Procesando señal 1398/2992
#    Procesando señal 1399/2992
#    Procesando señal 1400/2992
#    Procesando señal 1401/2992
#    Procesando señal 1402/2992
#    Procesando señal 1403/2992
#    Procesando señal 1404/2992
#    Procesando señal 1405/2992
#    Procesando señal 1406/2992
#    Procesando señal 1407/2992
#    Procesando señal 1408/2992
#    Procesando señal 1409/2992
#    Procesando señal 1410/2992
#    Procesando señal 1411/2992
#    Procesando señal 1412/2992
#    Procesando señal 1413/2992
#    Procesando señal 1414/2992
#    Procesando señal 1415/2992
#    Procesando señal 1416/2992
#    Procesando señal 1417/2992
#    Procesando señal 1418/2992
#    Procesando señal 1419/2992
#    Procesando señal 1420/2992
#    Procesando señal 1421/2992
#    Procesando señal 1422/2992
#    Procesando señal 1423/2992
#    Procesando señal 1424/2992
#    Procesando señal 1425/2992
#    Procesando señal 1426/2992
#    Procesando señal 1427/2992
#    Procesando señal 1428/2992
#    Procesando señal 1429/2992
#    Procesando señal 1430/2992
#    Procesando señal 1431/2992
#    Procesando señal 1432/2992
#    Procesando señal 1433/2992
#    Procesando señal 1434/2992
#    Procesando señal 1435/2992
#    Procesando señal 1436/2992
#    Procesando señal 1437/2992
#    Procesando señal 1438/2992
#    Procesando señal 1439/2992
#    Procesando señal 1440/2992
#    Procesando señal 1441/2992
#    Procesando señal 1442/2992
#    Procesando señal 1443/2992
#    Procesando señal 1444/2992
#    Procesando señal 1445/2992
#    Procesando señal 1446/2992
#    Procesando señal 1447/2992
#    Procesando señal 1448/2992
#    Procesando señal 1449/2992
#    Procesando señal 1450/2992
#    Procesando señal 1451/2992
#    Procesando señal 1452/2992
#    Procesando señal 1453/2992
#    Procesando señal 1454/2992
#    Procesando señal 1455/2992
#    Procesando señal 1456/2992
#    Procesando señal 1457/2992
#    Procesando señal 1458/2992
#    Procesando señal 1459/2992
#    Procesando señal 1460/2992
#    Procesando señal 1461/2992
#    Procesando señal 1462/2992
#    Procesando señal 1463/2992
#    Procesando señal 1464/2992
#    Procesando señal 1465/2992
#    Procesando señal 1466/2992
#    Procesando señal 1467/2992
#    Procesando señal 1468/2992
#    Procesando señal 1469/2992
#    Procesando señal 1470/2992
#    Procesando señal 1471/2992
#    Procesando señal 1472/2992
#    Procesando señal 1473/2992
#    Procesando señal 1474/2992
#    Procesando señal 1475/2992
#    Procesando señal 1476/2992
#    Procesando señal 1477/2992
#    Procesando señal 1478/2992
#    Procesando señal 1479/2992
#    Procesando señal 1480/2992
#    Procesando señal 1481/2992
#    Procesando señal 1482/2992
#    Procesando señal 1483/2992
#    Procesando señal 1484/2992
#    Procesando señal 1485/2992
#    Procesando señal 1486/2992
#    Procesando señal 1487/2992
#    Procesando señal 1488/2992
#    Procesando señal 1489/2992
#    Procesando señal 1490/2992
#    Procesando señal 1491/2992
#    Procesando señal 1492/2992
#    Procesando señal 1493/2992
#    Procesando señal 1494/2992
#    Procesando señal 1495/2992
#    Procesando señal 1496/2992
#    Procesando señal 1497/2992
#    Procesando señal 1498/2992
#    Procesando señal 1499/2992
#    Procesando señal 1500/2992
#    Procesando señal 1501/2992
#    Procesando señal 1502/2992
#    Procesando señal 1503/2992
#    Procesando señal 1504/2992
#    Procesando señal 1505/2992
#    Procesando señal 1506/2992
#    Procesando señal 1507/2992
#    Procesando señal 1508/2992
#    Procesando señal 1509/2992
#    Procesando señal 1510/2992
#    Procesando señal 1511/2992
#    Procesando señal 1512/2992
#    Procesando señal 1513/2992
#    Procesando señal 1514/2992
#    Procesando señal 1515/2992
#    Procesando señal 1516/2992
#    Procesando señal 1517/2992
#    Procesando señal 1518/2992
#    Procesando señal 1519/2992
#    Procesando señal 1520/2992
#    Procesando señal 1521/2992
#    Procesando señal 1522/2992
#    Procesando señal 1523/2992
#    Procesando señal 1524/2992
#    Procesando señal 1525/2992
#    Procesando señal 1526/2992
#    Procesando señal 1527/2992
#    Procesando señal 1528/2992
#    Procesando señal 1529/2992
#    Procesando señal 1530/2992
#    Procesando señal 1531/2992
#    Procesando señal 1532/2992
#    Procesando señal 1533/2992
#    Procesando señal 1534/2992
#    Procesando señal 1535/2992
#    Procesando señal 1536/2992
#    Procesando señal 1537/2992
#    Procesando señal 1538/2992
#    Procesando señal 1539/2992
#    Procesando señal 1540/2992
#    Procesando señal 1541/2992
#    Procesando señal 1542/2992
#    Procesando señal 1543/2992
#    Procesando señal 1544/2992
#    Procesando señal 1545/2992
#    Procesando señal 1546/2992
#    Procesando señal 1547/2992
#    Procesando señal 1548/2992
#    Procesando señal 1549/2992
#    Procesando señal 1550/2992
#    Procesando señal 1551/2992
#    Procesando señal 1552/2992
#    Procesando señal 1553/2992
#    Procesando señal 1554/2992
#    Procesando señal 1555/2992
#    Procesando señal 1556/2992
#    Procesando señal 1557/2992
#    Procesando señal 1558/2992
#    Procesando señal 1559/2992
#    Procesando señal 1560/2992
#    Procesando señal 1561/2992
#    Procesando señal 1562/2992
#    Procesando señal 1563/2992
#    Procesando señal 1564/2992
#    Procesando señal 1565/2992
#    Procesando señal 1566/2992
#    Procesando señal 1567/2992
#    Procesando señal 1568/2992
#    Procesando señal 1569/2992
#    Procesando señal 1570/2992
#    Procesando señal 1571/2992
#    Procesando señal 1572/2992
#    Procesando señal 1573/2992
#    Procesando señal 1574/2992
#    Procesando señal 1575/2992
#    Procesando señal 1576/2992
#    Procesando señal 1577/2992
#    Procesando señal 1578/2992
#    Procesando señal 1579/2992
#    Procesando señal 1580/2992
#    Procesando señal 1581/2992
#    Procesando señal 1582/2992
#    Procesando señal 1583/2992
#    Procesando señal 1584/2992
#    Procesando señal 1585/2992
#    Procesando señal 1586/2992
#    Procesando señal 1587/2992
#    Procesando señal 1588/2992
#    Procesando señal 1589/2992
#    Procesando señal 1590/2992
#    Procesando señal 1591/2992
#    Procesando señal 1592/2992
#    Procesando señal 1593/2992
#    Procesando señal 1594/2992
#    Procesando señal 1595/2992
#    Procesando señal 1596/2992
#    Procesando señal 1597/2992
#    Procesando señal 1598/2992
#    Procesando señal 1599/2992
#    Procesando señal 1600/2992
#    Procesando señal 1601/2992
#    Procesando señal 1602/2992
#    Procesando señal 1603/2992
#    Procesando señal 1604/2992
#    Procesando señal 1605/2992
#    Procesando señal 1606/2992
#    Procesando señal 1607/2992
#    Procesando señal 1608/2992
#    Procesando señal 1609/2992
#    Procesando señal 1610/2992
#    Procesando señal 1611/2992
#    Procesando señal 1612/2992
#    Procesando señal 1613/2992
#    Procesando señal 1614/2992
#    Procesando señal 1615/2992
#    Procesando señal 1616/2992
#    Procesando señal 1617/2992
#    Procesando señal 1618/2992
#    Procesando señal 1619/2992
#    Procesando señal 1620/2992
#    Procesando señal 1621/2992
#    Procesando señal 1622/2992
#    Procesando señal 1623/2992
#    Procesando señal 1624/2992
#    Procesando señal 1625/2992
#    Procesando señal 1626/2992
#    Procesando señal 1627/2992
#    Procesando señal 1628/2992
#    Procesando señal 1629/2992
#    Procesando señal 1630/2992
#    Procesando señal 1631/2992
#    Procesando señal 1632/2992
#    Procesando señal 1633/2992
#    Procesando señal 1634/2992
#    Procesando señal 1635/2992
#    Procesando señal 1636/2992
#    Procesando señal 1637/2992
#    Procesando señal 1638/2992
#    Procesando señal 1639/2992
#    Procesando señal 1640/2992
#    Procesando señal 1641/2992
#    Procesando señal 1642/2992
#    Procesando señal 1643/2992
#    Procesando señal 1644/2992
#    Procesando señal 1645/2992
#    Procesando señal 1646/2992
#    Procesando señal 1647/2992
#    Procesando señal 1648/2992
#    Procesando señal 1649/2992
#    Procesando señal 1650/2992
#    Procesando señal 1651/2992
#    Procesando señal 1652/2992
#    Procesando señal 1653/2992
#    Procesando señal 1654/2992
#    Procesando señal 1655/2992
#    Procesando señal 1656/2992
#    Procesando señal 1657/2992
#    Procesando señal 1658/2992
#    Procesando señal 1659/2992
#    Procesando señal 1660/2992
#    Procesando señal 1661/2992
#    Procesando señal 1662/2992
#    Procesando señal 1663/2992
#    Procesando señal 1664/2992
#    Procesando señal 1665/2992
#    Procesando señal 1666/2992
#    Procesando señal 1667/2992
#    Procesando señal 1668/2992
#    Procesando señal 1669/2992
#    Procesando señal 1670/2992
#    Procesando señal 1671/2992
#    Procesando señal 1672/2992
#    Procesando señal 1673/2992
#    Procesando señal 1674/2992
#    Procesando señal 1675/2992
#    Procesando señal 1676/2992
#    Procesando señal 1677/2992
#    Procesando señal 1678/2992
#    Procesando señal 1679/2992
#    Procesando señal 1680/2992
#    Procesando señal 1681/2992
#    Procesando señal 1682/2992
#    Procesando señal 1683/2992
#    Procesando señal 1684/2992
#    Procesando señal 1685/2992
#    Procesando señal 1686/2992
#    Procesando señal 1687/2992
#    Procesando señal 1688/2992
#    Procesando señal 1689/2992
#    Procesando señal 1690/2992
#    Procesando señal 1691/2992
#    Procesando señal 1692/2992
#    Procesando señal 1693/2992
#    Procesando señal 1694/2992
#    Procesando señal 1695/2992
#    Procesando señal 1696/2992
#    Procesando señal 1697/2992
#    Procesando señal 1698/2992
#    Procesando señal 1699/2992
#    Procesando señal 1700/2992
#    Procesando señal 1701/2992
#    Procesando señal 1702/2992
#    Procesando señal 1703/2992
#    Procesando señal 1704/2992
#    Procesando señal 1705/2992
#    Procesando señal 1706/2992
#    Procesando señal 1707/2992
#    Procesando señal 1708/2992
#    Procesando señal 1709/2992
#    Procesando señal 1710/2992
#    Procesando señal 1711/2992
#    Procesando señal 1712/2992
#    Procesando señal 1713/2992
#    Procesando señal 1714/2992
#    Procesando señal 1715/2992
#    Procesando señal 1716/2992
#    Procesando señal 1717/2992
#    Procesando señal 1718/2992
#    Procesando señal 1719/2992
#    Procesando señal 1720/2992
#    Procesando señal 1721/2992
#    Procesando señal 1722/2992
#    Procesando señal 1723/2992
#    Procesando señal 1724/2992
#    Procesando señal 1725/2992
#    Procesando señal 1726/2992
#    Procesando señal 1727/2992
#    Procesando señal 1728/2992
#    Procesando señal 1729/2992
#    Procesando señal 1730/2992
#    Procesando señal 1731/2992
#    Procesando señal 1732/2992
#    Procesando señal 1733/2992
#    Procesando señal 1734/2992
#    Procesando señal 1735/2992
#    Procesando señal 1736/2992
#    Procesando señal 1737/2992
#    Procesando señal 1738/2992
#    Procesando señal 1739/2992
#    Procesando señal 1740/2992
#    Procesando señal 1741/2992
#    Procesando señal 1742/2992
#    Procesando señal 1743/2992
#    Procesando señal 1744/2992
#    Procesando señal 1745/2992
#    Procesando señal 1746/2992
#    Procesando señal 1747/2992
#    Procesando señal 1748/2992
#    Procesando señal 1749/2992
#    Procesando señal 1750/2992
#    Procesando señal 1751/2992
#    Procesando señal 1752/2992
#    Procesando señal 1753/2992
#    Procesando señal 1754/2992
#    Procesando señal 1755/2992
#    Procesando señal 1756/2992
#    Procesando señal 1757/2992
#    Procesando señal 1758/2992
#    Procesando señal 1759/2992
#    Procesando señal 1760/2992
#    Procesando señal 1761/2992
#    Procesando señal 1762/2992
#    Procesando señal 1763/2992
#    Procesando señal 1764/2992
#    Procesando señal 1765/2992
#    Procesando señal 1766/2992
#    Procesando señal 1767/2992
#    Procesando señal 1768/2992
#    Procesando señal 1769/2992
#    Procesando señal 1770/2992
#    Procesando señal 1771/2992
#    Procesando señal 1772/2992
#    Procesando señal 1773/2992
#    Procesando señal 1774/2992
#    Procesando señal 1775/2992
#    Procesando señal 1776/2992
#    Procesando señal 1777/2992
#    Procesando señal 1778/2992
#    Procesando señal 1779/2992
#    Procesando señal 1780/2992
#    Procesando señal 1781/2992
#    Procesando señal 1782/2992
#    Procesando señal 1783/2992
#    Procesando señal 1784/2992
#    Procesando señal 1785/2992
#    Procesando señal 1786/2992
#    Procesando señal 1787/2992
#    Procesando señal 1788/2992
#    Procesando señal 1789/2992
#    Procesando señal 1790/2992
#    Procesando señal 1791/2992
#    Procesando señal 1792/2992
#    Procesando señal 1793/2992
#    Procesando señal 1794/2992
#    Procesando señal 1795/2992
#    Procesando señal 1796/2992
#    Procesando señal 1797/2992
#    Procesando señal 1798/2992
#    Procesando señal 1799/2992
#    Procesando señal 1800/2992
#    Procesando señal 1801/2992
#    Procesando señal 1802/2992
#    Procesando señal 1803/2992
#    Procesando señal 1804/2992
#    Procesando señal 1805/2992
#    Procesando señal 1806/2992
#    Procesando señal 1807/2992
#    Procesando señal 1808/2992
#    Procesando señal 1809/2992
#    Procesando señal 1810/2992
#    Procesando señal 1811/2992
#    Procesando señal 1812/2992
#    Procesando señal 1813/2992
#    Procesando señal 1814/2992
#    Procesando señal 1815/2992
#    Procesando señal 1816/2992
#    Procesando señal 1817/2992
#    Procesando señal 1818/2992
#    Procesando señal 1819/2992
#    Procesando señal 1820/2992
#    Procesando señal 1821/2992
#    Procesando señal 1822/2992
#    Procesando señal 1823/2992
#    Procesando señal 1824/2992
#    Procesando señal 1825/2992
#    Procesando señal 1826/2992
#    Procesando señal 1827/2992
#    Procesando señal 1828/2992
#    Procesando señal 1829/2992
#    Procesando señal 1830/2992
#    Procesando señal 1831/2992
#    Procesando señal 1832/2992
#    Procesando señal 1833/2992
#    Procesando señal 1834/2992
#    Procesando señal 1835/2992
#    Procesando señal 1836/2992
#    Procesando señal 1837/2992
#    Procesando señal 1838/2992
#    Procesando señal 1839/2992
#    Procesando señal 1840/2992
#    Procesando señal 1841/2992
#    Procesando señal 1842/2992
#    Procesando señal 1843/2992
#    Procesando señal 1844/2992
#    Procesando señal 1845/2992
#    Procesando señal 1846/2992
#    Procesando señal 1847/2992
#    Procesando señal 1848/2992
#    Procesando señal 1849/2992
#    Procesando señal 1850/2992
#    Procesando señal 1851/2992
#    Procesando señal 1852/2992
#    Procesando señal 1853/2992
#    Procesando señal 1854/2992
#    Procesando señal 1855/2992
#    Procesando señal 1856/2992
#    Procesando señal 1857/2992
#    Procesando señal 1858/2992
#    Procesando señal 1859/2992
#    Procesando señal 1860/2992
#    Procesando señal 1861/2992
#    Procesando señal 1862/2992
#    Procesando señal 1863/2992
#    Procesando señal 1864/2992
#    Procesando señal 1865/2992
#    Procesando señal 1866/2992
#    Procesando señal 1867/2992
#    Procesando señal 1868/2992
#    Procesando señal 1869/2992
#    Procesando señal 1870/2992
#    Procesando señal 1871/2992
#    Procesando señal 1872/2992
#    Procesando señal 1873/2992
#    Procesando señal 1874/2992
#    Procesando señal 1875/2992
#    Procesando señal 1876/2992
#    Procesando señal 1877/2992
#    Procesando señal 1878/2992
#    Procesando señal 1879/2992
#    Procesando señal 1880/2992
#    Procesando señal 1881/2992
#    Procesando señal 1882/2992
#    Procesando señal 1883/2992
#    Procesando señal 1884/2992
#    Procesando señal 1885/2992
#    Procesando señal 1886/2992
#    Procesando señal 1887/2992
#    Procesando señal 1888/2992
#    Procesando señal 1889/2992
#    Procesando señal 1890/2992
#    Procesando señal 1891/2992
#    Procesando señal 1892/2992
#    Procesando señal 1893/2992
#    Procesando señal 1894/2992
#    Procesando señal 1895/2992
#    Procesando señal 1896/2992
#    Procesando señal 1897/2992
#    Procesando señal 1898/2992
#    Procesando señal 1899/2992
#    Procesando señal 1900/2992
#    Procesando señal 1901/2992
#    Procesando señal 1902/2992
#    Procesando señal 1903/2992
#    Procesando señal 1904/2992
#    Procesando señal 1905/2992
#    Procesando señal 1906/2992
#    Procesando señal 1907/2992
#    Procesando señal 1908/2992
#    Procesando señal 1909/2992
#    Procesando señal 1910/2992
#    Procesando señal 1911/2992
#    Procesando señal 1912/2992
#    Procesando señal 1913/2992
#    Procesando señal 1914/2992
#    Procesando señal 1915/2992
#    Procesando señal 1916/2992
#    Procesando señal 1917/2992
#    Procesando señal 1918/2992
#    Procesando señal 1919/2992
#    Procesando señal 1920/2992
#    Procesando señal 1921/2992
#    Procesando señal 1922/2992
#    Procesando señal 1923/2992
#    Procesando señal 1924/2992
#    Procesando señal 1925/2992
#    Procesando señal 1926/2992
#    Procesando señal 1927/2992
#    Procesando señal 1928/2992
#    Procesando señal 1929/2992
#    Procesando señal 1930/2992
#    Procesando señal 1931/2992
#    Procesando señal 1932/2992
#    Procesando señal 1933/2992
#    Procesando señal 1934/2992
#    Procesando señal 1935/2992
#    Procesando señal 1936/2992
#    Procesando señal 1937/2992
#    Procesando señal 1938/2992
#    Procesando señal 1939/2992
#    Procesando señal 1940/2992
#    Procesando señal 1941/2992
#    Procesando señal 1942/2992
#    Procesando señal 1943/2992
#    Procesando señal 1944/2992
#    Procesando señal 1945/2992
#    Procesando señal 1946/2992
#    Procesando señal 1947/2992
#    Procesando señal 1948/2992
#    Procesando señal 1949/2992
#    Procesando señal 1950/2992
#    Procesando señal 1951/2992
#    Procesando señal 1952/2992
#    Procesando señal 1953/2992
#    Procesando señal 1954/2992
#    Procesando señal 1955/2992
#    Procesando señal 1956/2992
#    Procesando señal 1957/2992
#    Procesando señal 1958/2992
#    Procesando señal 1959/2992
#    Procesando señal 1960/2992
#    Procesando señal 1961/2992
#    Procesando señal 1962/2992
#    Procesando señal 1963/2992
#    Procesando señal 1964/2992
#    Procesando señal 1965/2992
#    Procesando señal 1966/2992
#    Procesando señal 1967/2992
#    Procesando señal 1968/2992
#    Procesando señal 1969/2992
#    Procesando señal 1970/2992
#    Procesando señal 1971/2992
#    Procesando señal 1972/2992
#    Procesando señal 1973/2992
#    Procesando señal 1974/2992
#    Procesando señal 1975/2992
#    Procesando señal 1976/2992
#    Procesando señal 1977/2992
#    Procesando señal 1978/2992
#    Procesando señal 1979/2992
#    Procesando señal 1980/2992
#    Procesando señal 1981/2992
#    Procesando señal 1982/2992
#    Procesando señal 1983/2992
#    Procesando señal 1984/2992
#    Procesando señal 1985/2992
#    Procesando señal 1986/2992
#    Procesando señal 1987/2992
#    Procesando señal 1988/2992
#    Procesando señal 1989/2992
#    Procesando señal 1990/2992
#    Procesando señal 1991/2992
#    Procesando señal 1992/2992
#    Procesando señal 1993/2992
#    Procesando señal 1994/2992
#    Procesando señal 1995/2992
#    Procesando señal 1996/2992
#    Procesando señal 1997/2992
#    Procesando señal 1998/2992
#    Procesando señal 1999/2992
#    Procesando señal 2000/2992
#    Procesando señal 2001/2992
#    Procesando señal 2002/2992
#    Procesando señal 2003/2992
#    Procesando señal 2004/2992
#    Procesando señal 2005/2992
#    Procesando señal 2006/2992
#    Procesando señal 2007/2992
#    Procesando señal 2008/2992
#    Procesando señal 2009/2992
#    Procesando señal 2010/2992
#    Procesando señal 2011/2992
#    Procesando señal 2012/2992
#    Procesando señal 2013/2992
#    Procesando señal 2014/2992
#    Procesando señal 2015/2992
#    Procesando señal 2016/2992
#    Procesando señal 2017/2992
#    Procesando señal 2018/2992
#    Procesando señal 2019/2992
#    Procesando señal 2020/2992
#    Procesando señal 2021/2992
#    Procesando señal 2022/2992
#    Procesando señal 2023/2992
#    Procesando señal 2024/2992
#    Procesando señal 2025/2992
#    Procesando señal 2026/2992
#    Procesando señal 2027/2992
#    Procesando señal 2028/2992
#    Procesando señal 2029/2992
#    Procesando señal 2030/2992
#    Procesando señal 2031/2992
#    Procesando señal 2032/2992
#    Procesando señal 2033/2992
#    Procesando señal 2034/2992
#    Procesando señal 2035/2992
#    Procesando señal 2036/2992
#    Procesando señal 2037/2992
#    Procesando señal 2038/2992
#    Procesando señal 2039/2992
#    Procesando señal 2040/2992
#    Procesando señal 2041/2992
#    Procesando señal 2042/2992
#    Procesando señal 2043/2992
#    Procesando señal 2044/2992
#    Procesando señal 2045/2992
#    Procesando señal 2046/2992
#    Procesando señal 2047/2992
#    Procesando señal 2048/2992
#    Procesando señal 2049/2992
#    Procesando señal 2050/2992
#    Procesando señal 2051/2992
#    Procesando señal 2052/2992
#    Procesando señal 2053/2992
#    Procesando señal 2054/2992
#    Procesando señal 2055/2992
#    Procesando señal 2056/2992
#    Procesando señal 2057/2992
#    Procesando señal 2058/2992
#    Procesando señal 2059/2992
#    Procesando señal 2060/2992
#    Procesando señal 2061/2992
#    Procesando señal 2062/2992
#    Procesando señal 2063/2992
#    Procesando señal 2064/2992
#    Procesando señal 2065/2992
#    Procesando señal 2066/2992
#    Procesando señal 2067/2992
#    Procesando señal 2068/2992
#    Procesando señal 2069/2992
#    Procesando señal 2070/2992
#    Procesando señal 2071/2992
#    Procesando señal 2072/2992
#    Procesando señal 2073/2992
#    Procesando señal 2074/2992
#    Procesando señal 2075/2992
#    Procesando señal 2076/2992
#    Procesando señal 2077/2992
#    Procesando señal 2078/2992
#    Procesando señal 2079/2992
#    Procesando señal 2080/2992
#    Procesando señal 2081/2992
#    Procesando señal 2082/2992
#    Procesando señal 2083/2992
#    Procesando señal 2084/2992
#    Procesando señal 2085/2992
#    Procesando señal 2086/2992
#    Procesando señal 2087/2992
#    Procesando señal 2088/2992
#    Procesando señal 2089/2992
#    Procesando señal 2090/2992
#    Procesando señal 2091/2992
#    Procesando señal 2092/2992
#    Procesando señal 2093/2992
#    Procesando señal 2094/2992
#    Procesando señal 2095/2992
#    Procesando señal 2096/2992
#    Procesando señal 2097/2992
#    Procesando señal 2098/2992
#    Procesando señal 2099/2992
#    Procesando señal 2100/2992
#    Procesando señal 2101/2992
#    Procesando señal 2102/2992
#    Procesando señal 2103/2992
#    Procesando señal 2104/2992
#    Procesando señal 2105/2992
#    Procesando señal 2106/2992
#    Procesando señal 2107/2992
#    Procesando señal 2108/2992
#    Procesando señal 2109/2992
#    Procesando señal 2110/2992
#    Procesando señal 2111/2992
#    Procesando señal 2112/2992
#    Procesando señal 2113/2992
#    Procesando señal 2114/2992
#    Procesando señal 2115/2992
#    Procesando señal 2116/2992
#    Procesando señal 2117/2992
#    Procesando señal 2118/2992
#    Procesando señal 2119/2992
#    Procesando señal 2120/2992
#    Procesando señal 2121/2992
#    Procesando señal 2122/2992
#    Procesando señal 2123/2992
#    Procesando señal 2124/2992
#    Procesando señal 2125/2992
#    Procesando señal 2126/2992
#    Procesando señal 2127/2992
#    Procesando señal 2128/2992
#    Procesando señal 2129/2992
#    Procesando señal 2130/2992
#    Procesando señal 2131/2992
#    Procesando señal 2132/2992
#    Procesando señal 2133/2992
#    Procesando señal 2134/2992
#    Procesando señal 2135/2992
#    Procesando señal 2136/2992
#    Procesando señal 2137/2992
#    Procesando señal 2138/2992
#    Procesando señal 2139/2992
#    Procesando señal 2140/2992
#    Procesando señal 2141/2992
#    Procesando señal 2142/2992
#    Procesando señal 2143/2992
#    Procesando señal 2144/2992
#    Procesando señal 2145/2992
#    Procesando señal 2146/2992
#    Procesando señal 2147/2992
#    Procesando señal 2148/2992
#    Procesando señal 2149/2992
#    Procesando señal 2150/2992
#    Procesando señal 2151/2992
#    Procesando señal 2152/2992
#    Procesando señal 2153/2992
#    Procesando señal 2154/2992
#    Procesando señal 2155/2992
#    Procesando señal 2156/2992
#    Procesando señal 2157/2992
#    Procesando señal 2158/2992
#    Procesando señal 2159/2992
#    Procesando señal 2160/2992
#    Procesando señal 2161/2992
#    Procesando señal 2162/2992
#    Procesando señal 2163/2992
#    Procesando señal 2164/2992
#    Procesando señal 2165/2992
#    Procesando señal 2166/2992
#    Procesando señal 2167/2992
#    Procesando señal 2168/2992
#    Procesando señal 2169/2992
#    Procesando señal 2170/2992
#    Procesando señal 2171/2992
#    Procesando señal 2172/2992
#    Procesando señal 2173/2992
#    Procesando señal 2174/2992
#    Procesando señal 2175/2992
#    Procesando señal 2176/2992
#    Procesando señal 2177/2992
#    Procesando señal 2178/2992
#    Procesando señal 2179/2992
#    Procesando señal 2180/2992
#    Procesando señal 2181/2992
#    Procesando señal 2182/2992
#    Procesando señal 2183/2992
#    Procesando señal 2184/2992
#    Procesando señal 2185/2992
#    Procesando señal 2186/2992
#    Procesando señal 2187/2992
#    Procesando señal 2188/2992
#    Procesando señal 2189/2992
#    Procesando señal 2190/2992
#    Procesando señal 2191/2992
#    Procesando señal 2192/2992
#    Procesando señal 2193/2992
#    Procesando señal 2194/2992
#    Procesando señal 2195/2992
#    Procesando señal 2196/2992
#    Procesando señal 2197/2992
#    Procesando señal 2198/2992
#    Procesando señal 2199/2992
#    Procesando señal 2200/2992
#    Procesando señal 2201/2992
#    Procesando señal 2202/2992
#    Procesando señal 2203/2992
#    Procesando señal 2204/2992
#    Procesando señal 2205/2992
#    Procesando señal 2206/2992
#    Procesando señal 2207/2992
#    Procesando señal 2208/2992
#    Procesando señal 2209/2992
#    Procesando señal 2210/2992
#    Procesando señal 2211/2992
#    Procesando señal 2212/2992
#    Procesando señal 2213/2992
#    Procesando señal 2214/2992
#    Procesando señal 2215/2992
#    Procesando señal 2216/2992
#    Procesando señal 2217/2992
#    Procesando señal 2218/2992
#    Procesando señal 2219/2992
#    Procesando señal 2220/2992
#    Procesando señal 2221/2992
#    Procesando señal 2222/2992
#    Procesando señal 2223/2992
#    Procesando señal 2224/2992
#    Procesando señal 2225/2992
#    Procesando señal 2226/2992
#    Procesando señal 2227/2992
#    Procesando señal 2228/2992
#    Procesando señal 2229/2992
#    Procesando señal 2230/2992
#    Procesando señal 2231/2992
#    Procesando señal 2232/2992
#    Procesando señal 2233/2992
#    Procesando señal 2234/2992
#    Procesando señal 2235/2992
#    Procesando señal 2236/2992
#    Procesando señal 2237/2992
#    Procesando señal 2238/2992
#    Procesando señal 2239/2992
#    Procesando señal 2240/2992
#    Procesando señal 2241/2992
#    Procesando señal 2242/2992
#    Procesando señal 2243/2992
#    Procesando señal 2244/2992
#    Procesando señal 2245/2992
#    Procesando señal 2246/2992
#    Procesando señal 2247/2992
#    Procesando señal 2248/2992
#    Procesando señal 2249/2992
#    Procesando señal 2250/2992
#    Procesando señal 2251/2992
#    Procesando señal 2252/2992
#    Procesando señal 2253/2992
#    Procesando señal 2254/2992
#    Procesando señal 2255/2992
#    Procesando señal 2256/2992
#    Procesando señal 2257/2992
#    Procesando señal 2258/2992
#    Procesando señal 2259/2992
#    Procesando señal 2260/2992
#    Procesando señal 2261/2992
#    Procesando señal 2262/2992
#    Procesando señal 2263/2992
#    Procesando señal 2264/2992
#    Procesando señal 2265/2992
#    Procesando señal 2266/2992
#    Procesando señal 2267/2992
#    Procesando señal 2268/2992
#    Procesando señal 2269/2992
#    Procesando señal 2270/2992
#    Procesando señal 2271/2992
#    Procesando señal 2272/2992
#    Procesando señal 2273/2992
#    Procesando señal 2274/2992
#    Procesando señal 2275/2992
#    Procesando señal 2276/2992
#    Procesando señal 2277/2992
#    Procesando señal 2278/2992
#    Procesando señal 2279/2992
#    Procesando señal 2280/2992
#    Procesando señal 2281/2992
#    Procesando señal 2282/2992
#    Procesando señal 2283/2992
#    Procesando señal 2284/2992
#    Procesando señal 2285/2992
#    Procesando señal 2286/2992
#    Procesando señal 2287/2992
#    Procesando señal 2288/2992
#    Procesando señal 2289/2992
#    Procesando señal 2290/2992
#    Procesando señal 2291/2992
#    Procesando señal 2292/2992
#    Procesando señal 2293/2992
#    Procesando señal 2294/2992
#    Procesando señal 2295/2992
#    Procesando señal 2296/2992
#    Procesando señal 2297/2992
#    Procesando señal 2298/2992
#    Procesando señal 2299/2992
#    Procesando señal 2300/2992
#    Procesando señal 2301/2992
#    Procesando señal 2302/2992
#    Procesando señal 2303/2992
#    Procesando señal 2304/2992
#    Procesando señal 2305/2992
#    Procesando señal 2306/2992
#    Procesando señal 2307/2992
#    Procesando señal 2308/2992
#    Procesando señal 2309/2992
#    Procesando señal 2310/2992
#    Procesando señal 2311/2992
#    Procesando señal 2312/2992
#    Procesando señal 2313/2992
#    Procesando señal 2314/2992
#    Procesando señal 2315/2992
#    Procesando señal 2316/2992
#    Procesando señal 2317/2992
#    Procesando señal 2318/2992
#    Procesando señal 2319/2992
#    Procesando señal 2320/2992
#    Procesando señal 2321/2992
#    Procesando señal 2322/2992
#    Procesando señal 2323/2992
#    Procesando señal 2324/2992
#    Procesando señal 2325/2992
#    Procesando señal 2326/2992
#    Procesando señal 2327/2992
#    Procesando señal 2328/2992
#    Procesando señal 2329/2992
#    Procesando señal 2330/2992
#    Procesando señal 2331/2992
#    Procesando señal 2332/2992
#    Procesando señal 2333/2992
#    Procesando señal 2334/2992
#    Procesando señal 2335/2992
#    Procesando señal 2336/2992
#    Procesando señal 2337/2992
#    Procesando señal 2338/2992
#    Procesando señal 2339/2992
#    Procesando señal 2340/2992
#    Procesando señal 2341/2992
#    Procesando señal 2342/2992
#    Procesando señal 2343/2992
#    Procesando señal 2344/2992
#    Procesando señal 2345/2992
#    Procesando señal 2346/2992
#    Procesando señal 2347/2992
#    Procesando señal 2348/2992
#    Procesando señal 2349/2992
#    Procesando señal 2350/2992
#    Procesando señal 2351/2992
#    Procesando señal 2352/2992
#    Procesando señal 2353/2992
#    Procesando señal 2354/2992
#    Procesando señal 2355/2992
#    Procesando señal 2356/2992
#    Procesando señal 2357/2992
#    Procesando señal 2358/2992
#    Procesando señal 2359/2992
#    Procesando señal 2360/2992
#    Procesando señal 2361/2992
#    Procesando señal 2362/2992
#    Procesando señal 2363/2992
#    Procesando señal 2364/2992
#    Procesando señal 2365/2992
#    Procesando señal 2366/2992
#    Procesando señal 2367/2992
#    Procesando señal 2368/2992
#    Procesando señal 2369/2992
#    Procesando señal 2370/2992
#    Procesando señal 2371/2992
#    Procesando señal 2372/2992
#    Procesando señal 2373/2992
#    Procesando señal 2374/2992
#    Procesando señal 2375/2992
#    Procesando señal 2376/2992
#    Procesando señal 2377/2992
#    Procesando señal 2378/2992
#    Procesando señal 2379/2992
#    Procesando señal 2380/2992
#    Procesando señal 2381/2992
#    Procesando señal 2382/2992
#    Procesando señal 2383/2992
#    Procesando señal 2384/2992
#    Procesando señal 2385/2992
#    Procesando señal 2386/2992
#    Procesando señal 2387/2992
#    Procesando señal 2388/2992
#    Procesando señal 2389/2992
#    Procesando señal 2390/2992
#    Procesando señal 2391/2992
#    Procesando señal 2392/2992
#    Procesando señal 2393/2992
#    Procesando señal 2394/2992
#    Procesando señal 2395/2992
#    Procesando señal 2396/2992
#    Procesando señal 2397/2992
#    Procesando señal 2398/2992
#    Procesando señal 2399/2992
#    Procesando señal 2400/2992
#    Procesando señal 2401/2992
#    Procesando señal 2402/2992
#    Procesando señal 2403/2992
#    Procesando señal 2404/2992
#    Procesando señal 2405/2992
#    Procesando señal 2406/2992
#    Procesando señal 2407/2992
#    Procesando señal 2408/2992
#    Procesando señal 2409/2992
#    Procesando señal 2410/2992
#    Procesando señal 2411/2992
#    Procesando señal 2412/2992
#    Procesando señal 2413/2992
#    Procesando señal 2414/2992
#    Procesando señal 2415/2992
#    Procesando señal 2416/2992
#    Procesando señal 2417/2992
#    Procesando señal 2418/2992
#    Procesando señal 2419/2992
#    Procesando señal 2420/2992
#    Procesando señal 2421/2992
#    Procesando señal 2422/2992
#    Procesando señal 2423/2992
#    Procesando señal 2424/2992
#    Procesando señal 2425/2992
#    Procesando señal 2426/2992
#    Procesando señal 2427/2992
#    Procesando señal 2428/2992
#    Procesando señal 2429/2992
#    Procesando señal 2430/2992
#    Procesando señal 2431/2992
#    Procesando señal 2432/2992
#    Procesando señal 2433/2992
#    Procesando señal 2434/2992
#    Procesando señal 2435/2992
#    Procesando señal 2436/2992
#    Procesando señal 2437/2992
#    Procesando señal 2438/2992
#    Procesando señal 2439/2992
#    Procesando señal 2440/2992
#    Procesando señal 2441/2992
#    Procesando señal 2442/2992
#    Procesando señal 2443/2992
#    Procesando señal 2444/2992
#    Procesando señal 2445/2992
#    Procesando señal 2446/2992
#    Procesando señal 2447/2992
#    Procesando señal 2448/2992
#    Procesando señal 2449/2992
#    Procesando señal 2450/2992
#    Procesando señal 2451/2992
#    Procesando señal 2452/2992
#    Procesando señal 2453/2992
#    Procesando señal 2454/2992
#    Procesando señal 2455/2992
#    Procesando señal 2456/2992
#    Procesando señal 2457/2992
#    Procesando señal 2458/2992
#    Procesando señal 2459/2992
#    Procesando señal 2460/2992
#    Procesando señal 2461/2992
#    Procesando señal 2462/2992
#    Procesando señal 2463/2992
#    Procesando señal 2464/2992
#    Procesando señal 2465/2992
#    Procesando señal 2466/2992
#    Procesando señal 2467/2992
#    Procesando señal 2468/2992
#    Procesando señal 2469/2992
#    Procesando señal 2470/2992
#    Procesando señal 2471/2992
#    Procesando señal 2472/2992
#    Procesando señal 2473/2992
#    Procesando señal 2474/2992
#    Procesando señal 2475/2992
#    Procesando señal 2476/2992
#    Procesando señal 2477/2992
#    Procesando señal 2478/2992
#    Procesando señal 2479/2992
#    Procesando señal 2480/2992
#    Procesando señal 2481/2992
#    Procesando señal 2482/2992
#    Procesando señal 2483/2992
#    Procesando señal 2484/2992
#    Procesando señal 2485/2992
#    Procesando señal 2486/2992
#    Procesando señal 2487/2992
#    Procesando señal 2488/2992
#    Procesando señal 2489/2992
#    Procesando señal 2490/2992
#    Procesando señal 2491/2992
#    Procesando señal 2492/2992
#    Procesando señal 2493/2992
#    Procesando señal 2494/2992
#    Procesando señal 2495/2992
#    Procesando señal 2496/2992
#    Procesando señal 2497/2992
#    Procesando señal 2498/2992
#    Procesando señal 2499/2992
#    Procesando señal 2500/2992
#    Procesando señal 2501/2992
#    Procesando señal 2502/2992
#    Procesando señal 2503/2992
#    Procesando señal 2504/2992
#    Procesando señal 2505/2992
#    Procesando señal 2506/2992
#    Procesando señal 2507/2992
#    Procesando señal 2508/2992
#    Procesando señal 2509/2992
#    Procesando señal 2510/2992
#    Procesando señal 2511/2992
#    Procesando señal 2512/2992
#    Procesando señal 2513/2992
#    Procesando señal 2514/2992
#    Procesando señal 2515/2992
#    Procesando señal 2516/2992
#    Procesando señal 2517/2992
#    Procesando señal 2518/2992
#    Procesando señal 2519/2992
#    Procesando señal 2520/2992
#    Procesando señal 2521/2992
#    Procesando señal 2522/2992
#    Procesando señal 2523/2992
#    Procesando señal 2524/2992
#    Procesando señal 2525/2992
#    Procesando señal 2526/2992
#    Procesando señal 2527/2992
#    Procesando señal 2528/2992
#    Procesando señal 2529/2992
#    Procesando señal 2530/2992
#    Procesando señal 2531/2992
#    Procesando señal 2532/2992
#    Procesando señal 2533/2992
#    Procesando señal 2534/2992
#    Procesando señal 2535/2992
#    Procesando señal 2536/2992
#    Procesando señal 2537/2992
#    Procesando señal 2538/2992
#    Procesando señal 2539/2992
#    Procesando señal 2540/2992
#    Procesando señal 2541/2992
#    Procesando señal 2542/2992
#    Procesando señal 2543/2992
#    Procesando señal 2544/2992
#    Procesando señal 2545/2992
#    Procesando señal 2546/2992
#    Procesando señal 2547/2992
#    Procesando señal 2548/2992
#    Procesando señal 2549/2992
#    Procesando señal 2550/2992
#    Procesando señal 2551/2992
#    Procesando señal 2552/2992
#    Procesando señal 2553/2992
#    Procesando señal 2554/2992
#    Procesando señal 2555/2992
#    Procesando señal 2556/2992
#    Procesando señal 2557/2992
#    Procesando señal 2558/2992
#    Procesando señal 2559/2992
#    Procesando señal 2560/2992
#    Procesando señal 2561/2992
#    Procesando señal 2562/2992
#    Procesando señal 2563/2992
#    Procesando señal 2564/2992
#    Procesando señal 2565/2992
#    Procesando señal 2566/2992
#    Procesando señal 2567/2992
#    Procesando señal 2568/2992
#    Procesando señal 2569/2992
#    Procesando señal 2570/2992
#    Procesando señal 2571/2992
#    Procesando señal 2572/2992
#    Procesando señal 2573/2992
#    Procesando señal 2574/2992
#    Procesando señal 2575/2992
#    Procesando señal 2576/2992
#    Procesando señal 2577/2992
#    Procesando señal 2578/2992
#    Procesando señal 2579/2992
#    Procesando señal 2580/2992
#    Procesando señal 2581/2992
#    Procesando señal 2582/2992
#    Procesando señal 2583/2992
#    Procesando señal 2584/2992
#    Procesando señal 2585/2992
#    Procesando señal 2586/2992
#    Procesando señal 2587/2992
#    Procesando señal 2588/2992
#    Procesando señal 2589/2992
#    Procesando señal 2590/2992
# ...
#    Procesando señal 2453/2971
#    Procesando señal 2454/2971
#    Procesando señal 2455/2971
#    Procesando señal 2456/2971
#    Procesando señal 2457/2971
#    Procesando señal 2458/2971
#    Procesando señal 2459/2971
#    Procesando señal 2460/2971
#    Procesando señal 2461/2971
#    Procesando señal 2462/2971
#    Procesando señal 2463/2971
#    Procesando señal 2464/2971
#    Procesando señal 2465/2971
#    Procesando señal 2466/2971
#    Procesando señal 2467/2971
#    Procesando señal 2468/2971
#    Procesando señal 2469/2971
#    Procesando señal 2470/2971
#    Procesando señal 2471/2971
#    Procesando señal 2472/2971
#    Procesando señal 2473/2971
#    Procesando señal 2474/2971
#    Procesando señal 2475/2971
#    Procesando señal 2476/2971
#    Procesando señal 2477/2971
#    Procesando señal 2478/2971
#    Procesando señal 2479/2971
#    Procesando señal 2480/2971
#    Procesando señal 2481/2971
#    Procesando señal 2482/2971
#    Procesando señal 2483/2971
#    Procesando señal 2484/2971
#    Procesando señal 2485/2971
#    Procesando señal 2486/2971
#    Procesando señal 2487/2971
#    Procesando señal 2488/2971
#    Procesando señal 2489/2971
#    Procesando señal 2490/2971
#    Procesando señal 2491/2971
#    Procesando señal 2492/2971
#    Procesando señal 2493/2971
#    Procesando señal 2494/2971
#    Procesando señal 2495/2971
#    Procesando señal 2496/2971
#    Procesando señal 2497/2971
#    Procesando señal 2498/2971
#    Procesando señal 2499/2971
#    Procesando señal 2500/2971
#    Procesando señal 2501/2971
#    Procesando señal 2502/2971
#    Procesando señal 2503/2971
#    Procesando señal 2504/2971
#    Procesando señal 2505/2971
#    Procesando señal 2506/2971
#    Procesando señal 2507/2971
#    Procesando señal 2508/2971
#    Procesando señal 2509/2971
#    Procesando señal 2510/2971
#    Procesando señal 2511/2971
#    Procesando señal 2512/2971
#    Procesando señal 2513/2971
#    Procesando señal 2514/2971
#    Procesando señal 2515/2971
#    Procesando señal 2516/2971
#    Procesando señal 2517/2971
#    Procesando señal 2518/2971
#    Procesando señal 2519/2971
#    Procesando señal 2520/2971
#    Procesando señal 2521/2971
#    Procesando señal 2522/2971
#    Procesando señal 2523/2971
#    Procesando señal 2524/2971
#    Procesando señal 2525/2971
#    Procesando señal 2526/2971
#    Procesando señal 2527/2971
#    Procesando señal 2528/2971
#    Procesando señal 2529/2971
#    Procesando señal 2530/2971
#    Procesando señal 2531/2971
#    Procesando señal 2532/2971
#    Procesando señal 2533/2971
#    Procesando señal 2534/2971
#    Procesando señal 2535/2971
#    Procesando señal 2536/2971
#    Procesando señal 2537/2971
#    Procesando señal 2538/2971
#    Procesando señal 2539/2971
#    Procesando señal 2540/2971
#    Procesando señal 2541/2971
#    Procesando señal 2542/2971
#    Procesando señal 2543/2971
#    Procesando señal 2544/2971
#    Procesando señal 2545/2971
#    Procesando señal 2546/2971
#    Procesando señal 2547/2971
#    Procesando señal 2548/2971
#    Procesando señal 2549/2971
#    Procesando señal 2550/2971
#    Procesando señal 2551/2971
#    Procesando señal 2552/2971
#    Procesando señal 2553/2971
#    Procesando señal 2554/2971
#    Procesando señal 2555/2971
#    Procesando señal 2556/2971
#    Procesando señal 2557/2971
#    Procesando señal 2558/2971
#    Procesando señal 2559/2971
#    Procesando señal 2560/2971
#    Procesando señal 2561/2971
#    Procesando señal 2562/2971
#    Procesando señal 2563/2971
#    Procesando señal 2564/2971
#    Procesando señal 2565/2971
#    Procesando señal 2566/2971
#    Procesando señal 2567/2971
#    Procesando señal 2568/2971
#    Procesando señal 2569/2971
#    Procesando señal 2570/2971
#    Procesando señal 2571/2971
#    Procesando señal 2572/2971
#    Procesando señal 2573/2971
#    Procesando señal 2574/2971
#    Procesando señal 2575/2971
#    Procesando señal 2576/2971
#    Procesando señal 2577/2971
#    Procesando señal 2578/2971
#    Procesando señal 2579/2971
#    Procesando señal 2580/2971
#    Procesando señal 2581/2971
#    Procesando señal 2582/2971
#    Procesando señal 2583/2971
#    Procesando señal 2584/2971
#    Procesando señal 2585/2971
#    Procesando señal 2586/2971
#    Procesando señal 2587/2971
#    Procesando señal 2588/2971
#    Procesando señal 2589/2971
#    Procesando señal 2590/2971
#    Procesando señal 2591/2971
#    Procesando señal 2592/2971
#    Procesando señal 2593/2971
#    Procesando señal 2594/2971
#    Procesando señal 2595/2971
#    Procesando señal 2596/2971
#    Procesando señal 2597/2971
#    Procesando señal 2598/2971
#    Procesando señal 2599/2971
#    Procesando señal 2600/2971
#    Procesando señal 2601/2971
#    Procesando señal 2602/2971
#    Procesando señal 2603/2971
#    Procesando señal 2604/2971
#    Procesando señal 2605/2971
#    Procesando señal 2606/2971
#    Procesando señal 2607/2971
#    Procesando señal 2608/2971
#    Procesando señal 2609/2971
#    Procesando señal 2610/2971
#    Procesando señal 2611/2971
#    Procesando señal 2612/2971
#    Procesando señal 2613/2971
#    Procesando señal 2614/2971
#    Procesando señal 2615/2971
#    Procesando señal 2616/2971
#    Procesando señal 2617/2971
#    Procesando señal 2618/2971
#    Procesando señal 2619/2971
#    Procesando señal 2620/2971
#    Procesando señal 2621/2971
#    Procesando señal 2622/2971
#    Procesando señal 2623/2971
#    Procesando señal 2624/2971
#    Procesando señal 2625/2971
#    Procesando señal 2626/2971
#    Procesando señal 2627/2971
#    Procesando señal 2628/2971
#    Procesando señal 2629/2971
#    Procesando señal 2630/2971
#    Procesando señal 2631/2971
#    Procesando señal 2632/2971
#    Procesando señal 2633/2971
#    Procesando señal 2634/2971
#    Procesando señal 2635/2971
#    Procesando señal 2636/2971
#    Procesando señal 2637/2971
#    Procesando señal 2638/2971
#    Procesando señal 2639/2971
#    Procesando señal 2640/2971
#    Procesando señal 2641/2971
#    Procesando señal 2642/2971
#    Procesando señal 2643/2971
#    Procesando señal 2644/2971
#    Procesando señal 2645/2971
#    Procesando señal 2646/2971
#    Procesando señal 2647/2971
#    Procesando señal 2648/2971
#    Procesando señal 2649/2971
#    Procesando señal 2650/2971
#    Procesando señal 2651/2971
#    Procesando señal 2652/2971
#    Procesando señal 2653/2971
#    Procesando señal 2654/2971
#    Procesando señal 2655/2971
#    Procesando señal 2656/2971
#    Procesando señal 2657/2971
#    Procesando señal 2658/2971
#    Procesando señal 2659/2971
#    Procesando señal 2660/2971
#    Procesando señal 2661/2971
#    Procesando señal 2662/2971
#    Procesando señal 2663/2971
#    Procesando señal 2664/2971
#    Procesando señal 2665/2971
#    Procesando señal 2666/2971
#    Procesando señal 2667/2971
#    Procesando señal 2668/2971
#    Procesando señal 2669/2971
#    Procesando señal 2670/2971
#    Procesando señal 2671/2971
#    Procesando señal 2672/2971
#    Procesando señal 2673/2971
#    Procesando señal 2674/2971
#    Procesando señal 2675/2971
#    Procesando señal 2676/2971
#    Procesando señal 2677/2971
#    Procesando señal 2678/2971
#    Procesando señal 2679/2971
#    Procesando señal 2680/2971
#    Procesando señal 2681/2971
#    Procesando señal 2682/2971
#    Procesando señal 2683/2971
#    Procesando señal 2684/2971
#    Procesando señal 2685/2971
#    Procesando señal 2686/2971
#    Procesando señal 2687/2971
#    Procesando señal 2688/2971
#    Procesando señal 2689/2971
#    Procesando señal 2690/2971
#    Procesando señal 2691/2971
#    Procesando señal 2692/2971
#    Procesando señal 2693/2971
#    Procesando señal 2694/2971
#    Procesando señal 2695/2971
#    Procesando señal 2696/2971
#    Procesando señal 2697/2971
#    Procesando señal 2698/2971
#    Procesando señal 2699/2971
#    Procesando señal 2700/2971
#    Procesando señal 2701/2971
#    Procesando señal 2702/2971
#    Procesando señal 2703/2971
#    Procesando señal 2704/2971
#    Procesando señal 2705/2971
#    Procesando señal 2706/2971
#    Procesando señal 2707/2971
#    Procesando señal 2708/2971
#    Procesando señal 2709/2971
#    Procesando señal 2710/2971
#    Procesando señal 2711/2971
#    Procesando señal 2712/2971
#    Procesando señal 2713/2971
#    Procesando señal 2714/2971
#    Procesando señal 2715/2971
#    Procesando señal 2716/2971
#    Procesando señal 2717/2971
#    Procesando señal 2718/2971
#    Procesando señal 2719/2971
#    Procesando señal 2720/2971
#    Procesando señal 2721/2971
#    Procesando señal 2722/2971
#    Procesando señal 2723/2971
#    Procesando señal 2724/2971
#    Procesando señal 2725/2971
#    Procesando señal 2726/2971
#    Procesando señal 2727/2971
#    Procesando señal 2728/2971
#    Procesando señal 2729/2971
#    Procesando señal 2730/2971
#    Procesando señal 2731/2971
#    Procesando señal 2732/2971
#    Procesando señal 2733/2971
#    Procesando señal 2734/2971
#    Procesando señal 2735/2971
#    Procesando señal 2736/2971
#    Procesando señal 2737/2971
#    Procesando señal 2738/2971
#    Procesando señal 2739/2971
#    Procesando señal 2740/2971
#    Procesando señal 2741/2971
#    Procesando señal 2742/2971
#    Procesando señal 2743/2971
#    Procesando señal 2744/2971
#    Procesando señal 2745/2971
#    Procesando señal 2746/2971
#    Procesando señal 2747/2971
#    Procesando señal 2748/2971
#    Procesando señal 2749/2971
#    Procesando señal 2750/2971
#    Procesando señal 2751/2971
#    Procesando señal 2752/2971
#    Procesando señal 2753/2971
#    Procesando señal 2754/2971
#    Procesando señal 2755/2971
#    Procesando señal 2756/2971
#    Procesando señal 2757/2971
#    Procesando señal 2758/2971
#    Procesando señal 2759/2971
#    Procesando señal 2760/2971
#    Procesando señal 2761/2971
#    Procesando señal 2762/2971
#    Procesando señal 2763/2971
#    Procesando señal 2764/2971
#    Procesando señal 2765/2971
#    Procesando señal 2766/2971
#    Procesando señal 2767/2971
#    Procesando señal 2768/2971
#    Procesando señal 2769/2971
#    Procesando señal 2770/2971
#    Procesando señal 2771/2971
#    Procesando señal 2772/2971
#    Procesando señal 2773/2971
#    Procesando señal 2774/2971
#    Procesando señal 2775/2971
#    Procesando señal 2776/2971
#    Procesando señal 2777/2971
#    Procesando señal 2778/2971
#    Procesando señal 2779/2971
#    Procesando señal 2780/2971
#    Procesando señal 2781/2971
#    Procesando señal 2782/2971
#    Procesando señal 2783/2971
#    Procesando señal 2784/2971
#    Procesando señal 2785/2971
#    Procesando señal 2786/2971
#    Procesando señal 2787/2971
#    Procesando señal 2788/2971
#    Procesando señal 2789/2971
#    Procesando señal 2790/2971
#    Procesando señal 2791/2971
#    Procesando señal 2792/2971
#    Procesando señal 2793/2971
#    Procesando señal 2794/2971
#    Procesando señal 2795/2971
#    Procesando señal 2796/2971
#    Procesando señal 2797/2971
#    Procesando señal 2798/2971
#    Procesando señal 2799/2971
#    Procesando señal 2800/2971
#    Procesando señal 2801/2971
#    Procesando señal 2802/2971
#    Procesando señal 2803/2971
#    Procesando señal 2804/2971
#    Procesando señal 2805/2971
#    Procesando señal 2806/2971
#    Procesando señal 2807/2971
#    Procesando señal 2808/2971
#    Procesando señal 2809/2971
#    Procesando señal 2810/2971
#    Procesando señal 2811/2971
#    Procesando señal 2812/2971
#    Procesando señal 2813/2971
#    Procesando señal 2814/2971
#    Procesando señal 2815/2971
#    Procesando señal 2816/2971
#    Procesando señal 2817/2971
#    Procesando señal 2818/2971
#    Procesando señal 2819/2971
#    Procesando señal 2820/2971
#    Procesando señal 2821/2971
#    Procesando señal 2822/2971
#    Procesando señal 2823/2971
#    Procesando señal 2824/2971
#    Procesando señal 2825/2971
#    Procesando señal 2826/2971
#    Procesando señal 2827/2971
#    Procesando señal 2828/2971
#    Procesando señal 2829/2971
#    Procesando señal 2830/2971
#    Procesando señal 2831/2971
#    Procesando señal 2832/2971
#    Procesando señal 2833/2971
#    Procesando señal 2834/2971
#    Procesando señal 2835/2971
#    Procesando señal 2836/2971
#    Procesando señal 2837/2971
#    Procesando señal 2838/2971
#    Procesando señal 2839/2971
#    Procesando señal 2840/2971
#    Procesando señal 2841/2971
#    Procesando señal 2842/2971
#    Procesando señal 2843/2971
#    Procesando señal 2844/2971
#    Procesando señal 2845/2971
#    Procesando señal 2846/2971
#    Procesando señal 2847/2971
#    Procesando señal 2848/2971
#    Procesando señal 2849/2971
#    Procesando señal 2850/2971
#    Procesando señal 2851/2971
#    Procesando señal 2852/2971
#    Procesando señal 2853/2971
#    Procesando señal 2854/2971
#    Procesando señal 2855/2971
#    Procesando señal 2856/2971
#    Procesando señal 2857/2971
#    Procesando señal 2858/2971
#    Procesando señal 2859/2971
#    Procesando señal 2860/2971
#    Procesando señal 2861/2971
#    Procesando señal 2862/2971
#    Procesando señal 2863/2971
#    Procesando señal 2864/2971
#    Procesando señal 2865/2971
#    Procesando señal 2866/2971
#    Procesando señal 2867/2971
#    Procesando señal 2868/2971
#    Procesando señal 2869/2971
#    Procesando señal 2870/2971
#    Procesando señal 2871/2971
#    Procesando señal 2872/2971
#    Procesando señal 2873/2971
#    Procesando señal 2874/2971
#    Procesando señal 2875/2971
#    Procesando señal 2876/2971
#    Procesando señal 2877/2971
#    Procesando señal 2878/2971
#    Procesando señal 2879/2971
#    Procesando señal 2880/2971
#    Procesando señal 2881/2971
#    Procesando señal 2882/2971
#    Procesando señal 2883/2971
#    Procesando señal 2884/2971
#    Procesando señal 2885/2971
#    Procesando señal 2886/2971
#    Procesando señal 2887/2971
#    Procesando señal 2888/2971
#    Procesando señal 2889/2971
#    Procesando señal 2890/2971
#    Procesando señal 2891/2971
#    Procesando señal 2892/2971
#    Procesando señal 2893/2971
#    Procesando señal 2894/2971
#    Procesando señal 2895/2971
#    Procesando señal 2896/2971
#    Procesando señal 2897/2971
#    Procesando señal 2898/2971
#    Procesando señal 2899/2971
#    Procesando señal 2900/2971
#    Procesando señal 2901/2971
#    Procesando señal 2902/2971
#    Procesando señal 2903/2971
#    Procesando señal 2904/2971
#    Procesando señal 2905/2971
#    Procesando señal 2906/2971
#    Procesando señal 2907/2971
#    Procesando señal 2908/2971
#    Procesando señal 2909/2971
#    Procesando señal 2910/2971
#    Procesando señal 2911/2971
#    Procesando señal 2912/2971
#    Procesando señal 2913/2971
#    Procesando señal 2914/2971
#    Procesando señal 2915/2971
#    Procesando señal 2916/2971
#    Procesando señal 2917/2971
#    Procesando señal 2918/2971
#    Procesando señal 2919/2971
#    Procesando señal 2920/2971
#    Procesando señal 2921/2971
#    Procesando señal 2922/2971
#    Procesando señal 2923/2971
#    Procesando señal 2924/2971
#    Procesando señal 2925/2971
#    Procesando señal 2926/2971
#    Procesando señal 2927/2971
#    Procesando señal 2928/2971
#    Procesando señal 2929/2971
#    Procesando señal 2930/2971
#    Procesando señal 2931/2971
#    Procesando señal 2932/2971
#    Procesando señal 2933/2971
#    Procesando señal 2934/2971
#    Procesando señal 2935/2971
#    Procesando señal 2936/2971
#    Procesando señal 2937/2971
#    Procesando señal 2938/2971
#    Procesando señal 2939/2971
#    Procesando señal 2940/2971
#    Procesando señal 2941/2971
#    Procesando señal 2942/2971
#    Procesando señal 2943/2971
#    Procesando señal 2944/2971
#    Procesando señal 2945/2971
#    Procesando señal 2946/2971
#    Procesando señal 2947/2971
#    Procesando señal 2948/2971
#    Procesando señal 2949/2971
#    Procesando señal 2950/2971
#    Procesando señal 2951/2971
#    Procesando señal 2952/2971
#    Procesando señal 2953/2971
#    Procesando señal 2954/2971
#    Procesando señal 2955/2971
#    Procesando señal 2956/2971
#    Procesando señal 2957/2971
#    Procesando señal 2958/2971
#    Procesando señal 2959/2971
#    Procesando señal 2960/2971
#    Procesando señal 2961/2971
#    Procesando señal 2962/2971
#    Procesando señal 2963/2971
#    Procesando señal 2964/2971
#    Procesando señal 2965/2971
#    Procesando señal 2966/2971
#    Procesando señal 2967/2971
#    Procesando señal 2968/2971
#    Procesando señal 2969/2971
#    Procesando señal 2970/2971
#    Procesando señal 2971/2971
#
#    📊 Total resultados: 2994
# ✅ Fold completado - Resultados agregados: 2994
#
# ============================================================
# 📊 CALCULANDO MÉTRICAS FINALES
# ============================================================
# 📊 RESULTADOS FINALES (Microaverage):
#    Total resultados: 46306
#    F1-Score: 82.127%
#    Precision: 82.855%
#    Recall: 81.411%
#
# 💾 Resultados guardados en: inference_results_moda_microaverage.json

# %%
# !ls "/content/drive/MyDrive/codigo_eeg_redes"
# Out:
# Conv_MDB_Diagram.png			  Proyecto_RN.ipynb
# data					  README.md
# inference_results_moda_microaverage.json  requirements.txt
# mc_dropout_results			  run_model.ipynb
# model_weights				  SEED_diagram.png
# model_weights_best_original

# %% [markdown]
# # MC dropout

# %%
import torch
import torch.nn as nn
import numpy as np
import h5py
import json
from pathlib import Path
import gc
from torch.utils.data import Dataset

# ===================================================================
# CONFIGURACIÓN DEL MODELO (misma que en entrenamiento)
# ===================================================================

EMBED_DIM = 64
EMBED_BLOCKS = 1
FILTER_IN = 64
BLOCK_DILATATION = 2
RESOL_FACTOR = 8
BATCH_SIZE = 32
NUM_WORKERS = 12

EMBEDDING_CONFIG_SEED = {
    "embed_dim": EMBED_DIM,
    "block_depth": 2,
    "blocks": EMBED_BLOCKS,
    "dropout": 0.0,
    "filters_in": FILTER_IN,
    "block_dilatation": BLOCK_DILATATION,
}

CLASSIFIER_CONFIG = {
    "embed_dim": 256,
    "hide_dim": 128,
}

# Paths
h5_file_path = "/content/drive/MyDrive/codigo_eeg_redes/data/moda_augmented_s5.h5"
folds_json_path = "/content/drive/MyDrive/codigo_eeg_redes/data/moda_folds.json"
weights_save_dir = "/content/drive/MyDrive/codigo_eeg_redes/model_weights_best_original"  # o model_weights

mc_dropout_dir = Path("/content/drive/MyDrive/codigo_eeg_redes/mc_dropout_results")
mc_dropout_dir.mkdir(parents=True, exist_ok=True)

print("🔍 CONFIGURACIÓN DE INFERENCIA:")
print(f"   📁 Dataset: {h5_file_path}")
print(f"   📁 Folds: {folds_json_path}")
print(f"   💾 Pesos: {weights_save_dir}")

# ===================================================================
# FUNCIONES PARA MC DROPOUT
# ===================================================================

def enable_mc_dropout(model):
    """
    Fuerza a todas las capas Dropout a estar en modo entrenamiento durante la inferencia.
    Esto mantiene la aleatoriedad para MC Dropout.
    """
    for module in model.modules():
        if module.__class__.__name__.startswith('Dropout'):
            module.train()



# ===================================================================
# DATASET H5 PARA INFERENCIA
# ===================================================================

class H5InferenceDataset(Dataset):
    def __init__(self, h5_file_path, subject_ids=None):
        self.h5_file_path = h5_file_path

        with h5py.File(h5_file_path, 'r') as f:
            self.total_samples = len(f['signals'])
            self.signal_length = f['signals'].shape[1]
            self.label_length = f['labels'].shape[1]

            all_subject_ids = [s.decode('utf-8') for s in f['subject_ids'][:]]

            if subject_ids is not None:
                self.valid_indices = []
                for i, subj_id in enumerate(all_subject_ids):
                    if subj_id in subject_ids:
                        self.valid_indices.append(i)
            else:
                self.valid_indices = list(range(self.total_samples))

        print(f"📊 Dataset de inferencia creado:")
        print(f"   Total muestras: {len(self.valid_indices)}")

    def __len__(self):
        return len(self.valid_indices)

    def __getitem__(self, idx):
        real_idx = self.valid_indices[idx]

        with h5py.File(self.h5_file_path, 'r') as f:
            signal = f['signals'][real_idx]
            labels = f['labels'][real_idx]

            signal = signal.astype(np.float32)
            labels = labels.astype(np.float32)

            return real_idx, signal, labels

def create_batch_inference(data_list):
    """Función para crear batches para inferencia"""
    data_list = [data for data in data_list if data is not None]

    if len(data_list) == 0:
        return torch.empty(0, dtype=torch.long), torch.empty(0, 0), torch.empty(0, 0)

    ids, signals, labels = zip(*data_list)

    ids_tensor = torch.LongTensor(np.array(ids))
    signals_tensor = torch.FloatTensor(np.array(signals))
    labels_tensor = torch.FloatTensor(np.array(labels))

    return ids_tensor, signals_tensor, labels_tensor

# ===================================================================
# FUNCIONES DE Post PROCESAMIENTO
# ===================================================================

def process_spindle_simple(det_out, dur_out):
    """Versión simplificada del procesamiento de spindles"""
    new_output = dur_out.copy()

    F_RESAMPLE = 200  # Frecuencia de muestreo
    min_duration = int(F_RESAMPLE * 0.3)  # 0.3 segundos
    max_duration = int(F_RESAMPLE * 5)    # 5 segundos

    # Conectar detecciones cercanas
    i_last_label = 0
    in_event = False

    for i, label in enumerate(dur_out):
        if label == 1 and not in_event:
            if i_last_label != 0 and i - i_last_label < min_duration:
                new_output[i_last_label: i] = np.ones(i - i_last_label)
            in_event = True
        elif label == 0 and in_event:
            i_last_label = i
            in_event = False

    # Eliminar eventos muy cortos o largos
    i_start_label = 0
    in_event = False

    for i, label in enumerate(new_output):
        if label == 1 and not in_event:
            i_start_label = i
            in_event = True
        elif (label == 0 or i + 1 == len(new_output)) and in_event:
            if i - i_start_label < min_duration:
                new_output[i_start_label: i] = np.zeros(i - i_start_label)
            elif i - i_start_label > max_duration:
                p0 = (i - i_start_label - max_duration) // 2 + i_start_label
                pf = p0 + max_duration
                new_output[i_start_label: p0] = np.zeros(p0 - i_start_label)
                new_output[pf: i] = np.zeros(i - pf)
            in_event = False

    return new_output

def get_results_simple(labels, output):

    label_stamps = []
    predict_stamps = []

    in_predict_event = 0
    in_label_event = 0

    for i, (label, predict) in enumerate(zip(labels, output)):
        # Eventos reales
        if not in_label_event and label == 1:
            in_label_event = i
        elif in_label_event and (label == 0 or i + 1 == len(labels)):
            label_stamps.append((in_label_event, i))
            in_label_event = 0
            if (not in_predict_event and len(predict_stamps) < len(label_stamps)) or len(predict_stamps) + 1 < len(label_stamps):
                predict_stamps.append(0)

        # Eventos predichos
        if not in_predict_event and predict == 1:
            in_predict_event = i
        elif in_predict_event and (predict == 0 or i + 1 == len(output)):
            predict_stamps.append((in_predict_event, i))
            in_predict_event = 0
            if (not in_label_event and len(label_stamps) < len(predict_stamps)) or len(label_stamps) + 1 < len(predict_stamps):
                label_stamps.append(0)

    result = []
    # Calcular IoUs
    for label, predict in zip(label_stamps, predict_stamps):
        if not label and predict:  # Falso positivo
            result.append(-1)
        elif not predict and label:  # Falso negativo
            result.append(0)
        else:  # IoU
            inter = min(label[1], predict[1]) - max(label[0], predict[0])
            union = max(label[1], predict[1]) - min(label[0], predict[0])
            result.append(inter / union)

    return result

def calculate_metrics_simple(results, thresholds, threshold=0.2):
    """Versión simplificada de calculate_metrics"""
    true_positives = np.zeros_like(thresholds, dtype=float)
    false_positives = np.zeros_like(thresholds, dtype=float)
    false_negatives = np.zeros_like(thresholds, dtype=float)

    threshold_index = np.argmin(np.abs(thresholds - threshold))

    for i, t in enumerate(thresholds):
        for IoU in results:
            if IoU == -1:
                false_positives[i] += 1
            elif IoU == 0:
                false_negatives[i] += 1
            elif IoU >= t:
                true_positives[i] += 1
            else:
                false_negatives[i] += 1

    with np.errstate(divide='ignore', invalid='ignore'):
        precision = np.divide(true_positives, (true_positives + false_positives))
        recall = np.divide(true_positives, (true_positives + false_negatives))

        precision = np.nan_to_num(precision, nan=0.0)
        recall = np.nan_to_num(recall, nan=0.0)

        f1_score = np.divide(2 * precision * recall, (precision + recall),
                           out=np.zeros_like(recall), where=(precision + recall) != 0)

    return threshold_index, precision, recall, f1_score
# ===================================================================
# FUNCIÓN PRINCIPAL DE INFERENCIA
# ===================================================================

def run_inference_for_fold(eval_num, fold_num, test_subjects, model_weights_dir):
    """Ejecuta inferencia para un fold específico SIN DataLoader"""

    print(f"\n🔍 INFERENCIA EVAL {eval_num} - FOLD {fold_num}")
    print(f"   Test subjects: {test_subjects}")

    # Limpiar memoria
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    gc.collect()

    # Crear dataset de test (SIN DataLoader)
    test_dataset = H5InferenceDataset(h5_file_path, subject_ids=test_subjects)

    # Cargar modelo
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = SEED_Model().to(device)

    # Cargar pesos

    weights_folder = Path(model_weights_dir) / f"eval_{eval_num}" / f"fold_{fold_num}"

    try:
        model.embedding.load_state_dict(torch.load(weights_folder / "embedding_best.pth", map_location=device), strict=False) # Stric=False para no cargar pesos innecesarios de los embeddings originales
        model.transformer.load_state_dict(torch.load(weights_folder / "lstm_best.pth", map_location=device))
        model.classifier.load_state_dict(torch.load(weights_folder / "classifier_best.pth", map_location=device))
        print(f"   ✅ Pesos cargados desde: {weights_folder}")
    except Exception as e:
        print(f"   ❌ Error cargando pesos: {e}")
        return []

    # Modo evaluación estándar
    model.eval()

    # 🔹 ACTIVAR MC DROPOUT
    enable_mc_dropout(model)
    print("🔹 MC Dropout activado: las capas Dropout permanecerán activas durante la inferencia.")


    all_results = []
    total_signals = len(test_dataset)

    # ✅ ITERAR DIRECTAMENTE SOBRE EL DATASET
    with torch.no_grad():
        for s, (_, comp_signal, comp_labels) in enumerate(test_dataset):

            print(f"   Procesando señal {s+1}/{total_signals}")

            # Procesar señal completa
            comp_output = process_full_signal(model, comp_signal, device, signal_idx=s) #LOGITS

            # Aplicar thresholds
            det_out = np.where(comp_output >= 0.5, np.ones_like(comp_output), np.zeros_like(comp_output))
            dur_out = np.where(comp_output >= 0.425, np.ones_like(comp_output), np.zeros_like(comp_output))

            # Procesar detecciones
            processed_out = process_spindle_simple(det_out, dur_out)

            # Calcular IoUs
            sample_results = get_results_simple(comp_labels.astype(int), processed_out)
            all_results.extend(sample_results)

    print(f"\n   📊 Total resultados: {len(all_results)}")

    # Limpiar memoria
    del model
    del test_dataset

    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    gc.collect()

    return all_results

def process_full_signal(model, comp_signal, device, signal_idx):
    """Procesa una señal completa usando segmentos (como en detections_2.py)"""

    F_RESAMPLE = 200
    SIGNAL_WINDOW = 20  # 20 segundos
    INFERENCE_STRIDE = 10  # 10 segundos

    # Cantidad de segmentos
    segments = int(len(comp_signal) / F_RESAMPLE - SIGNAL_WINDOW) // INFERENCE_STRIDE + 1

    for i in range(segments):
        p0 = INFERENCE_STRIDE * F_RESAMPLE * i
        pf = p0 + SIGNAL_WINDOW * F_RESAMPLE  # 20 segundos desde la pos inicial

        # Obtener output del segmento
        signal_segment = torch.FloatTensor(comp_signal[p0:pf]).unsqueeze(0).to(device)
        output = model(signal_segment)
        output = torch.sigmoid(output).squeeze().cpu().numpy()

        # Concatenar 10 segundos centrales del output
        p1 = F_RESAMPLE * (SIGNAL_WINDOW - INFERENCE_STRIDE) // 2
        p2 = p1 + F_RESAMPLE * INFERENCE_STRIDE

        if i == 0:
            comp_output = output[:p2]
        elif i + 1 == segments:
            comp_output = np.concatenate((comp_output, output[p1:]), axis=0)
        else:
            comp_output = np.concatenate((comp_output, output[p1:p2]), axis=0)

    # Analizar si queda resto de señal
    rest = (len(comp_signal) / F_RESAMPLE - SIGNAL_WINDOW) % INFERENCE_STRIDE
    if rest != 0:
        p0 = len(comp_signal) - SIGNAL_WINDOW * F_RESAMPLE
        signal_segment = torch.FloatTensor(comp_signal[p0:]).unsqueeze(0).to(device)



        # 🔹 MC Dropout: realizar varias predicciones para estimar incertidumbre
        NUM_MC_SAMPLES = 20  # número de pasadas forward, ajusta según tu GPU
        outputs_mc = []

        for _ in range(NUM_MC_SAMPLES):
            mc_output = model(signal_segment)
            mc_output = torch.sigmoid(mc_output).squeeze().cpu().numpy()
            outputs_mc.append(mc_output)

        # Convertir a numpy array: shape = (NUM_MC_SAMPLES, longitud_segmento)
        outputs_mc = np.stack(outputs_mc)

        # Calcular promedio y desviación estándar
        output_mean = outputs_mc.mean(axis=0)
        output_std = outputs_mc.std(axis=0)  # Incertidumbre

        # Guardar la incertidumbre para cada señal analizada
        np.save(mc_dropout_dir / f"mc_std_signal{signal_idx+1}.npy", output_std)
        np.save(mc_dropout_dir / f"mc_outputs_signal{signal_idx+1}.npy", outputs_mc)      # todas las predicciones (opcional)



        # Usar el promedio para el pipeline original
        output = output_mean



        comp_output = np.concatenate((comp_output, output[-int(rest * F_RESAMPLE):]), axis=0)

    return comp_output

def main_inference():
    """Función principal que ejecuta toda la inferencia SIN DataLoader"""

    print("🚀 INICIANDO INFERENCIA COMPLETA")
    print("="*60)

    # Cargar configuración de folds
    with open(folds_json_path, 'r') as f:
        folds_data = json.load(f)

    all_fold_results = []
    evaluations = [1, 2, 3]
    folds = [1, 2, 3, 4, 5]

    total_folds = len(evaluations) * len(folds)
    current_fold = 0

    # Iterar sobre todas las evaluaciones y folds
    for eval_num in evaluations:
        for fold_num in folds:
            current_fold += 1

            eval_key = f"eval_{eval_num}"
            fold_key = f"fold_{fold_num}"

            test_subjects = folds_data[eval_key][fold_key]['test']

            print(f"\n{'='*60}")
            print(f"🎯 PROCESANDO {current_fold}/{total_folds}: EVAL {eval_num} - FOLD {fold_num}")
            print(f"{'='*60}")

            # Ejecutar inferencia para este fold
            fold_results = run_inference_for_fold(eval_num, fold_num, test_subjects, weights_save_dir)

            if fold_results:
                all_fold_results.extend(fold_results)
                print(f"✅ Fold completado - Resultados agregados: {len(fold_results)}")
            else:
                print(f"❌ Error en fold {eval_num}-{fold_num}")

    # Calcular métricas finales (microaverage)
    print(f"\n{'='*60}")
    print("📊 CALCULANDO MÉTRICAS FINALES")
    print(f"{'='*60}")

    if all_fold_results:
        thresholds = np.linspace(0, 1, 100)
        index, precision, recall, f1_score = calculate_metrics_simple(all_fold_results, thresholds)

        final_metrics = {
            'total_results': len(all_fold_results),
            'f1_score': float(f1_score[index] * 100),
            'precision': float(precision[index] * 100),
            'recall': float(recall[index] * 100),
            'threshold_iou': 0.2,
            'evaluations': evaluations,
            'folds': folds,
            'microaverage': True
        }

        print(f"📊 RESULTADOS FINALES (Microaverage):")
        print(f"   Total resultados: {final_metrics['total_results']}")
        print(f"   F1-Score: {final_metrics['f1_score']:.3f}%")
        print(f"   Precision: {final_metrics['precision']:.3f}%")
        print(f"   Recall: {final_metrics['recall']:.3f}%")

        # Guardar resultados
        output_file = "inference_results_moda_microaverage_mc_dropout.json"
        with open(output_file, 'w') as f:
            json.dump(final_metrics, f, indent=4)

        print(f"\n💾 Resultados guardados en: {output_file}")

    else:
        print("❌ No se obtuvieron resultados de ningún fold")

# Ejecutar inferencia
if __name__ == "__main__":
    main_inference()
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#    Procesando señal 994/2992
#    Procesando señal 995/2992
#    Procesando señal 996/2992
#    Procesando señal 997/2992
#    Procesando señal 998/2992
#    Procesando señal 999/2992
#    Procesando señal 1000/2992
#    Procesando señal 1001/2992
#    Procesando señal 1002/2992
#    Procesando señal 1003/2992
#    Procesando señal 1004/2992
#    Procesando señal 1005/2992
#    Procesando señal 1006/2992
#    Procesando señal 1007/2992
#    Procesando señal 1008/2992
#    Procesando señal 1009/2992
#    Procesando señal 1010/2992
#    Procesando señal 1011/2992
#    Procesando señal 1012/2992
#    Procesando señal 1013/2992
#    Procesando señal 1014/2992
#    Procesando señal 1015/2992
#    Procesando señal 1016/2992
#    Procesando señal 1017/2992
#    Procesando señal 1018/2992
#    Procesando señal 1019/2992
#    Procesando señal 1020/2992
#    Procesando señal 1021/2992
#    Procesando señal 1022/2992
#    Procesando señal 1023/2992
#    Procesando señal 1024/2992
#    Procesando señal 1025/2992
#    Procesando señal 1026/2992
#    Procesando señal 1027/2992
#    Procesando señal 1028/2992
#    Procesando señal 1029/2992
#    Procesando señal 1030/2992
#    Procesando señal 1031/2992
#    Procesando señal 1032/2992
#    Procesando señal 1033/2992
#    Procesando señal 1034/2992
#    Procesando señal 1035/2992
#    Procesando señal 1036/2992
#    Procesando señal 1037/2992
#    Procesando señal 1038/2992
#    Procesando señal 1039/2992
#    Procesando señal 1040/2992
#    Procesando señal 1041/2992
#    Procesando señal 1042/2992
#    Procesando señal 1043/2992
#    Procesando señal 1044/2992
#    Procesando señal 1045/2992
#    Procesando señal 1046/2992
#    Procesando señal 1047/2992
#    Procesando señal 1048/2992
#    Procesando señal 1049/2992
#    Procesando señal 1050/2992
#    Procesando señal 1051/2992
#    Procesando señal 1052/2992
#    Procesando señal 1053/2992
#    Procesando señal 1054/2992
#    Procesando señal 1055/2992
#    Procesando señal 1056/2992
#    Procesando señal 1057/2992
#    Procesando señal 1058/2992
#    Procesando señal 1059/2992
#    Procesando señal 1060/2992
#    Procesando señal 1061/2992
#    Procesando señal 1062/2992
#    Procesando señal 1063/2992
#    Procesando señal 1064/2992
#    Procesando señal 1065/2992
#    Procesando señal 1066/2992
#    Procesando señal 1067/2992
#    Procesando señal 1068/2992
#    Procesando señal 1069/2992
#    Procesando señal 1070/2992
#    Procesando señal 1071/2992
#    Procesando señal 1072/2992
#    Procesando señal 1073/2992
#    Procesando señal 1074/2992
#    Procesando señal 1075/2992
#    Procesando señal 1076/2992
#    Procesando señal 1077/2992
#    Procesando señal 1078/2992
#    Procesando señal 1079/2992
#    Procesando señal 1080/2992
#    Procesando señal 1081/2992
#    Procesando señal 1082/2992
#    Procesando señal 1083/2992
#    Procesando señal 1084/2992
#    Procesando señal 1085/2992
#    Procesando señal 1086/2992
#    Procesando señal 1087/2992
#    Procesando señal 1088/2992
#    Procesando señal 1089/2992
#    Procesando señal 1090/2992
#    Procesando señal 1091/2992
#    Procesando señal 1092/2992
#    Procesando señal 1093/2992
#    Procesando señal 1094/2992
#    Procesando señal 1095/2992
#    Procesando señal 1096/2992
#    Procesando señal 1097/2992
#    Procesando señal 1098/2992
#    Procesando señal 1099/2992
#    Procesando señal 1100/2992
#    Procesando señal 1101/2992
#    Procesando señal 1102/2992
#    Procesando señal 1103/2992
#    Procesando señal 1104/2992
#    Procesando señal 1105/2992
#    Procesando señal 1106/2992
#    Procesando señal 1107/2992
#    Procesando señal 1108/2992
#    Procesando señal 1109/2992
#    Procesando señal 1110/2992
#    Procesando señal 1111/2992
#    Procesando señal 1112/2992
#    Procesando señal 1113/2992
#    Procesando señal 1114/2992
#    Procesando señal 1115/2992
#    Procesando señal 1116/2992
#    Procesando señal 1117/2992
#    Procesando señal 1118/2992
#    Procesando señal 1119/2992
#    Procesando señal 1120/2992
#    Procesando señal 1121/2992
#    Procesando señal 1122/2992
#    Procesando señal 1123/2992
#    Procesando señal 1124/2992
#    Procesando señal 1125/2992
#    Procesando señal 1126/2992
#    Procesando señal 1127/2992
#    Procesando señal 1128/2992
#    Procesando señal 1129/2992
#    Procesando señal 1130/2992
#    Procesando señal 1131/2992
#    Procesando señal 1132/2992
#    Procesando señal 1133/2992
#    Procesando señal 1134/2992
#    Procesando señal 1135/2992
#    Procesando señal 1136/2992
#    Procesando señal 1137/2992
#    Procesando señal 1138/2992
#    Procesando señal 1139/2992
#    Procesando señal 1140/2992
#    Procesando señal 1141/2992
#    Procesando señal 1142/2992
#    Procesando señal 1143/2992
#    Procesando señal 1144/2992
#    Procesando señal 1145/2992
#    Procesando señal 1146/2992
#    Procesando señal 1147/2992
#    Procesando señal 1148/2992
#    Procesando señal 1149/2992
#    Procesando señal 1150/2992
#    Procesando señal 1151/2992
#    Procesando señal 1152/2992
#    Procesando señal 1153/2992
#    Procesando señal 1154/2992
#    Procesando señal 1155/2992
#    Procesando señal 1156/2992
#    Procesando señal 1157/2992
#    Procesando señal 1158/2992
#    Procesando señal 1159/2992
#    Procesando señal 1160/2992
#    Procesando señal 1161/2992
#    Procesando señal 1162/2992
#    Procesando señal 1163/2992
#    Procesando señal 1164/2992
#    Procesando señal 1165/2992
#    Procesando señal 1166/2992
#    Procesando señal 1167/2992
#    Procesando señal 1168/2992
#    Procesando señal 1169/2992
#    Procesando señal 1170/2992
#    Procesando señal 1171/2992
#    Procesando señal 1172/2992
#    Procesando señal 1173/2992
#    Procesando señal 1174/2992
#    Procesando señal 1175/2992
#    Procesando señal 1176/2992
#    Procesando señal 1177/2992
#    Procesando señal 1178/2992
#    Procesando señal 1179/2992
#    Procesando señal 1180/2992
#    Procesando señal 1181/2992
#    Procesando señal 1182/2992
#    Procesando señal 1183/2992
#    Procesando señal 1184/2992
#    Procesando señal 1185/2992
#    Procesando señal 1186/2992
#    Procesando señal 1187/2992
#    Procesando señal 1188/2992
#    Procesando señal 1189/2992
#    Procesando señal 1190/2992
#    Procesando señal 1191/2992
#    Procesando señal 1192/2992
#    Procesando señal 1193/2992
#    Procesando señal 1194/2992
#    Procesando señal 1195/2992
#    Procesando señal 1196/2992
#    Procesando señal 1197/2992
#    Procesando señal 1198/2992
#    Procesando señal 1199/2992
#    Procesando señal 1200/2992
#    Procesando señal 1201/2992
#    Procesando señal 1202/2992
#    Procesando señal 1203/2992
#    Procesando señal 1204/2992
#    Procesando señal 1205/2992
#    Procesando señal 1206/2992
#    Procesando señal 1207/2992
#    Procesando señal 1208/2992
#    Procesando señal 1209/2992
#    Procesando señal 1210/2992
#    Procesando señal 1211/2992
#    Procesando señal 1212/2992
#    Procesando señal 1213/2992
#    Procesando señal 1214/2992
#    Procesando señal 1215/2992
#    Procesando señal 1216/2992
#    Procesando señal 1217/2992
#    Procesando señal 1218/2992
#    Procesando señal 1219/2992
#    Procesando señal 1220/2992
#    Procesando señal 1221/2992
#    Procesando señal 1222/2992
#    Procesando señal 1223/2992
#    Procesando señal 1224/2992
#    Procesando señal 1225/2992
#    Procesando señal 1226/2992
#    Procesando señal 1227/2992
#    Procesando señal 1228/2992
#    Procesando señal 1229/2992
#    Procesando señal 1230/2992
#    Procesando señal 1231/2992
#    Procesando señal 1232/2992
#    Procesando señal 1233/2992
#    Procesando señal 1234/2992
#    Procesando señal 1235/2992
#    Procesando señal 1236/2992
#    Procesando señal 1237/2992
#    Procesando señal 1238/2992
#    Procesando señal 1239/2992
#    Procesando señal 1240/2992
#    Procesando señal 1241/2992
#    Procesando señal 1242/2992
#    Procesando señal 1243/2992
#    Procesando señal 1244/2992
#    Procesando señal 1245/2992
#    Procesando señal 1246/2992
#    Procesando señal 1247/2992
#    Procesando señal 1248/2992
#    Procesando señal 1249/2992
#    Procesando señal 1250/2992
#    Procesando señal 1251/2992
#    Procesando señal 1252/2992
#    Procesando señal 1253/2992
#    Procesando señal 1254/2992
#    Procesando señal 1255/2992
#    Procesando señal 1256/2992
#    Procesando señal 1257/2992
#    Procesando señal 1258/2992
#    Procesando señal 1259/2992
#    Procesando señal 1260/2992
#    Procesando señal 1261/2992
#    Procesando señal 1262/2992
#    Procesando señal 1263/2992
#    Procesando señal 1264/2992
#    Procesando señal 1265/2992
#    Procesando señal 1266/2992
#    Procesando señal 1267/2992
#    Procesando señal 1268/2992
#    Procesando señal 1269/2992
#    Procesando señal 1270/2992
#    Procesando señal 1271/2992
#    Procesando señal 1272/2992
#    Procesando señal 1273/2992
#    Procesando señal 1274/2992
#    Procesando señal 1275/2992
#    Procesando señal 1276/2992
#    Procesando señal 1277/2992
#    Procesando señal 1278/2992
#    Procesando señal 1279/2992
#    Procesando señal 1280/2992
#    Procesando señal 1281/2992
#    Procesando señal 1282/2992
#    Procesando señal 1283/2992
#    Procesando señal 1284/2992
#    Procesando señal 1285/2992
#    Procesando señal 1286/2992
#    Procesando señal 1287/2992
#    Procesando señal 1288/2992
#    Procesando señal 1289/2992
#    Procesando señal 1290/2992
#    Procesando señal 1291/2992
#    Procesando señal 1292/2992
#    Procesando señal 1293/2992
#    Procesando señal 1294/2992
#    Procesando señal 1295/2992
#    Procesando señal 1296/2992
#    Procesando señal 1297/2992
#    Procesando señal 1298/2992
#    Procesando señal 1299/2992
#    Procesando señal 1300/2992
#    Procesando señal 1301/2992
#    Procesando señal 1302/2992
#    Procesando señal 1303/2992
#    Procesando señal 1304/2992
#    Procesando señal 1305/2992
#    Procesando señal 1306/2992
#    Procesando señal 1307/2992
#    Procesando señal 1308/2992
#    Procesando señal 1309/2992
#    Procesando señal 1310/2992
#    Procesando señal 1311/2992
#    Procesando señal 1312/2992
#    Procesando señal 1313/2992
#    Procesando señal 1314/2992
#    Procesando señal 1315/2992
#    Procesando señal 1316/2992
#    Procesando señal 1317/2992
#    Procesando señal 1318/2992
#    Procesando señal 1319/2992
#    Procesando señal 1320/2992
#    Procesando señal 1321/2992
#    Procesando señal 1322/2992
#    Procesando señal 1323/2992
#    Procesando señal 1324/2992
#    Procesando señal 1325/2992
#    Procesando señal 1326/2992
#    Procesando señal 1327/2992
#    Procesando señal 1328/2992
#    Procesando señal 1329/2992
#    Procesando señal 1330/2992
#    Procesando señal 1331/2992
#    Procesando señal 1332/2992
#    Procesando señal 1333/2992
#    Procesando señal 1334/2992
#    Procesando señal 1335/2992
#    Procesando señal 1336/2992
#    Procesando señal 1337/2992
#    Procesando señal 1338/2992
#    Procesando señal 1339/2992
#    Procesando señal 1340/2992
#    Procesando señal 1341/2992
#    Procesando señal 1342/2992
#    Procesando señal 1343/2992
#    Procesando señal 1344/2992
#    Procesando señal 1345/2992
#    Procesando señal 1346/2992
#    Procesando señal 1347/2992
#    Procesando señal 1348/2992
#    Procesando señal 1349/2992
#    Procesando señal 1350/2992
#    Procesando señal 1351/2992
#    Procesando señal 1352/2992
#    Procesando señal 1353/2992
#    Procesando señal 1354/2992
#    Procesando señal 1355/2992
#    Procesando señal 1356/2992
#    Procesando señal 1357/2992
#    Procesando señal 1358/2992
#    Procesando señal 1359/2992
#    Procesando señal 1360/2992
#    Procesando señal 1361/2992
#    Procesando señal 1362/2992
#    Procesando señal 1363/2992
#    Procesando señal 1364/2992
#    Procesando señal 1365/2992
#    Procesando señal 1366/2992
#    Procesando señal 1367/2992
#    Procesando señal 1368/2992
#    Procesando señal 1369/2992
#    Procesando señal 1370/2992
#    Procesando señal 1371/2992
#    Procesando señal 1372/2992
#    Procesando señal 1373/2992
#    Procesando señal 1374/2992
#    Procesando señal 1375/2992
#    Procesando señal 1376/2992
#    Procesando señal 1377/2992
#    Procesando señal 1378/2992
#    Procesando señal 1379/2992
#    Procesando señal 1380/2992
#    Procesando señal 1381/2992
#    Procesando señal 1382/2992
#    Procesando señal 1383/2992
#    Procesando señal 1384/2992
#    Procesando señal 1385/2992
#    Procesando señal 1386/2992
#    Procesando señal 1387/2992
#    Procesando señal 1388/2992
#    Procesando señal 1389/2992
#    Procesando señal 1390/2992
#    Procesando señal 1391/2992
#    Procesando señal 1392/2992
#    Procesando señal 1393/2992
#    Procesando señal 1394/2992
#    Procesando señal 1395/2992
#    Procesando señal 1396/2992
#    Procesando señal 1397/2992
#    Procesando señal 1398/2992
#    Procesando señal 1399/2992
#    Procesando señal 1400/2992
#    Procesando señal 1401/2992
#    Procesando señal 1402/2992
#    Procesando señal 1403/2992
#    Procesando señal 1404/2992
#    Procesando señal 1405/2992
#    Procesando señal 1406/2992
#    Procesando señal 1407/2992
#    Procesando señal 1408/2992
#    Procesando señal 1409/2992
#    Procesando señal 1410/2992
#    Procesando señal 1411/2992
#    Procesando señal 1412/2992
#    Procesando señal 1413/2992
#    Procesando señal 1414/2992
#    Procesando señal 1415/2992
#    Procesando señal 1416/2992
#    Procesando señal 1417/2992
#    Procesando señal 1418/2992
#    Procesando señal 1419/2992
#    Procesando señal 1420/2992
#    Procesando señal 1421/2992
#    Procesando señal 1422/2992
#    Procesando señal 1423/2992
#    Procesando señal 1424/2992
#    Procesando señal 1425/2992
#    Procesando señal 1426/2992
#    Procesando señal 1427/2992
#    Procesando señal 1428/2992
#    Procesando señal 1429/2992
#    Procesando señal 1430/2992
#    Procesando señal 1431/2992
#    Procesando señal 1432/2992
#    Procesando señal 1433/2992
#    Procesando señal 1434/2992
#    Procesando señal 1435/2992
#    Procesando señal 1436/2992
#    Procesando señal 1437/2992
#    Procesando señal 1438/2992
#    Procesando señal 1439/2992
#    Procesando señal 1440/2992
#    Procesando señal 1441/2992
#    Procesando señal 1442/2992
#    Procesando señal 1443/2992
#    Procesando señal 1444/2992
#    Procesando señal 1445/2992
#    Procesando señal 1446/2992
#    Procesando señal 1447/2992
#    Procesando señal 1448/2992
#    Procesando señal 1449/2992
#    Procesando señal 1450/2992
#    Procesando señal 1451/2992
#    Procesando señal 1452/2992
#    Procesando señal 1453/2992
#    Procesando señal 1454/2992
#    Procesando señal 1455/2992
#    Procesando señal 1456/2992
#    Procesando señal 1457/2992
#    Procesando señal 1458/2992
#    Procesando señal 1459/2992
#    Procesando señal 1460/2992
#    Procesando señal 1461/2992
#    Procesando señal 1462/2992
#    Procesando señal 1463/2992
#    Procesando señal 1464/2992
#    Procesando señal 1465/2992
#    Procesando señal 1466/2992
#    Procesando señal 1467/2992
#    Procesando señal 1468/2992
#    Procesando señal 1469/2992
#    Procesando señal 1470/2992
#    Procesando señal 1471/2992
#    Procesando señal 1472/2992
#    Procesando señal 1473/2992
#    Procesando señal 1474/2992
#    Procesando señal 1475/2992
#    Procesando señal 1476/2992
#    Procesando señal 1477/2992
#    Procesando señal 1478/2992
#    Procesando señal 1479/2992
#    Procesando señal 1480/2992
#    Procesando señal 1481/2992
#    Procesando señal 1482/2992
#    Procesando señal 1483/2992
#    Procesando señal 1484/2992
#    Procesando señal 1485/2992
#    Procesando señal 1486/2992
#    Procesando señal 1487/2992
#    Procesando señal 1488/2992
#    Procesando señal 1489/2992
#    Procesando señal 1490/2992
#    Procesando señal 1491/2992
#    Procesando señal 1492/2992
#    Procesando señal 1493/2992
#    Procesando señal 1494/2992
#    Procesando señal 1495/2992
#    Procesando señal 1496/2992
#    Procesando señal 1497/2992
#    Procesando señal 1498/2992
#    Procesando señal 1499/2992
#    Procesando señal 1500/2992
#    Procesando señal 1501/2992
#    Procesando señal 1502/2992
#    Procesando señal 1503/2992
#    Procesando señal 1504/2992
#    Procesando señal 1505/2992
#    Procesando señal 1506/2992
#    Procesando señal 1507/2992
#    Procesando señal 1508/2992
#    Procesando señal 1509/2992
#    Procesando señal 1510/2992
#    Procesando señal 1511/2992
#    Procesando señal 1512/2992
#    Procesando señal 1513/2992
#    Procesando señal 1514/2992
#    Procesando señal 1515/2992
#    Procesando señal 1516/2992
#    Procesando señal 1517/2992
#    Procesando señal 1518/2992
#    Procesando señal 1519/2992
#    Procesando señal 1520/2992
#    Procesando señal 1521/2992
#    Procesando señal 1522/2992
#    Procesando señal 1523/2992
#    Procesando señal 1524/2992
#    Procesando señal 1525/2992
#    Procesando señal 1526/2992
#    Procesando señal 1527/2992
#    Procesando señal 1528/2992
#    Procesando señal 1529/2992
#    Procesando señal 1530/2992
#    Procesando señal 1531/2992
#    Procesando señal 1532/2992
#    Procesando señal 1533/2992
#    Procesando señal 1534/2992
#    Procesando señal 1535/2992
#    Procesando señal 1536/2992
#    Procesando señal 1537/2992
#    Procesando señal 1538/2992
#    Procesando señal 1539/2992
#    Procesando señal 1540/2992
#    Procesando señal 1541/2992
#    Procesando señal 1542/2992
#    Procesando señal 1543/2992
#    Procesando señal 1544/2992
#    Procesando señal 1545/2992
#    Procesando señal 1546/2992
#    Procesando señal 1547/2992
#    Procesando señal 1548/2992
#    Procesando señal 1549/2992
#    Procesando señal 1550/2992
#    Procesando señal 1551/2992
#    Procesando señal 1552/2992
#    Procesando señal 1553/2992
#    Procesando señal 1554/2992
#    Procesando señal 1555/2992
#    Procesando señal 1556/2992
#    Procesando señal 1557/2992
#    Procesando señal 1558/2992
#    Procesando señal 1559/2992
#    Procesando señal 1560/2992
#    Procesando señal 1561/2992
#    Procesando señal 1562/2992
#    Procesando señal 1563/2992
#    Procesando señal 1564/2992
#    Procesando señal 1565/2992
#    Procesando señal 1566/2992
#    Procesando señal 1567/2992
#    Procesando señal 1568/2992
#    Procesando señal 1569/2992
#    Procesando señal 1570/2992
#    Procesando señal 1571/2992
#    Procesando señal 1572/2992
#    Procesando señal 1573/2992
#    Procesando señal 1574/2992
#    Procesando señal 1575/2992
#    Procesando señal 1576/2992
#    Procesando señal 1577/2992
#    Procesando señal 1578/2992
#    Procesando señal 1579/2992
#    Procesando señal 1580/2992
#    Procesando señal 1581/2992
#    Procesando señal 1582/2992
#    Procesando señal 1583/2992
#    Procesando señal 1584/2992
#    Procesando señal 1585/2992
#    Procesando señal 1586/2992
#    Procesando señal 1587/2992
#    Procesando señal 1588/2992
#    Procesando señal 1589/2992
#    Procesando señal 1590/2992
#    Procesando señal 1591/2992
#    Procesando señal 1592/2992
#    Procesando señal 1593/2992
#    Procesando señal 1594/2992
#    Procesando señal 1595/2992
#    Procesando señal 1596/2992
#    Procesando señal 1597/2992
#    Procesando señal 1598/2992
#    Procesando señal 1599/2992
#    Procesando señal 1600/2992
#    Procesando señal 1601/2992
#    Procesando señal 1602/2992
#    Procesando señal 1603/2992
#    Procesando señal 1604/2992
#    Procesando señal 1605/2992
#    Procesando señal 1606/2992
#    Procesando señal 1607/2992
#    Procesando señal 1608/2992
#    Procesando señal 1609/2992
#    Procesando señal 1610/2992
#    Procesando señal 1611/2992
#    Procesando señal 1612/2992
#    Procesando señal 1613/2992
#    Procesando señal 1614/2992
#    Procesando señal 1615/2992
#    Procesando señal 1616/2992
#    Procesando señal 1617/2992
#    Procesando señal 1618/2992
#    Procesando señal 1619/2992
#    Procesando señal 1620/2992
#    Procesando señal 1621/2992
#    Procesando señal 1622/2992
#    Procesando señal 1623/2992
#    Procesando señal 1624/2992
#    Procesando señal 1625/2992
#    Procesando señal 1626/2992
#    Procesando señal 1627/2992
#    Procesando señal 1628/2992
#    Procesando señal 1629/2992
#    Procesando señal 1630/2992
#    Procesando señal 1631/2992
#    Procesando señal 1632/2992
#    Procesando señal 1633/2992
#    Procesando señal 1634/2992
#    Procesando señal 1635/2992
#    Procesando señal 1636/2992
#    Procesando señal 1637/2992
#    Procesando señal 1638/2992
#    Procesando señal 1639/2992
#    Procesando señal 1640/2992
#    Procesando señal 1641/2992
#    Procesando señal 1642/2992
#    Procesando señal 1643/2992
#    Procesando señal 1644/2992
#    Procesando señal 1645/2992
#    Procesando señal 1646/2992
#    Procesando señal 1647/2992
#    Procesando señal 1648/2992
#    Procesando señal 1649/2992
#    Procesando señal 1650/2992
#    Procesando señal 1651/2992
#    Procesando señal 1652/2992
#    Procesando señal 1653/2992
#    Procesando señal 1654/2992
#    Procesando señal 1655/2992
#    Procesando señal 1656/2992
#    Procesando señal 1657/2992
#    Procesando señal 1658/2992
#    Procesando señal 1659/2992
#    Procesando señal 1660/2992
#    Procesando señal 1661/2992
#    Procesando señal 1662/2992
#    Procesando señal 1663/2992
#    Procesando señal 1664/2992
#    Procesando señal 1665/2992
#    Procesando señal 1666/2992
#    Procesando señal 1667/2992
#    Procesando señal 1668/2992
#    Procesando señal 1669/2992
#    Procesando señal 1670/2992
#    Procesando señal 1671/2992
#    Procesando señal 1672/2992
#    Procesando señal 1673/2992
#    Procesando señal 1674/2992
#    Procesando señal 1675/2992
#    Procesando señal 1676/2992
#    Procesando señal 1677/2992
#    Procesando señal 1678/2992
#    Procesando señal 1679/2992
#    Procesando señal 1680/2992
#    Procesando señal 1681/2992
#    Procesando señal 1682/2992
#    Procesando señal 1683/2992
#    Procesando señal 1684/2992
#    Procesando señal 1685/2992
#    Procesando señal 1686/2992
#    Procesando señal 1687/2992
#    Procesando señal 1688/2992
#    Procesando señal 1689/2992
#    Procesando señal 1690/2992
#    Procesando señal 1691/2992
#    Procesando señal 1692/2992
#    Procesando señal 1693/2992
#    Procesando señal 1694/2992
#    Procesando señal 1695/2992
#    Procesando señal 1696/2992
#    Procesando señal 1697/2992
#    Procesando señal 1698/2992
#    Procesando señal 1699/2992
#    Procesando señal 1700/2992
#    Procesando señal 1701/2992
#    Procesando señal 1702/2992
#    Procesando señal 1703/2992
#    Procesando señal 1704/2992
#    Procesando señal 1705/2992
#    Procesando señal 1706/2992
#    Procesando señal 1707/2992
#    Procesando señal 1708/2992
#    Procesando señal 1709/2992
#    Procesando señal 1710/2992
#    Procesando señal 1711/2992
#    Procesando señal 1712/2992
#    Procesando señal 1713/2992
#    Procesando señal 1714/2992
#    Procesando señal 1715/2992
#    Procesando señal 1716/2992
#    Procesando señal 1717/2992
#    Procesando señal 1718/2992
#    Procesando señal 1719/2992
#    Procesando señal 1720/2992
#    Procesando señal 1721/2992
#    Procesando señal 1722/2992
#    Procesando señal 1723/2992
#    Procesando señal 1724/2992
#    Procesando señal 1725/2992
#    Procesando señal 1726/2992
#    Procesando señal 1727/2992
#    Procesando señal 1728/2992
#    Procesando señal 1729/2992
#    Procesando señal 1730/2992
#    Procesando señal 1731/2992
#    Procesando señal 1732/2992
#    Procesando señal 1733/2992
#    Procesando señal 1734/2992
#    Procesando señal 1735/2992
#    Procesando señal 1736/2992
#    Procesando señal 1737/2992
#    Procesando señal 1738/2992
#    Procesando señal 1739/2992
#    Procesando señal 1740/2992
#    Procesando señal 1741/2992
#    Procesando señal 1742/2992
#    Procesando señal 1743/2992
#    Procesando señal 1744/2992
#    Procesando señal 1745/2992
#    Procesando señal 1746/2992
#    Procesando señal 1747/2992
#    Procesando señal 1748/2992
#    Procesando señal 1749/2992
#    Procesando señal 1750/2992
#    Procesando señal 1751/2992
#    Procesando señal 1752/2992
#    Procesando señal 1753/2992
#    Procesando señal 1754/2992
#    Procesando señal 1755/2992
#    Procesando señal 1756/2992
#    Procesando señal 1757/2992
#    Procesando señal 1758/2992
#    Procesando señal 1759/2992
#    Procesando señal 1760/2992
#    Procesando señal 1761/2992
#    Procesando señal 1762/2992
#    Procesando señal 1763/2992
#    Procesando señal 1764/2992
#    Procesando señal 1765/2992
#    Procesando señal 1766/2992
#    Procesando señal 1767/2992
#    Procesando señal 1768/2992
#    Procesando señal 1769/2992
#    Procesando señal 1770/2992
#    Procesando señal 1771/2992
#    Procesando señal 1772/2992
#    Procesando señal 1773/2992
#    Procesando señal 1774/2992
#    Procesando señal 1775/2992
#    Procesando señal 1776/2992
#    Procesando señal 1777/2992
#    Procesando señal 1778/2992
#    Procesando señal 1779/2992
#    Procesando señal 1780/2992
#    Procesando señal 1781/2992
#    Procesando señal 1782/2992
#    Procesando señal 1783/2992
#    Procesando señal 1784/2992
#    Procesando señal 1785/2992
#    Procesando señal 1786/2992
#    Procesando señal 1787/2992
#    Procesando señal 1788/2992
#    Procesando señal 1789/2992
#    Procesando señal 1790/2992
#    Procesando señal 1791/2992
#    Procesando señal 1792/2992
#    Procesando señal 1793/2992
#    Procesando señal 1794/2992
#    Procesando señal 1795/2992
#    Procesando señal 1796/2992
#    Procesando señal 1797/2992
#    Procesando señal 1798/2992
#    Procesando señal 1799/2992
#    Procesando señal 1800/2992
#    Procesando señal 1801/2992
#    Procesando señal 1802/2992
#    Procesando señal 1803/2992
#    Procesando señal 1804/2992
#    Procesando señal 1805/2992
#    Procesando señal 1806/2992
#    Procesando señal 1807/2992
#    Procesando señal 1808/2992
#    Procesando señal 1809/2992
#    Procesando señal 1810/2992
#    Procesando señal 1811/2992
#    Procesando señal 1812/2992
#    Procesando señal 1813/2992
#    Procesando señal 1814/2992
#    Procesando señal 1815/2992
#    Procesando señal 1816/2992
#    Procesando señal 1817/2992
#    Procesando señal 1818/2992
#    Procesando señal 1819/2992
#    Procesando señal 1820/2992
#    Procesando señal 1821/2992
#    Procesando señal 1822/2992
#    Procesando señal 1823/2992
#    Procesando señal 1824/2992
#    Procesando señal 1825/2992
#    Procesando señal 1826/2992
#    Procesando señal 1827/2992
#    Procesando señal 1828/2992
#    Procesando señal 1829/2992
#    Procesando señal 1830/2992
#    Procesando señal 1831/2992
#    Procesando señal 1832/2992
#    Procesando señal 1833/2992
#    Procesando señal 1834/2992
#    Procesando señal 1835/2992
#    Procesando señal 1836/2992
#    Procesando señal 1837/2992
#    Procesando señal 1838/2992
#    Procesando señal 1839/2992
#    Procesando señal 1840/2992
#    Procesando señal 1841/2992
#    Procesando señal 1842/2992
#    Procesando señal 1843/2992
#    Procesando señal 1844/2992
#    Procesando señal 1845/2992
#    Procesando señal 1846/2992
#    Procesando señal 1847/2992
#    Procesando señal 1848/2992
#    Procesando señal 1849/2992
#    Procesando señal 1850/2992
#    Procesando señal 1851/2992
#    Procesando señal 1852/2992
#    Procesando señal 1853/2992
#    Procesando señal 1854/2992
#    Procesando señal 1855/2992
#    Procesando señal 1856/2992
#    Procesando señal 1857/2992
#    Procesando señal 1858/2992
#    Procesando señal 1859/2992
#    Procesando señal 1860/2992
#    Procesando señal 1861/2992
#    Procesando señal 1862/2992
#    Procesando señal 1863/2992
#    Procesando señal 1864/2992
#    Procesando señal 1865/2992
#    Procesando señal 1866/2992
#    Procesando señal 1867/2992
#    Procesando señal 1868/2992
#    Procesando señal 1869/2992
#    Procesando señal 1870/2992
#    Procesando señal 1871/2992
#    Procesando señal 1872/2992
#    Procesando señal 1873/2992
#    Procesando señal 1874/2992
#    Procesando señal 1875/2992
#    Procesando señal 1876/2992
#    Procesando señal 1877/2992
#    Procesando señal 1878/2992
#    Procesando señal 1879/2992
#    Procesando señal 1880/2992
#    Procesando señal 1881/2992
#    Procesando señal 1882/2992
#    Procesando señal 1883/2992
#    Procesando señal 1884/2992
#    Procesando señal 1885/2992
#    Procesando señal 1886/2992
#    Procesando señal 1887/2992
#    Procesando señal 1888/2992
#    Procesando señal 1889/2992
#    Procesando señal 1890/2992
#    Procesando señal 1891/2992
#    Procesando señal 1892/2992
#    Procesando señal 1893/2992
#    Procesando señal 1894/2992
#    Procesando señal 1895/2992
#    Procesando señal 1896/2992
#    Procesando señal 1897/2992
#    Procesando señal 1898/2992
#    Procesando señal 1899/2992
#    Procesando señal 1900/2992
#    Procesando señal 1901/2992
#    Procesando señal 1902/2992
#    Procesando señal 1903/2992
#    Procesando señal 1904/2992
#    Procesando señal 1905/2992
#    Procesando señal 1906/2992
#    Procesando señal 1907/2992
#    Procesando señal 1908/2992
#    Procesando señal 1909/2992
#    Procesando señal 1910/2992
#    Procesando señal 1911/2992
#    Procesando señal 1912/2992
#    Procesando señal 1913/2992
#    Procesando señal 1914/2992
#    Procesando señal 1915/2992
#    Procesando señal 1916/2992
#    Procesando señal 1917/2992
#    Procesando señal 1918/2992
#    Procesando señal 1919/2992
#    Procesando señal 1920/2992
#    Procesando señal 1921/2992
#    Procesando señal 1922/2992
#    Procesando señal 1923/2992
#    Procesando señal 1924/2992
#    Procesando señal 1925/2992
#    Procesando señal 1926/2992
#    Procesando señal 1927/2992
#    Procesando señal 1928/2992
#    Procesando señal 1929/2992
#    Procesando señal 1930/2992
#    Procesando señal 1931/2992
#    Procesando señal 1932/2992
#    Procesando señal 1933/2992
#    Procesando señal 1934/2992
#    Procesando señal 1935/2992
#    Procesando señal 1936/2992
#    Procesando señal 1937/2992
#    Procesando señal 1938/2992
#    Procesando señal 1939/2992
#    Procesando señal 1940/2992
#    Procesando señal 1941/2992
#    Procesando señal 1942/2992
#    Procesando señal 1943/2992
#    Procesando señal 1944/2992
#    Procesando señal 1945/2992
#    Procesando señal 1946/2992
#    Procesando señal 1947/2992
#    Procesando señal 1948/2992
#    Procesando señal 1949/2992
#    Procesando señal 1950/2992
#    Procesando señal 1951/2992
#    Procesando señal 1952/2992
#    Procesando señal 1953/2992
#    Procesando señal 1954/2992
#    Procesando señal 1955/2992
#    Procesando señal 1956/2992
#    Procesando señal 1957/2992
#    Procesando señal 1958/2992
#    Procesando señal 1959/2992
#    Procesando señal 1960/2992
#    Procesando señal 1961/2992
#    Procesando señal 1962/2992
#    Procesando señal 1963/2992
#    Procesando señal 1964/2992
#    Procesando señal 1965/2992
#    Procesando señal 1966/2992
#    Procesando señal 1967/2992
#    Procesando señal 1968/2992
#    Procesando señal 1969/2992
#    Procesando señal 1970/2992
#    Procesando señal 1971/2992
#    Procesando señal 1972/2992
#    Procesando señal 1973/2992
#    Procesando señal 1974/2992
#    Procesando señal 1975/2992
#    Procesando señal 1976/2992
#    Procesando señal 1977/2992
#    Procesando señal 1978/2992
#    Procesando señal 1979/2992
#    Procesando señal 1980/2992
#    Procesando señal 1981/2992
#    Procesando señal 1982/2992
#    Procesando señal 1983/2992
#    Procesando señal 1984/2992
#    Procesando señal 1985/2992
#    Procesando señal 1986/2992
#    Procesando señal 1987/2992
#    Procesando señal 1988/2992
#    Procesando señal 1989/2992
#    Procesando señal 1990/2992
#    Procesando señal 1991/2992
#    Procesando señal 1992/2992
#    Procesando señal 1993/2992
#    Procesando señal 1994/2992
#    Procesando señal 1995/2992
#    Procesando señal 1996/2992
#    Procesando señal 1997/2992
#    Procesando señal 1998/2992
#    Procesando señal 1999/2992
#    Procesando señal 2000/2992
#    Procesando señal 2001/2992
#    Procesando señal 2002/2992
#    Procesando señal 2003/2992
#    Procesando señal 2004/2992
#    Procesando señal 2005/2992
#    Procesando señal 2006/2992
#    Procesando señal 2007/2992
#    Procesando señal 2008/2992
#    Procesando señal 2009/2992
#    Procesando señal 2010/2992
#    Procesando señal 2011/2992
#    Procesando señal 2012/2992
#    Procesando señal 2013/2992
#    Procesando señal 2014/2992
#    Procesando señal 2015/2992
#    Procesando señal 2016/2992
#    Procesando señal 2017/2992
#    Procesando señal 2018/2992
#    Procesando señal 2019/2992
#    Procesando señal 2020/2992
#    Procesando señal 2021/2992
#    Procesando señal 2022/2992
#    Procesando señal 2023/2992
#    Procesando señal 2024/2992
#    Procesando señal 2025/2992
#    Procesando señal 2026/2992
#    Procesando señal 2027/2992
#    Procesando señal 2028/2992
#    Procesando señal 2029/2992
#    Procesando señal 2030/2992
#    Procesando señal 2031/2992
#    Procesando señal 2032/2992
#    Procesando señal 2033/2992
#    Procesando señal 2034/2992
#    Procesando señal 2035/2992
#    Procesando señal 2036/2992
#    Procesando señal 2037/2992
#    Procesando señal 2038/2992
#    Procesando señal 2039/2992
#    Procesando señal 2040/2992
#    Procesando señal 2041/2992
#    Procesando señal 2042/2992
#    Procesando señal 2043/2992
#    Procesando señal 2044/2992
#    Procesando señal 2045/2992
#    Procesando señal 2046/2992
#    Procesando señal 2047/2992
#    Procesando señal 2048/2992
#    Procesando señal 2049/2992
#    Procesando señal 2050/2992
#    Procesando señal 2051/2992
#    Procesando señal 2052/2992
#    Procesando señal 2053/2992
#    Procesando señal 2054/2992
#    Procesando señal 2055/2992
#    Procesando señal 2056/2992
#    Procesando señal 2057/2992
#    Procesando señal 2058/2992
#    Procesando señal 2059/2992
#    Procesando señal 2060/2992
#    Procesando señal 2061/2992
#    Procesando señal 2062/2992
#    Procesando señal 2063/2992
#    Procesando señal 2064/2992
#    Procesando señal 2065/2992
#    Procesando señal 2066/2992
#    Procesando señal 2067/2992
#    Procesando señal 2068/2992
#    Procesando señal 2069/2992
#    Procesando señal 2070/2992
#    Procesando señal 2071/2992
#    Procesando señal 2072/2992
#    Procesando señal 2073/2992
#    Procesando señal 2074/2992
#    Procesando señal 2075/2992
#    Procesando señal 2076/2992
#    Procesando señal 2077/2992
#    Procesando señal 2078/2992
#    Procesando señal 2079/2992
#    Procesando señal 2080/2992
#    Procesando señal 2081/2992
#    Procesando señal 2082/2992
#    Procesando señal 2083/2992
#    Procesando señal 2084/2992
#    Procesando señal 2085/2992
#    Procesando señal 2086/2992
#    Procesando señal 2087/2992
#    Procesando señal 2088/2992
#    Procesando señal 2089/2992
#    Procesando señal 2090/2992
#    Procesando señal 2091/2992
#    Procesando señal 2092/2992
#    Procesando señal 2093/2992
#    Procesando señal 2094/2992
#    Procesando señal 2095/2992
#    Procesando señal 2096/2992
#    Procesando señal 2097/2992
#    Procesando señal 2098/2992
#    Procesando señal 2099/2992
#    Procesando señal 2100/2992
#    Procesando señal 2101/2992
#    Procesando señal 2102/2992
#    Procesando señal 2103/2992
#    Procesando señal 2104/2992
#    Procesando señal 2105/2992
#    Procesando señal 2106/2992
#    Procesando señal 2107/2992
#    Procesando señal 2108/2992
#    Procesando señal 2109/2992
#    Procesando señal 2110/2992
#    Procesando señal 2111/2992
#    Procesando señal 2112/2992
#    Procesando señal 2113/2992
#    Procesando señal 2114/2992
#    Procesando señal 2115/2992
#    Procesando señal 2116/2992
#    Procesando señal 2117/2992
#    Procesando señal 2118/2992
#    Procesando señal 2119/2992
#    Procesando señal 2120/2992
#    Procesando señal 2121/2992
#    Procesando señal 2122/2992
#    Procesando señal 2123/2992
#    Procesando señal 2124/2992
#    Procesando señal 2125/2992
#    Procesando señal 2126/2992
#    Procesando señal 2127/2992
#    Procesando señal 2128/2992
#    Procesando señal 2129/2992
#    Procesando señal 2130/2992
#    Procesando señal 2131/2992
#    Procesando señal 2132/2992
#    Procesando señal 2133/2992
#    Procesando señal 2134/2992
#    Procesando señal 2135/2992
#    Procesando señal 2136/2992
#    Procesando señal 2137/2992
#    Procesando señal 2138/2992
#    Procesando señal 2139/2992
#    Procesando señal 2140/2992
#    Procesando señal 2141/2992
#    Procesando señal 2142/2992
#    Procesando señal 2143/2992
#    Procesando señal 2144/2992
#    Procesando señal 2145/2992
#    Procesando señal 2146/2992
#    Procesando señal 2147/2992
#    Procesando señal 2148/2992
#    Procesando señal 2149/2992
#    Procesando señal 2150/2992
#    Procesando señal 2151/2992
#    Procesando señal 2152/2992
#    Procesando señal 2153/2992
#    Procesando señal 2154/2992
#    Procesando señal 2155/2992
#    Procesando señal 2156/2992
#    Procesando señal 2157/2992
#    Procesando señal 2158/2992
#    Procesando señal 2159/2992
#    Procesando señal 2160/2992
#    Procesando señal 2161/2992
#    Procesando señal 2162/2992
#    Procesando señal 2163/2992
#    Procesando señal 2164/2992
#    Procesando señal 2165/2992
#    Procesando señal 2166/2992
#    Procesando señal 2167/2992
#    Procesando señal 2168/2992
#    Procesando señal 2169/2992
#    Procesando señal 2170/2992
#    Procesando señal 2171/2992
#    Procesando señal 2172/2992
#    Procesando señal 2173/2992
#    Procesando señal 2174/2992
#    Procesando señal 2175/2992
#    Procesando señal 2176/2992
#    Procesando señal 2177/2992
#    Procesando señal 2178/2992
#    Procesando señal 2179/2992
#    Procesando señal 2180/2992
#    Procesando señal 2181/2992
#    Procesando señal 2182/2992
#    Procesando señal 2183/2992
#    Procesando señal 2184/2992
#    Procesando señal 2185/2992
#    Procesando señal 2186/2992
#    Procesando señal 2187/2992
#    Procesando señal 2188/2992
#    Procesando señal 2189/2992
#    Procesando señal 2190/2992
#    Procesando señal 2191/2992
#    Procesando señal 2192/2992
#    Procesando señal 2193/2992
#    Procesando señal 2194/2992
#    Procesando señal 2195/2992
#    Procesando señal 2196/2992
#    Procesando señal 2197/2992
#    Procesando señal 2198/2992
#    Procesando señal 2199/2992
#    Procesando señal 2200/2992
#    Procesando señal 2201/2992
#    Procesando señal 2202/2992
#    Procesando señal 2203/2992
#    Procesando señal 2204/2992
#    Procesando señal 2205/2992
#    Procesando señal 2206/2992
#    Procesando señal 2207/2992
#    Procesando señal 2208/2992
#    Procesando señal 2209/2992
#    Procesando señal 2210/2992
#    Procesando señal 2211/2992
#    Procesando señal 2212/2992
#    Procesando señal 2213/2992
#    Procesando señal 2214/2992
#    Procesando señal 2215/2992
#    Procesando señal 2216/2992
#    Procesando señal 2217/2992
#    Procesando señal 2218/2992
#    Procesando señal 2219/2992
#    Procesando señal 2220/2992
#    Procesando señal 2221/2992
#    Procesando señal 2222/2992
#    Procesando señal 2223/2992
#    Procesando señal 2224/2992
#    Procesando señal 2225/2992
#    Procesando señal 2226/2992
#    Procesando señal 2227/2992
#    Procesando señal 2228/2992
#    Procesando señal 2229/2992
#    Procesando señal 2230/2992
#    Procesando señal 2231/2992
#    Procesando señal 2232/2992
#    Procesando señal 2233/2992
#    Procesando señal 2234/2992
#    Procesando señal 2235/2992
#    Procesando señal 2236/2992
#    Procesando señal 2237/2992
#    Procesando señal 2238/2992
#    Procesando señal 2239/2992
#    Procesando señal 2240/2992
#    Procesando señal 2241/2992
#    Procesando señal 2242/2992
#    Procesando señal 2243/2992
#    Procesando señal 2244/2992
#    Procesando señal 2245/2992
#    Procesando señal 2246/2992
#    Procesando señal 2247/2992
#    Procesando señal 2248/2992
#    Procesando señal 2249/2992
#    Procesando señal 2250/2992
#    Procesando señal 2251/2992
#    Procesando señal 2252/2992
#    Procesando señal 2253/2992
#    Procesando señal 2254/2992
#    Procesando señal 2255/2992
#    Procesando señal 2256/2992
#    Procesando señal 2257/2992
#    Procesando señal 2258/2992
#    Procesando señal 2259/2992
#    Procesando señal 2260/2992
#    Procesando señal 2261/2992
#    Procesando señal 2262/2992
#    Procesando señal 2263/2992
#    Procesando señal 2264/2992
#    Procesando señal 2265/2992
#    Procesando señal 2266/2992
#    Procesando señal 2267/2992
#    Procesando señal 2268/2992
#    Procesando señal 2269/2992
#    Procesando señal 2270/2992
#    Procesando señal 2271/2992
#    Procesando señal 2272/2992
#    Procesando señal 2273/2992
#    Procesando señal 2274/2992
#    Procesando señal 2275/2992
#    Procesando señal 2276/2992
#    Procesando señal 2277/2992
#    Procesando señal 2278/2992
#    Procesando señal 2279/2992
#    Procesando señal 2280/2992
#    Procesando señal 2281/2992
#    Procesando señal 2282/2992
#    Procesando señal 2283/2992
#    Procesando señal 2284/2992
#    Procesando señal 2285/2992
#    Procesando señal 2286/2992
#    Procesando señal 2287/2992
#    Procesando señal 2288/2992
#    Procesando señal 2289/2992
#    Procesando señal 2290/2992
#    Procesando señal 2291/2992
#    Procesando señal 2292/2992
#    Procesando señal 2293/2992
#    Procesando señal 2294/2992
#    Procesando señal 2295/2992
#    Procesando señal 2296/2992
#    Procesando señal 2297/2992
#    Procesando señal 2298/2992
#    Procesando señal 2299/2992
#    Procesando señal 2300/2992
#    Procesando señal 2301/2992
#    Procesando señal 2302/2992
#    Procesando señal 2303/2992
#    Procesando señal 2304/2992
#    Procesando señal 2305/2992
#    Procesando señal 2306/2992
#    Procesando señal 2307/2992
#    Procesando señal 2308/2992
#    Procesando señal 2309/2992
#    Procesando señal 2310/2992
#    Procesando señal 2311/2992
#    Procesando señal 2312/2992
#    Procesando señal 2313/2992
#    Procesando señal 2314/2992
#    Procesando señal 2315/2992
#    Procesando señal 2316/2992
#    Procesando señal 2317/2992
#    Procesando señal 2318/2992
#    Procesando señal 2319/2992
#    Procesando señal 2320/2992
#    Procesando señal 2321/2992
#    Procesando señal 2322/2992
#    Procesando señal 2323/2992
#    Procesando señal 2324/2992
#    Procesando señal 2325/2992
#    Procesando señal 2326/2992
#    Procesando señal 2327/2992
#    Procesando señal 2328/2992
#    Procesando señal 2329/2992
#    Procesando señal 2330/2992
#    Procesando señal 2331/2992
#    Procesando señal 2332/2992
#    Procesando señal 2333/2992
#    Procesando señal 2334/2992
#    Procesando señal 2335/2992
#    Procesando señal 2336/2992
#    Procesando señal 2337/2992
#    Procesando señal 2338/2992
#    Procesando señal 2339/2992
#    Procesando señal 2340/2992
#    Procesando señal 2341/2992
#    Procesando señal 2342/2992
#    Procesando señal 2343/2992
#    Procesando señal 2344/2992
#    Procesando señal 2345/2992
#    Procesando señal 2346/2992
#    Procesando señal 2347/2992
#    Procesando señal 2348/2992
#    Procesando señal 2349/2992
#    Procesando señal 2350/2992
#    Procesando señal 2351/2992
#    Procesando señal 2352/2992
#    Procesando señal 2353/2992
#    Procesando señal 2354/2992
#    Procesando señal 2355/2992
#    Procesando señal 2356/2992
#    Procesando señal 2357/2992
#    Procesando señal 2358/2992
#    Procesando señal 2359/2992
#    Procesando señal 2360/2992
#    Procesando señal 2361/2992
#    Procesando señal 2362/2992
#    Procesando señal 2363/2992
#    Procesando señal 2364/2992
#    Procesando señal 2365/2992
#    Procesando señal 2366/2992
#    Procesando señal 2367/2992
#    Procesando señal 2368/2992
#    Procesando señal 2369/2992
#    Procesando señal 2370/2992
#    Procesando señal 2371/2992
#    Procesando señal 2372/2992
#    Procesando señal 2373/2992
#    Procesando señal 2374/2992
#    Procesando señal 2375/2992
#    Procesando señal 2376/2992
#    Procesando señal 2377/2992
#    Procesando señal 2378/2992
#    Procesando señal 2379/2992
#    Procesando señal 2380/2992
#    Procesando señal 2381/2992
#    Procesando señal 2382/2992
#    Procesando señal 2383/2992
#    Procesando señal 2384/2992
#    Procesando señal 2385/2992
#    Procesando señal 2386/2992
#    Procesando señal 2387/2992
#    Procesando señal 2388/2992
#    Procesando señal 2389/2992
#    Procesando señal 2390/2992
#    Procesando señal 2391/2992
#    Procesando señal 2392/2992
#    Procesando señal 2393/2992
#    Procesando señal 2394/2992
#    Procesando señal 2395/2992
#    Procesando señal 2396/2992
#    Procesando señal 2397/2992
#    Procesando señal 2398/2992
#    Procesando señal 2399/2992
#    Procesando señal 2400/2992
#    Procesando señal 2401/2992
#    Procesando señal 2402/2992
#    Procesando señal 2403/2992
#    Procesando señal 2404/2992
#    Procesando señal 2405/2992
#    Procesando señal 2406/2992
#    Procesando señal 2407/2992
#    Procesando señal 2408/2992
#    Procesando señal 2409/2992
#    Procesando señal 2410/2992
#    Procesando señal 2411/2992
#    Procesando señal 2412/2992
#    Procesando señal 2413/2992
#    Procesando señal 2414/2992
#    Procesando señal 2415/2992
#    Procesando señal 2416/2992
#    Procesando señal 2417/2992
#    Procesando señal 2418/2992
#    Procesando señal 2419/2992
#    Procesando señal 2420/2992
#    Procesando señal 2421/2992
#    Procesando señal 2422/2992
#    Procesando señal 2423/2992
#    Procesando señal 2424/2992
#    Procesando señal 2425/2992
#    Procesando señal 2426/2992
#    Procesando señal 2427/2992
#    Procesando señal 2428/2992
#    Procesando señal 2429/2992
#    Procesando señal 2430/2992
#    Procesando señal 2431/2992
#    Procesando señal 2432/2992
#    Procesando señal 2433/2992
#    Procesando señal 2434/2992
#    Procesando señal 2435/2992
#    Procesando señal 2436/2992
#    Procesando señal 2437/2992
#    Procesando señal 2438/2992
#    Procesando señal 2439/2992
#    Procesando señal 2440/2992
#    Procesando señal 2441/2992
#    Procesando señal 2442/2992
#    Procesando señal 2443/2992
#    Procesando señal 2444/2992
#    Procesando señal 2445/2992
#    Procesando señal 2446/2992
#    Procesando señal 2447/2992
#    Procesando señal 2448/2992
#    Procesando señal 2449/2992
#    Procesando señal 2450/2992
#    Procesando señal 2451/2992
#    Procesando señal 2452/2992
#    Procesando señal 2453/2992
#    Procesando señal 2454/2992
#    Procesando señal 2455/2992
#    Procesando señal 2456/2992
#    Procesando señal 2457/2992
#    Procesando señal 2458/2992
#    Procesando señal 2459/2992
#    Procesando señal 2460/2992
#    Procesando señal 2461/2992
#    Procesando señal 2462/2992
#    Procesando señal 2463/2992
#    Procesando señal 2464/2992
#    Procesando señal 2465/2992
#    Procesando señal 2466/2992
#    Procesando señal 2467/2992
#    Procesando señal 2468/2992
#    Procesando señal 2469/2992
#    Procesando señal 2470/2992
#    Procesando señal 2471/2992
#    Procesando señal 2472/2992
#    Procesando señal 2473/2992
#    Procesando señal 2474/2992
#    Procesando señal 2475/2992
#    Procesando señal 2476/2992
#    Procesando señal 2477/2992
#    Procesando señal 2478/2992
#    Procesando señal 2479/2992
#    Procesando señal 2480/2992
#    Procesando señal 2481/2992
#    Procesando señal 2482/2992
#    Procesando señal 2483/2992
#    Procesando señal 2484/2992
#    Procesando señal 2485/2992
#    Procesando señal 2486/2992
#    Procesando señal 2487/2992
#    Procesando señal 2488/2992
#    Procesando señal 2489/2992
#    Procesando señal 2490/2992
#    Procesando señal 2491/2992
#    Procesando señal 2492/2992
#    Procesando señal 2493/2992
#    Procesando señal 2494/2992
#    Procesando señal 2495/2992
#    Procesando señal 2496/2992
#    Procesando señal 2497/2992
#    Procesando señal 2498/2992
#    Procesando señal 2499/2992
#    Procesando señal 2500/2992
#    Procesando señal 2501/2992
#    Procesando señal 2502/2992
#    Procesando señal 2503/2992
#    Procesando señal 2504/2992
#    Procesando señal 2505/2992
#    Procesando señal 2506/2992
#    Procesando señal 2507/2992
#    Procesando señal 2508/2992
#    Procesando señal 2509/2992
#    Procesando señal 2510/2992
#    Procesando señal 2511/2992
#    Procesando señal 2512/2992
#    Procesando señal 2513/2992
#    Procesando señal 2514/2992
#    Procesando señal 2515/2992
#    Procesando señal 2516/2992
#    Procesando señal 2517/2992
#    Procesando señal 2518/2992
#    Procesando señal 2519/2992
#    Procesando señal 2520/2992
#    Procesando señal 2521/2992
#    Procesando señal 2522/2992
#    Procesando señal 2523/2992
#    Procesando señal 2524/2992
#    Procesando señal 2525/2992
#    Procesando señal 2526/2992
#    Procesando señal 2527/2992
#    Procesando señal 2528/2992
#    Procesando señal 2529/2992
#    Procesando señal 2530/2992
#    Procesando señal 2531/2992
#    Procesando señal 2532/2992
#    Procesando señal 2533/2992
#    Procesando señal 2534/2992
#    Procesando señal 2535/2992
#    Procesando señal 2536/2992
#    Procesando señal 2537/2992
#    Procesando señal 2538/2992
#    Procesando señal 2539/2992
#    Procesando señal 2540/2992
#    Procesando señal 2541/2992
#    Procesando señal 2542/2992
#    Procesando señal 2543/2992
#    Procesando señal 2544/2992
#    Procesando señal 2545/2992
#    Procesando señal 2546/2992
#    Procesando señal 2547/2992
#    Procesando señal 2548/2992
#    Procesando señal 2549/2992
#    Procesando señal 2550/2992
#    Procesando señal 2551/2992
#    Procesando señal 2552/2992
#    Procesando señal 2553/2992
#    Procesando señal 2554/2992
#    Procesando señal 2555/2992
#    Procesando señal 2556/2992
#    Procesando señal 2557/2992
#    Procesando señal 2558/2992
#    Procesando señal 2559/2992
#    Procesando señal 2560/2992
#    Procesando señal 2561/2992
#    Procesando señal 2562/2992
#    Procesando señal 2563/2992
#    Procesando señal 2564/2992
#    Procesando señal 2565/2992
#    Procesando señal 2566/2992
#    Procesando señal 2567/2992
#    Procesando señal 2568/2992
#    Procesando señal 2569/2992
#    Procesando señal 2570/2992
#    Procesando señal 2571/2992
#    Procesando señal 2572/2992
#    Procesando señal 2573/2992
#    Procesando señal 2574/2992
#    Procesando señal 2575/2992
#    Procesando señal 2576/2992
#    Procesando señal 2577/2992
#    Procesando señal 2578/2992
#    Procesando señal 2579/2992
#    Procesando señal 2580/2992
#    Procesando señal 2581/2992
#    Procesando señal 2582/2992
#    Procesando señal 2583/2992
#    Procesando señal 2584/2992
#    Procesando señal 2585/2992
#    Procesando señal 2586/2992
#    Procesando señal 2587/2992
#    Procesando señal 2588/2992
#    Procesando señal 2589/2992
#    Procesando señal 2590/2992
# ...
#    Procesando señal 2454/2971
#    Procesando señal 2455/2971
#    Procesando señal 2456/2971
#    Procesando señal 2457/2971
#    Procesando señal 2458/2971
#    Procesando señal 2459/2971
#    Procesando señal 2460/2971
#    Procesando señal 2461/2971
#    Procesando señal 2462/2971
#    Procesando señal 2463/2971
#    Procesando señal 2464/2971
#    Procesando señal 2465/2971
#    Procesando señal 2466/2971
#    Procesando señal 2467/2971
#    Procesando señal 2468/2971
#    Procesando señal 2469/2971
#    Procesando señal 2470/2971
#    Procesando señal 2471/2971
#    Procesando señal 2472/2971
#    Procesando señal 2473/2971
#    Procesando señal 2474/2971
#    Procesando señal 2475/2971
#    Procesando señal 2476/2971
#    Procesando señal 2477/2971
#    Procesando señal 2478/2971
#    Procesando señal 2479/2971
#    Procesando señal 2480/2971
#    Procesando señal 2481/2971
#    Procesando señal 2482/2971
#    Procesando señal 2483/2971
#    Procesando señal 2484/2971
#    Procesando señal 2485/2971
#    Procesando señal 2486/2971
#    Procesando señal 2487/2971
#    Procesando señal 2488/2971
#    Procesando señal 2489/2971
#    Procesando señal 2490/2971
#    Procesando señal 2491/2971
#    Procesando señal 2492/2971
#    Procesando señal 2493/2971
#    Procesando señal 2494/2971
#    Procesando señal 2495/2971
#    Procesando señal 2496/2971
#    Procesando señal 2497/2971
#    Procesando señal 2498/2971
#    Procesando señal 2499/2971
#    Procesando señal 2500/2971
#    Procesando señal 2501/2971
#    Procesando señal 2502/2971
#    Procesando señal 2503/2971
#    Procesando señal 2504/2971
#    Procesando señal 2505/2971
#    Procesando señal 2506/2971
#    Procesando señal 2507/2971
#    Procesando señal 2508/2971
#    Procesando señal 2509/2971
#    Procesando señal 2510/2971
#    Procesando señal 2511/2971
#    Procesando señal 2512/2971
#    Procesando señal 2513/2971
#    Procesando señal 2514/2971
#    Procesando señal 2515/2971
#    Procesando señal 2516/2971
#    Procesando señal 2517/2971
#    Procesando señal 2518/2971
#    Procesando señal 2519/2971
#    Procesando señal 2520/2971
#    Procesando señal 2521/2971
#    Procesando señal 2522/2971
#    Procesando señal 2523/2971
#    Procesando señal 2524/2971
#    Procesando señal 2525/2971
#    Procesando señal 2526/2971
#    Procesando señal 2527/2971
#    Procesando señal 2528/2971
#    Procesando señal 2529/2971
#    Procesando señal 2530/2971
#    Procesando señal 2531/2971
#    Procesando señal 2532/2971
#    Procesando señal 2533/2971
#    Procesando señal 2534/2971
#    Procesando señal 2535/2971
#    Procesando señal 2536/2971
#    Procesando señal 2537/2971
#    Procesando señal 2538/2971
#    Procesando señal 2539/2971
#    Procesando señal 2540/2971
#    Procesando señal 2541/2971
#    Procesando señal 2542/2971
#    Procesando señal 2543/2971
#    Procesando señal 2544/2971
#    Procesando señal 2545/2971
#    Procesando señal 2546/2971
#    Procesando señal 2547/2971
#    Procesando señal 2548/2971
#    Procesando señal 2549/2971
#    Procesando señal 2550/2971
#    Procesando señal 2551/2971
#    Procesando señal 2552/2971
#    Procesando señal 2553/2971
#    Procesando señal 2554/2971
#    Procesando señal 2555/2971
#    Procesando señal 2556/2971
#    Procesando señal 2557/2971
#    Procesando señal 2558/2971
#    Procesando señal 2559/2971
#    Procesando señal 2560/2971
#    Procesando señal 2561/2971
#    Procesando señal 2562/2971
#    Procesando señal 2563/2971
#    Procesando señal 2564/2971
#    Procesando señal 2565/2971
#    Procesando señal 2566/2971
#    Procesando señal 2567/2971
#    Procesando señal 2568/2971
#    Procesando señal 2569/2971
#    Procesando señal 2570/2971
#    Procesando señal 2571/2971
#    Procesando señal 2572/2971
#    Procesando señal 2573/2971
#    Procesando señal 2574/2971
#    Procesando señal 2575/2971
#    Procesando señal 2576/2971
#    Procesando señal 2577/2971
#    Procesando señal 2578/2971
#    Procesando señal 2579/2971
#    Procesando señal 2580/2971
#    Procesando señal 2581/2971
#    Procesando señal 2582/2971
#    Procesando señal 2583/2971
#    Procesando señal 2584/2971
#    Procesando señal 2585/2971
#    Procesando señal 2586/2971
#    Procesando señal 2587/2971
#    Procesando señal 2588/2971
#    Procesando señal 2589/2971
#    Procesando señal 2590/2971
#    Procesando señal 2591/2971
#    Procesando señal 2592/2971
#    Procesando señal 2593/2971
#    Procesando señal 2594/2971
#    Procesando señal 2595/2971
#    Procesando señal 2596/2971
#    Procesando señal 2597/2971
#    Procesando señal 2598/2971
#    Procesando señal 2599/2971
#    Procesando señal 2600/2971
#    Procesando señal 2601/2971
#    Procesando señal 2602/2971
#    Procesando señal 2603/2971
#    Procesando señal 2604/2971
#    Procesando señal 2605/2971
#    Procesando señal 2606/2971
#    Procesando señal 2607/2971
#    Procesando señal 2608/2971
#    Procesando señal 2609/2971
#    Procesando señal 2610/2971
#    Procesando señal 2611/2971
#    Procesando señal 2612/2971
#    Procesando señal 2613/2971
#    Procesando señal 2614/2971
#    Procesando señal 2615/2971
#    Procesando señal 2616/2971
#    Procesando señal 2617/2971
#    Procesando señal 2618/2971
#    Procesando señal 2619/2971
#    Procesando señal 2620/2971
#    Procesando señal 2621/2971
#    Procesando señal 2622/2971
#    Procesando señal 2623/2971
#    Procesando señal 2624/2971
#    Procesando señal 2625/2971
#    Procesando señal 2626/2971
#    Procesando señal 2627/2971
#    Procesando señal 2628/2971
#    Procesando señal 2629/2971
#    Procesando señal 2630/2971
#    Procesando señal 2631/2971
#    Procesando señal 2632/2971
#    Procesando señal 2633/2971
#    Procesando señal 2634/2971
#    Procesando señal 2635/2971
#    Procesando señal 2636/2971
#    Procesando señal 2637/2971
#    Procesando señal 2638/2971
#    Procesando señal 2639/2971
#    Procesando señal 2640/2971
#    Procesando señal 2641/2971
#    Procesando señal 2642/2971
#    Procesando señal 2643/2971
#    Procesando señal 2644/2971
#    Procesando señal 2645/2971
#    Procesando señal 2646/2971
#    Procesando señal 2647/2971
#    Procesando señal 2648/2971
#    Procesando señal 2649/2971
#    Procesando señal 2650/2971
#    Procesando señal 2651/2971
#    Procesando señal 2652/2971
#    Procesando señal 2653/2971
#    Procesando señal 2654/2971
#    Procesando señal 2655/2971
#    Procesando señal 2656/2971
#    Procesando señal 2657/2971
#    Procesando señal 2658/2971
#    Procesando señal 2659/2971
#    Procesando señal 2660/2971
#    Procesando señal 2661/2971
#    Procesando señal 2662/2971
#    Procesando señal 2663/2971
#    Procesando señal 2664/2971
#    Procesando señal 2665/2971
#    Procesando señal 2666/2971
#    Procesando señal 2667/2971
#    Procesando señal 2668/2971
#    Procesando señal 2669/2971
#    Procesando señal 2670/2971
#    Procesando señal 2671/2971
#    Procesando señal 2672/2971
#    Procesando señal 2673/2971
#    Procesando señal 2674/2971
#    Procesando señal 2675/2971
#    Procesando señal 2676/2971
#    Procesando señal 2677/2971
#    Procesando señal 2678/2971
#    Procesando señal 2679/2971
#    Procesando señal 2680/2971
#    Procesando señal 2681/2971
#    Procesando señal 2682/2971
#    Procesando señal 2683/2971
#    Procesando señal 2684/2971
#    Procesando señal 2685/2971
#    Procesando señal 2686/2971
#    Procesando señal 2687/2971
#    Procesando señal 2688/2971
#    Procesando señal 2689/2971
#    Procesando señal 2690/2971
#    Procesando señal 2691/2971
#    Procesando señal 2692/2971
#    Procesando señal 2693/2971
#    Procesando señal 2694/2971
#    Procesando señal 2695/2971
#    Procesando señal 2696/2971
#    Procesando señal 2697/2971
#    Procesando señal 2698/2971
#    Procesando señal 2699/2971
#    Procesando señal 2700/2971
#    Procesando señal 2701/2971
#    Procesando señal 2702/2971
#    Procesando señal 2703/2971
#    Procesando señal 2704/2971
#    Procesando señal 2705/2971
#    Procesando señal 2706/2971
#    Procesando señal 2707/2971
#    Procesando señal 2708/2971
#    Procesando señal 2709/2971
#    Procesando señal 2710/2971
#    Procesando señal 2711/2971
#    Procesando señal 2712/2971
#    Procesando señal 2713/2971
#    Procesando señal 2714/2971
#    Procesando señal 2715/2971
#    Procesando señal 2716/2971
#    Procesando señal 2717/2971
#    Procesando señal 2718/2971
#    Procesando señal 2719/2971
#    Procesando señal 2720/2971
#    Procesando señal 2721/2971
#    Procesando señal 2722/2971
#    Procesando señal 2723/2971
#    Procesando señal 2724/2971
#    Procesando señal 2725/2971
#    Procesando señal 2726/2971
#    Procesando señal 2727/2971
#    Procesando señal 2728/2971
#    Procesando señal 2729/2971
#    Procesando señal 2730/2971
#    Procesando señal 2731/2971
#    Procesando señal 2732/2971
#    Procesando señal 2733/2971
#    Procesando señal 2734/2971
#    Procesando señal 2735/2971
#    Procesando señal 2736/2971
#    Procesando señal 2737/2971
#    Procesando señal 2738/2971
#    Procesando señal 2739/2971
#    Procesando señal 2740/2971
#    Procesando señal 2741/2971
#    Procesando señal 2742/2971
#    Procesando señal 2743/2971
#    Procesando señal 2744/2971
#    Procesando señal 2745/2971
#    Procesando señal 2746/2971
#    Procesando señal 2747/2971
#    Procesando señal 2748/2971
#    Procesando señal 2749/2971
#    Procesando señal 2750/2971
#    Procesando señal 2751/2971
#    Procesando señal 2752/2971
#    Procesando señal 2753/2971
#    Procesando señal 2754/2971
#    Procesando señal 2755/2971
#    Procesando señal 2756/2971
#    Procesando señal 2757/2971
#    Procesando señal 2758/2971
#    Procesando señal 2759/2971
#    Procesando señal 2760/2971
#    Procesando señal 2761/2971
#    Procesando señal 2762/2971
#    Procesando señal 2763/2971
#    Procesando señal 2764/2971
#    Procesando señal 2765/2971
#    Procesando señal 2766/2971
#    Procesando señal 2767/2971
#    Procesando señal 2768/2971
#    Procesando señal 2769/2971
#    Procesando señal 2770/2971
#    Procesando señal 2771/2971
#    Procesando señal 2772/2971
#    Procesando señal 2773/2971
#    Procesando señal 2774/2971
#    Procesando señal 2775/2971
#    Procesando señal 2776/2971
#    Procesando señal 2777/2971
#    Procesando señal 2778/2971
#    Procesando señal 2779/2971
#    Procesando señal 2780/2971
#    Procesando señal 2781/2971
#    Procesando señal 2782/2971
#    Procesando señal 2783/2971
#    Procesando señal 2784/2971
#    Procesando señal 2785/2971
#    Procesando señal 2786/2971
#    Procesando señal 2787/2971
#    Procesando señal 2788/2971
#    Procesando señal 2789/2971
#    Procesando señal 2790/2971
#    Procesando señal 2791/2971
#    Procesando señal 2792/2971
#    Procesando señal 2793/2971
#    Procesando señal 2794/2971
#    Procesando señal 2795/2971
#    Procesando señal 2796/2971
#    Procesando señal 2797/2971
#    Procesando señal 2798/2971
#    Procesando señal 2799/2971
#    Procesando señal 2800/2971
#    Procesando señal 2801/2971
#    Procesando señal 2802/2971
#    Procesando señal 2803/2971
#    Procesando señal 2804/2971
#    Procesando señal 2805/2971
#    Procesando señal 2806/2971
#    Procesando señal 2807/2971
#    Procesando señal 2808/2971
#    Procesando señal 2809/2971
#    Procesando señal 2810/2971
#    Procesando señal 2811/2971
#    Procesando señal 2812/2971
#    Procesando señal 2813/2971
#    Procesando señal 2814/2971
#    Procesando señal 2815/2971
#    Procesando señal 2816/2971
#    Procesando señal 2817/2971
#    Procesando señal 2818/2971
#    Procesando señal 2819/2971
#    Procesando señal 2820/2971
#    Procesando señal 2821/2971
#    Procesando señal 2822/2971
#    Procesando señal 2823/2971
#    Procesando señal 2824/2971
#    Procesando señal 2825/2971
#    Procesando señal 2826/2971
#    Procesando señal 2827/2971
#    Procesando señal 2828/2971
#    Procesando señal 2829/2971
#    Procesando señal 2830/2971
#    Procesando señal 2831/2971
#    Procesando señal 2832/2971
#    Procesando señal 2833/2971
#    Procesando señal 2834/2971
#    Procesando señal 2835/2971
#    Procesando señal 2836/2971
#    Procesando señal 2837/2971
#    Procesando señal 2838/2971
#    Procesando señal 2839/2971
#    Procesando señal 2840/2971
#    Procesando señal 2841/2971
#    Procesando señal 2842/2971
#    Procesando señal 2843/2971
#    Procesando señal 2844/2971
#    Procesando señal 2845/2971
#    Procesando señal 2846/2971
#    Procesando señal 2847/2971
#    Procesando señal 2848/2971
#    Procesando señal 2849/2971
#    Procesando señal 2850/2971
#    Procesando señal 2851/2971
#    Procesando señal 2852/2971
#    Procesando señal 2853/2971
#    Procesando señal 2854/2971
#    Procesando señal 2855/2971
#    Procesando señal 2856/2971
#    Procesando señal 2857/2971
#    Procesando señal 2858/2971
#    Procesando señal 2859/2971
#    Procesando señal 2860/2971
#    Procesando señal 2861/2971
#    Procesando señal 2862/2971
#    Procesando señal 2863/2971
#    Procesando señal 2864/2971
#    Procesando señal 2865/2971
#    Procesando señal 2866/2971
#    Procesando señal 2867/2971
#    Procesando señal 2868/2971
#    Procesando señal 2869/2971
#    Procesando señal 2870/2971
#    Procesando señal 2871/2971
#    Procesando señal 2872/2971
#    Procesando señal 2873/2971
#    Procesando señal 2874/2971
#    Procesando señal 2875/2971
#    Procesando señal 2876/2971
#    Procesando señal 2877/2971
#    Procesando señal 2878/2971
#    Procesando señal 2879/2971
#    Procesando señal 2880/2971
#    Procesando señal 2881/2971
#    Procesando señal 2882/2971
#    Procesando señal 2883/2971
#    Procesando señal 2884/2971
#    Procesando señal 2885/2971
#    Procesando señal 2886/2971
#    Procesando señal 2887/2971
#    Procesando señal 2888/2971
#    Procesando señal 2889/2971
#    Procesando señal 2890/2971
#    Procesando señal 2891/2971
#    Procesando señal 2892/2971
#    Procesando señal 2893/2971
#    Procesando señal 2894/2971
#    Procesando señal 2895/2971
#    Procesando señal 2896/2971
#    Procesando señal 2897/2971
#    Procesando señal 2898/2971
#    Procesando señal 2899/2971
#    Procesando señal 2900/2971
#    Procesando señal 2901/2971
#    Procesando señal 2902/2971
#    Procesando señal 2903/2971
#    Procesando señal 2904/2971
#    Procesando señal 2905/2971
#    Procesando señal 2906/2971
#    Procesando señal 2907/2971
#    Procesando señal 2908/2971
#    Procesando señal 2909/2971
#    Procesando señal 2910/2971
#    Procesando señal 2911/2971
#    Procesando señal 2912/2971
#    Procesando señal 2913/2971
#    Procesando señal 2914/2971
#    Procesando señal 2915/2971
#    Procesando señal 2916/2971
#    Procesando señal 2917/2971
#    Procesando señal 2918/2971
#    Procesando señal 2919/2971
#    Procesando señal 2920/2971
#    Procesando señal 2921/2971
#    Procesando señal 2922/2971
#    Procesando señal 2923/2971
#    Procesando señal 2924/2971
#    Procesando señal 2925/2971
#    Procesando señal 2926/2971
#    Procesando señal 2927/2971
#    Procesando señal 2928/2971
#    Procesando señal 2929/2971
#    Procesando señal 2930/2971
#    Procesando señal 2931/2971
#    Procesando señal 2932/2971
#    Procesando señal 2933/2971
#    Procesando señal 2934/2971
#    Procesando señal 2935/2971
#    Procesando señal 2936/2971
#    Procesando señal 2937/2971
#    Procesando señal 2938/2971
#    Procesando señal 2939/2971
#    Procesando señal 2940/2971
#    Procesando señal 2941/2971
#    Procesando señal 2942/2971
#    Procesando señal 2943/2971
#    Procesando señal 2944/2971
#    Procesando señal 2945/2971
#    Procesando señal 2946/2971
#    Procesando señal 2947/2971
#    Procesando señal 2948/2971
#    Procesando señal 2949/2971
#    Procesando señal 2950/2971
#    Procesando señal 2951/2971
#    Procesando señal 2952/2971
#    Procesando señal 2953/2971
#    Procesando señal 2954/2971
#    Procesando señal 2955/2971
#    Procesando señal 2956/2971
#    Procesando señal 2957/2971
#    Procesando señal 2958/2971
#    Procesando señal 2959/2971
#    Procesando señal 2960/2971
#    Procesando señal 2961/2971
#    Procesando señal 2962/2971
#    Procesando señal 2963/2971
#    Procesando señal 2964/2971
#    Procesando señal 2965/2971
#    Procesando señal 2966/2971
#    Procesando señal 2967/2971
#    Procesando señal 2968/2971
#    Procesando señal 2969/2971
#    Procesando señal 2970/2971
#    Procesando señal 2971/2971
#
#    📊 Total resultados: 3025
# ✅ Fold completado - Resultados agregados: 3025
#
# ============================================================
# 📊 CALCULANDO MÉTRICAS FINALES
# ============================================================
# 📊 RESULTADOS FINALES (Microaverage):
#    Total resultados: 47003
#    F1-Score: 80.788%
#    Precision: 81.204%
#    Recall: 80.376%
#
# 💾 Resultados guardados en: inference_results_moda_microaverage_mc_dropout.json

# %% [markdown]
# # Borrador

# %%
model = SEED_Model()

for name, param in model.named_parameters():
    print(name)
    print(param.shape)
    # print(name, param.shape)
# Out:
# [(64, 1), (32, 2), (16, 4), (16, 8)]
# [(128, 1), (64, 2), (32, 4), (32, 8)]
# embedding.conv_layer.bn.weight
# torch.Size([1])
# embedding.conv_layer.bn.bias
# torch.Size([1])
# embedding.conv_layer.ln.weight
# torch.Size([1])
# embedding.conv_layer.ln.bias
# torch.Size([1])
# embedding.conv_layer.conv_blocks.0.convs.0.weight
# torch.Size([64, 1, 3])
# embedding.conv_layer.conv_blocks.0.convs.0.bias
# torch.Size([64])
# embedding.conv_layer.conv_blocks.0.convs.1.weight
# torch.Size([64, 64, 3])
# embedding.conv_layer.conv_blocks.0.convs.1.bias
# torch.Size([64])
# embedding.conv_layer.conv_blocks.0.bns.0.weight
# torch.Size([64])
# embedding.conv_layer.conv_blocks.0.bns.0.bias
# torch.Size([64])
# embedding.conv_layer.conv_blocks.0.bns.1.weight
# torch.Size([64])
# embedding.conv_layer.conv_blocks.0.bns.1.bias
# torch.Size([64])
# embedding.layer_dilatations.0.branches.0.0.weight
# torch.Size([64, 64, 3])
# embedding.layer_dilatations.0.branches.0.1.weight
# torch.Size([64])
# embedding.layer_dilatations.0.branches.0.1.bias
# torch.Size([64])
# embedding.layer_dilatations.0.branches.0.3.weight
# torch.Size([64, 64, 3])
# embedding.layer_dilatations.0.branches.0.4.weight
# torch.Size([64])
# embedding.layer_dilatations.0.branches.0.4.bias
# torch.Size([64])
# embedding.layer_dilatations.0.branches.1.0.weight
# torch.Size([32, 64, 3])
# embedding.layer_dilatations.0.branches.1.1.weight
# torch.Size([32])
# embedding.layer_dilatations.0.branches.1.1.bias
# torch.Size([32])
# embedding.layer_dilatations.0.branches.1.3.weight
# torch.Size([32, 32, 3])
# embedding.layer_dilatations.0.branches.1.4.weight
# torch.Size([32])
# embedding.layer_dilatations.0.branches.1.4.bias
# torch.Size([32])
# embedding.layer_dilatations.0.branches.2.0.weight
# torch.Size([16, 64, 3])
# embedding.layer_dilatations.0.branches.2.1.weight
# torch.Size([16])
# embedding.layer_dilatations.0.branches.2.1.bias
# torch.Size([16])
# embedding.layer_dilatations.0.branches.2.3.weight
# torch.Size([16, 16, 3])
# embedding.layer_dilatations.0.branches.2.4.weight
# torch.Size([16])
# embedding.layer_dilatations.0.branches.2.4.bias
# torch.Size([16])
# embedding.layer_dilatations.0.branches.3.0.weight
# torch.Size([16, 64, 3])
# embedding.layer_dilatations.0.branches.3.1.weight
# torch.Size([16])
# embedding.layer_dilatations.0.branches.3.1.bias
# torch.Size([16])
# embedding.layer_dilatations.0.branches.3.3.weight
# torch.Size([16, 16, 3])
# embedding.layer_dilatations.0.branches.3.4.weight
# torch.Size([16])
# embedding.layer_dilatations.0.branches.3.4.bias
# torch.Size([16])
# embedding.layer_dilatations.1.branches.0.0.weight
# torch.Size([128, 128, 3])
# embedding.layer_dilatations.1.branches.0.1.weight
# torch.Size([128])
# embedding.layer_dilatations.1.branches.0.1.bias
# torch.Size([128])
# embedding.layer_dilatations.1.branches.0.3.weight
# torch.Size([128, 128, 3])
# embedding.layer_dilatations.1.branches.0.4.weight
# torch.Size([128])
# embedding.layer_dilatations.1.branches.0.4.bias
# torch.Size([128])
# embedding.layer_dilatations.1.branches.1.0.weight
# torch.Size([64, 128, 3])
# embedding.layer_dilatations.1.branches.1.1.weight
# torch.Size([64])
# embedding.layer_dilatations.1.branches.1.1.bias
# torch.Size([64])
# embedding.layer_dilatations.1.branches.1.3.weight
# torch.Size([64, 64, 3])
# embedding.layer_dilatations.1.branches.1.4.weight
# torch.Size([64])
# embedding.layer_dilatations.1.branches.1.4.bias
# torch.Size([64])
# embedding.layer_dilatations.1.branches.2.0.weight
# torch.Size([32, 128, 3])
# embedding.layer_dilatations.1.branches.2.1.weight
# torch.Size([32])
# embedding.layer_dilatations.1.branches.2.1.bias
# torch.Size([32])
# embedding.layer_dilatations.1.branches.2.3.weight
# torch.Size([32, 32, 3])
# embedding.layer_dilatations.1.branches.2.4.weight
# torch.Size([32])
# embedding.layer_dilatations.1.branches.2.4.bias
# torch.Size([32])
# embedding.layer_dilatations.1.branches.3.0.weight
# torch.Size([32, 128, 3])
# embedding.layer_dilatations.1.branches.3.1.weight
# torch.Size([32])
# embedding.layer_dilatations.1.branches.3.1.bias
# torch.Size([32])
# embedding.layer_dilatations.1.branches.3.3.weight
# torch.Size([32, 32, 3])
# embedding.layer_dilatations.1.branches.3.4.weight
# torch.Size([32])
# embedding.layer_dilatations.1.branches.3.4.bias
# torch.Size([32])
# transformer.lstm.weight_ih_l0
# torch.Size([1024, 256])
# transformer.lstm.weight_hh_l0
# torch.Size([1024, 256])
# transformer.lstm.bias_ih_l0
# torch.Size([1024])
# transformer.lstm.bias_hh_l0
# torch.Size([1024])
# transformer.lstm.weight_ih_l0_reverse
# torch.Size([1024, 256])
# transformer.lstm.weight_hh_l0_reverse
# torch.Size([1024, 256])
# transformer.lstm.bias_ih_l0_reverse
# torch.Size([1024])
# transformer.lstm.bias_hh_l0_reverse
# torch.Size([1024])
# transformer.lstm.weight_ih_l1
# torch.Size([1024, 512])
# transformer.lstm.weight_hh_l1
# torch.Size([1024, 256])
# transformer.lstm.bias_ih_l1
# torch.Size([1024])
# transformer.lstm.bias_hh_l1
# torch.Size([1024])
# transformer.lstm.weight_ih_l1_reverse
# torch.Size([1024, 512])
# transformer.lstm.weight_hh_l1_reverse
# torch.Size([1024, 256])
# transformer.lstm.bias_ih_l1_reverse
# torch.Size([1024])
# transformer.lstm.bias_hh_l1_reverse
# torch.Size([1024])
# classifier.hidden.weight
# torch.Size([128, 512])
# classifier.hidden.bias
# torch.Size([128])
# classifier.logits.weight
# torch.Size([1, 128])
# classifier.logits.bias
# torch.Size([1])
